# %% [markdown]
# # CNA news crawling: step by step
#
# 中央社新聞爬蟲-分解動作
#
# Only 20 pieces of news for each category in a page

# %% [markdown]
# Beautiful Soup is a HTML/XML parser with Python
# Beautiful Soup是用Python寫的一個HTML/XML的解析器
#
#     find specified tag with the following appraoches:
#     尋找特定標籤或有著特定屬性的標籤Tag，有以下兩種方法
#
#     (1)find
#     find('article', {'class':"article"})
#     findAll('' , {})
#
#
#
#     (2)select
#     select_one()
#     select()
#
#
#     findAll():  find all 找到全部
#     find():    find one 找到一個就停止
#
#     連續查找:
#     find().find()
#
# Reference參考資料
# https://www.crummy.com/software/BeautifulSoup/bs3/documentation.html

# %%
import requests
from bs4 import BeautifulSoup
import re
from fake_useragent import UserAgent

# %%
user_agent = UserAgent()

# %%
user_agent.random
# Out:
# 'Mozilla/5.0 (Windows NT 10.0; Win64; x64; rv:109.0) Gecko/20100101 Firefox/118.0'

# %% [markdown]
# # Crawl title and links from a certain page
#
# 爬取某一類新聞標題與連結(以政治新聞為例)

# %% [markdown]
# ## Political news
#
# 以政治新聞為例

# %%
category_url = 'https://www.sportsv.net/baseball/mlb'
# req = requests.get( category_url )
req = requests.get(category_url, headers={ 'user-agent': user_agent.random }, timeout=5)

# %%
req
# Out:
# <Response [200]>

# %%
req.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-Hant-TW">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <meta name="_token" content="DBIWKx6SdVrqDO6p5cKgPRJLnMOBYq0jOPNE84Gu"/>\n        <link rel="shortcut icon" href="https://www.sportsv.net/assets/images/favicon.ico" type="image/x-icon">\n        <title>MLB | 運動視界 Sports Vision</title>\n<meta name="description" content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler">\n<link rel="canonical" href="https://www.sportsv.net/baseball/mlb">\n        <meta property="og:title" content="MLB | 運動視界 Sports Vision">\n<meta property="og:description" content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler">\n<meta property="og:url" content="https://www.sportsv.net/baseball/mlb">\n<meta property="og:site_name" content="運動視界 Sports Vision">\n<meta property="og:locale" content="zh_TW">\n<meta property="og:image" content="https://www.sportsv.net/assets/images/social-share.jpg">\n\n        <meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="運動視界 Sports Vision">\n<meta name="twitter:creator" content="運動視界 Sports Vision">\n<meta name="twitter:title" content="MLB | 運動視界 Sports Vision">\n<meta name="twitter:description" content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler">\n\n        <meta name="robots" content="all">\n\n        <link rel="preload" as="style" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" /><link rel="preload" as="style" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" /><link rel="stylesheet" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" /><link rel="stylesheet" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" />        <script>\n          window.pbjs = window.pbjs || {que: []};\n                window.googletag = window.googletag || {cmd: []};\n      </script>\n  <script async src="https://flux-cdn.com/client/1000265/sportsv_01465.min.js"></script>\n  <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>\n  <script>\n    window.fluxtag = {\n      readyBids: {prebid: false, amazon: false, google: false},\n      failSafeTimeout: 3000,\n      isFn: function (object) {\n        var _t = \'Function\';\n        var toString = Object.prototype.toString;\n        return toString.call(object) === \'[object \' + _t + \']\';\n      },\n      launchAdServer: function () {\n        if (!fluxtag.readyBids.prebid || !fluxtag.readyBids.amazon) {\n          return;\n        }\n        fluxtag.requestAdServer();\n      },\n      requestAdServer: function () {\n        if (!fluxtag.readyBids.google) {\n          fluxtag.readyBids.google = true;\n          googletag.cmd.push(function () {\n            if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {\n              pbjs.que.push(function () { pbjs.setTargetingForGPTAsync(); });\n            }\n            googletag.pubads().refresh();\n          });\n        }\n      },\n      renderAds: function (lines, failSafeTimeout) {\n        googletag.cmd.push(function () {\n          var failSafeTimeout = failSafeTimeout || window.fluxtag.failSafeTimeout;\n          var bidRequestTimeout = (failSafeTimeout - 500) > 0 ? failSafeTimeout - 500 : failSafeTimeout;\n          var refreshLines = [];\n          var param ...

# %%
# page = BeautifulSoup(req.text,'lxml')
page = BeautifulSoup(req.text, 'html.parser')

# %%
print(page)
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant-TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="DBIWKx6SdVrqDO6p5cKgPRJLnMOBYq0jOPNE84Gu" name="_token">
# <link href="https://www.sportsv.net/assets/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>MLB | 運動視界 Sports Vision</title>
# <meta content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler" name="description"/>
# <link href="https://www.sportsv.net/baseball/mlb" rel="canonical"/>
# <meta content="MLB | 運動視界 Sports Vision" property="og:title"/>
# <meta content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler" property="og:description"/>
# <meta content="https://www.sportsv.net/baseball/mlb" property="og:url"/>
# <meta content="運動視界 Sports Vision" property="og:site_name"/>
# <meta content="zh_TW" property="og:locale"/>
# <meta content="https://www.sportsv.net/assets/images/social-share.jpg" property="og:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="運動視界 Sports Vision" name="twitter:site"/>
# <meta content="運動視界 Sports Vision" name="twitter:creator"/>
# <meta content="MLB | 運動視界 Sports Vision" name="twitter:title"/>
# <meta content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler" name="twitter:description"/>
# <meta content="all" name="robots"/>
# <link as="style" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" rel="preload"><link as="style" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" rel="preload"><link href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" rel="stylesheet"/><link href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" rel="stylesheet"/> <script>
#           window.pbjs = window.pbjs || {que: []};
#                 window.googletag = window.googletag || {cmd: []};
#       </script>
# <script async="" src="https://flux-cdn.com/client/1000265/sportsv_01465.min.js"></script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#     window.fluxtag = {
#       readyBids: {prebid: false, amazon: false, google: false},
#       failSafeTimeout: 3000,
#       isFn: function (object) {
#         var _t = 'Function';
#         var toString = Object.prototype.toString;
#         return toString.call(object) === '[object ' + _t + ']';
#       },
#       launchAdServer: function () {
#         if (!fluxtag.readyBids.prebid || !fluxtag.readyBids.amazon) {
#           return;
#         }
#         fluxtag.requestAdServer();
#       },
#       requestAdServer: function () {
#         if (!fluxtag.readyBids.google) {
#           fluxtag.readyBids.google = true;
#           googletag.cmd.push(function () {
#             if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {
#               pbjs.que.push(function () { pbjs.setTargetingForGPTAsync(); });
#             }
#             googletag.pubads().refresh();
#           });
#         }
#       },
#       renderAds: function (lines, failSafeTimeout) {
#         googletag.cmd.push(function () {
#           var failSafeTimeout = failSafeTimeout || window.fluxtag.failSafeTimeout;
#           var bidRequestTimeout = (failSafeTimeout - 500) > 0 ? failSafeTimeout - 500 : failSafeTimeout;
#           var refreshLines = [];
#           var params = (function () {
#             var readyBids = {amazon: false, google: false, prebid: false};
#             var definedSlots = [];
#             var adsInfo = {
#               gpt: {slots: [], displayDivIds: []},
#               aps: {slots: [], divIds: []},
#               pb: {divIds: []},
#             };
#             var getSizeList = function (width, height, sizeMappings) {
#               const sizeMapping = sizeMappings.filter(function (mappingObject) {
#                 return mappingObject[0][0] <= width && mappingObject[0][1] <= height;
#               }).reduce(function (a, b) {
#                 return (Math.abs(b[0][0] - width) <= Math.abs(a[0][0] - width) && Math.abs(b[0][1] - height) <= Math.abs(a[0][1] - height)) ? b : a;
#               });
#               if (!sizeMapping[1].length) {
#                 sizeMapping[1].push([]);
#               }
#               return sizeMapping[1];
#             };
#             googletag.pubads().getSlots().forEach(function (slot) {
#               definedSlots[slot.getSlotElementId()] = slot;
#             });
#             lines.forEach(function (line) {
#               var divId = line.divId;
#               adsInfo.pb.divIds.push(divId);
#               refreshLines.push({code: line.gpt.unitCode, id: divId});
#               if (definedSlots[divId]) {
#                 adsInfo.gpt.slots.push(definedSlots[divId]);
#               } else {
#                 var slot = googletag.defineSlot(line.gpt.unitCode, line.gpt.sizes, divId).addService(googletag.pubads());
#                 if (line.gpt.sizeMapping && line.gpt.sizeMapping.length > 0) {
#                   var sizeMapping = googletag.sizeMapping();
#                   line.gpt.sizeMapping.forEach(function (size) {
#                     sizeMapping.addSize(size[0], size[1]);
#                   });
#                   slot.defineSizeMapping(sizeMapping.build());
#                 }
#                 if (line.gpt.keyValues && line.gpt.keyValues.length > 0) {
#                   line.gpt.keyValues.forEach(function (param) {
#                     slot.setTargeting(param.key, param.value);
#                   });
#                 }
#                 adsInfo.gpt.slots.push(slot);
#                 adsInfo.gpt.displayDivIds.push(divId);
#               }
#               if (!!line.aps) {
#                 if (line.gpt.sizeMapping && line.gpt.sizeMapping.length > 0) {
#                   line.aps.sizes = getSizeList(window.innerWidth, window.innerHeight, line.gpt.sizeMapping);
#                 }
#                 adsInfo.aps.slots.push({
#                   slotID: divId,
#                   slotName: line.aps.slotName,
#                   sizes: line.aps.sizes,
#                 });
#                 adsInfo.aps.divIds.push(divId);
#               }
#             });
#             if (adsInfo.aps.slots.length === 0) {
#               readyBids.amazon = true;
#             }
#             var adServerSend = function () {
#               if (!readyBids.amazon || !readyBids.prebid) {
#                 return;
#               }
#               if (!readyBids.google) {
#                 readyBids.google = true;
#                 adsInfo.gpt.displayDivIds.forEach(function (divId) {
#                   googletag.display(divId);
#                 });
#                 if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {
#                   pbjs.que.push(function () {
#                     pbjs.setTargetingForGPTAsync(adsInfo.pb.divIds);
#                   });
#                 }
#                 if (adsInfo.aps.slots.length > 0 && !!(window.apstag) && fluxtag.isFn(window.apstag.fetchBids)) {
#                   window.apstag.setDisplayBids(adsInfo.aps.divIds);
#                 }
#                 googletag.pubads().refresh(adsInfo.gpt.slots);
#               }
#             };
#             var apsCallback = function () {
#               readyBids.amazon = true;
#               adServerSend();
#             };
#             var pbCallback = function () {
#               readyBids.prebid = true;
#               adServerSend();
#             };
#             setTimeout(function () {
#               readyBids.amazon = true;
#               readyBids.prebid = true;
#               adServerSend();
#             }, failSafeTimeout);
#             return {aps: {slots: adsInfo.aps.slots, callback: apsCallback}, prebid: {callback: pbCallback}};
#           })();
#           if (!!(window.pbFlux) && window.pbFlux.refresh && fluxtag.isFn(window.pbFlux.refresh)) {
#             pbjs.que.push(function () {
#               window.pbFlux.refresh({
#                 lines: refreshLines,
#                 callback: params.prebid.callback,
#                 timeout: bidRequestTimeout,
#               });
#             });
#           } else {
#             params.prebid.callback();
#           }
#           if (params.aps.slots.length > 0 && !!(window.apstag) && fluxtag.isFn(window.apstag.fetchBids)) {
#             window.apstag.fetchBids({
#               slots: params.aps.slots,
#               timeout: bidRequestTimeout,
#             }, function (bids) { params.aps.callback(); });
#           } else {
#             params.aps.callback();
#           }
#         });
#       },
#     };
#   </script>
# <script>
#     googletag.cmd.push(function () {
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().collapseEmptyDivs();
#                         googletag.enableServices();
#     });
#   </script>
# <script>
#     window.tmgad = {
#       serial: 0,
#       loaded: false,
#       scan: function () {
#         googletag.cmd.push(function () {
#           let list = document.querySelectorAll('.tmgad-new');
#           for (let i = 0; i < list.length; i++) {
#             tmgad.build(list[i]);
#           }
#         });
#         if (!tmgad.loaded) {
#           document.addEventListener('DOMContentLoaded', function () {
#             tmgad.scan();
#           });
#           tmgad.loaded = true;
#         }
#       },
#       build: function (target) {
#         if (!target.classList.contains('tmgad-new')) {
#           console.log('TMGAD build: Pass ' + target.getAttribute('class'));
#           return;
#         }
#         try { target.classList.remove('tmgad-new'); } catch (e) {}
#         let attributes = {id: '', name: '', slot: '', type: 'general', size: [], mapping: [], targeting: {}};
#         try {
#           attributes = Object.assign(attributes, JSON.parse(target.querySelector('script').textContent.trim()));
#           tmgad.serial++;
#           attributes.id = 'tmgad-' + attributes.name + '-' + tmgad.serial;
#           target.setAttribute('id', attributes.id);
#           switch (attributes.type) {
#             case 'flux':
#               let flux = {
#                 divId: attributes.id,
#                 gpt: {
#                   unitCode: attributes.slot,
#                   sizes: attributes.size,
#                   sizeMapping: attributes.mapping,
#                   keyValues: [],
#                 },
#               };
#               for (let targeting in attributes.targeting) {
#                 if (!attributes.targeting[targeting].length) {
#                   continue;
#                 }
#                 flux.gpt.keyValues.push({key: targeting, value: attributes.targeting[targeting]});
#               }
#               window.fluxtag.renderAds([flux]);
#               return;
#           }
#           let mapping = googletag.sizeMapping();
#           for (let i = 0; i < attributes.mapping.length; i++) {
#             if (!attributes.mapping[i][1].length) {
#               continue;
#             }
#             mapping = mapping.addSize(attributes.mapping[i][0], attributes.mapping[i][1]);
#           }
#           let service = googletag.pubads();
#           for (let targeting in attributes.targeting) {
#             if (!attributes.targeting[targeting].length) {
#               continue;
#             }
#             service.setTargeting(targeting, attributes.targeting[targeting]);
#           }
#           googletag.cmd.push(function () {
#             let slot;
#             switch (attributes.type) {
#               case 'oop':
#                 slot = googletag.defineOutOfPageSlot(attributes.slot, attributes.id)
#                   .addService(service);
#                 break;
#               default:
#                 slot = googletag.defineSlot(attributes.slot, attributes.size, attributes.id)
#                   .defineSizeMapping(mapping.build()).addService(service);
#                 break;
#             }
#             googletag.display(attributes.id);
#             googletag.pubads().refresh([slot]);
#           });
#         } catch (e) {
#           console.warn('TMGAD build: [' + attributes.id + ']' + e.message);
#           return false;
#         }
#       },
#     };
#   </script>
# <script id="sportsv_info" type="application/json">{"datalayer_sets":{"analyticsAuthors":[],"analyticsTerms":[{"type":"category","key":"baseball","name":"\u68d2\u7403"},{"type":"category","key":"mlb","name":"MLB"}]}}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-XYPFETDX47&amp;l=ga4DataLayer"></script>
# <script>
#     window.ga4DataLayer = window.ga4DataLayer || [];
#     function ga4_tag(){ga4DataLayer.push(arguments);}
#     ga4_tag('js', new Date());
#     ga4_tag('config', 'G-XYPFETDX47');
#     (function () {
#         try {
#             window.Sportsv = window.Sportsv || {};
#             if (!window.Sportsv.sourceMaterial) {
#                 window.Sportsv.sourceMaterial = {};
#                 window.Sportsv.sourceMaterial = JSON.parse(document.getElementById('sportsv_info').textContent)
#             }
#             let source = window.Sportsv?.sourceMaterial
#             source.datalayer_sets.analyticsAuthors.forEach(function (value){
#                 ga4_tag('event', 'Counter-Author', {
#                     'action': 'trigger',
#                     'label': value.name
#                 })
#             })
#             source.datalayer_sets.analyticsTerms.forEach(function (value){
#                 ga4_tag('event', 'Counter-Term', {
#                     'action': 'trigger',
#                     'label': value.name
#                 })
#             })
#         } catch (e) {}
#     })();
# </script>
# <script>
#     window.BrandGtmDataLayer = window.BrandGtmDataLayer || [];
#     window.DaexGtmDataLayer = window.DaexGtmDataLayer || [];
#     window.TNLMGTagDataLayer = window.TNLMGTagDataLayer || [];
#     DaexGtmDataLayer.push({'ID' : 'D-100007'});
#     TNLMGTagDataLayer.push({
#         event: 'config',
#         config_id: 'a2fdd15c62e51c434bff7452b5025520e5deca2c45a198aa2da0b04aef7b4a7f',
#     });
#     let memberId = localStorage.getItem('member_id');
#     if (memberId) {
#         TNLMGTagDataLayer.push({
#             event: 'set_member_id',
#             member_id: memberId,
#         });
#     }
#     (function () {
#         try {
#             let source = window.Sportsv?.sourceMaterial
#
#             BrandGtmDataLayer.push(source.datalayer_sets);
#             DaexGtmDataLayer.push(source.datalayer_sets);
#
#
#             //BrandGtmDataLayer.push({'event': 'UserLoaded'})
#             //DaexGtmDataLayer.push({'event': 'UserLoaded'})
#
#             TNLMGTagDataLayer.push({event: 'pageview'});
#
#                     } catch (e) {}
#     })();
#
#     // BRAND
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','BrandGtmDataLayer','GTM-TX847V4');
#
#     // DAEX
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','DaexGtmDataLayer','GTM-5THSZR9');
#
#     /* TNLMGTag */
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','TNLMGTagDataLayer','GTM-5HR8SM3V');
#
#     /* Inkmagine */
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','inkmagineDataLayer','GTM-MGHRKMRV');
# </script>
# <!-- Begin Comscore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({c1: "2", c2: "17728543", options: {enableFirstPartyCookie: true, bypassUserConsentRequirementFor1PCookie: true}});
#     (function () {
#         var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#         s.async = true; s.src = "https://sb.scorecardresearch.com/cs/17728543/beacon.js";
#         el.parentNode.insertBefore(s, el);
#     })();
# </script>
# <!--End Comscore Tag-->
# <script type="text/javascript">
#     (function() {
#         let sections = [];
#         let authors = [];
#         try {
#             let source = window.Sportsv?.sourceMaterial;
#             source.datalayer_sets.analyticsAuthors.forEach(function (value){
#                 authors.push(value.name);
#             });
#             source.datalayer_sets.analyticsTerms.forEach(function (value){
#                 if (value.type == 'category') {
#                     sections.push(value.name);
#                 }
#             });
#         }catch(e) {}
#         /** CONFIGURATION START **/
#         var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
#         _sf_async_config.uid = 61305;
#         _sf_async_config.domain = 'sportsv.net'; //CHANGE THIS TO THE ROOT DOMAIN
#         _sf_async_config.flickerControl = false;
#         _sf_async_config.useCanonical = true;
#         _sf_async_config.useCanonicalDomain = true;
#         _sf_async_config.sections = sections.join(','); // CHANGE THIS TO YOUR SECTION NAME(s)
#         _sf_async_config.authors = authors.join(','); // CHANGE THIS TO YOUR AUTHOR NAME(s)
#         /** CONFIGURATION END **/
#         function loadChartbeat() {
#             var e = document.createElement('script');
#             var n = document.getElementsByTagName('script')[0];
#             e.type = 'text/javascript';
#             e.async = true;
#             e.src = '//static.chartbeat.com/js/chartbeat.js';;
#             n.parentNode.insertBefore(e, n);
#         }
#         loadChartbeat();
#     })();
# </script>
# <script async="" src="//static.chartbeat.com/js/chartbeat_mab.js"></script>
# <script>
#     !function(f,b,e,v,n,t,s)
#         {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                         n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#                 if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#                 n.queue=[];t=b.createElement(e);t.async=!0;
#                 t.src=v;s=b.getElementsByTagName(e)[0];
#                 s.parentNode.insertBefore(t,s)}(window, document,'script',
#                                 'https://connect.facebook.net/zh_TW/fbevents.js');
#     fbq('init', '2210311835696207');
#     fbq('track', 'PageView');
# </script>
# <script defer="" src="https://resource.tnlmediagene.com/assets/v1/js/tnlmedia-header-footer.js"></script>
# <script async="" src="https://www.sportsv.net/assets/assets/head-D73q8ojf.js" type="module"></script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebSite","url":"https:\/\/www.sportsv.net","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.sportsv.net\/search?q={search_term_string}","query-input":"required name=search_term_string"},"publisher":{"@type":"Organization","name":"運動視界Sports Vision","logo":"https:\/\/www.sportsv.net\/assets\/images\/logo.png"}}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebPage","name":"MLB | 運動視界 Sports Vision","description":"MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler","keywords":["聖路易紅雀","匹茲堡海盜","突破僵局制","大聯盟初登場","鄭宗哲","Erick Fedde","Mitch Keller","Tsung-Che Cheng","Joey Bart","底特律老虎","紐約洋基","Paul Goldschmidt","Aaron Judge","Tarik Skubal","Dillon Dingler"],"dateCreated":"2025-03-27T07:01:15+08:00","dateModified":"2025-04-10T09:14:57+08:00","datePublished":"2025-04-07T15:56:39+08:00","primaryImageOfPage":{"@type":"ImageObject","contentUrl":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg"}}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"ItemList","itemListElement":[{"@type":"ListItem","position":1,"name":"【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰","url":"https:\/\/www.sportsv.net\/articles\/118662","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg"},{"@type":"ListItem","position":2,"name":"【MLB2025】捕手不同卻是一樣的賽揚實力，Tarik Skubal完美出擊助老虎咬傷洋基","url":"https:\/\/www.sportsv.net\/articles\/118640","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg"},{"@type":"ListItem","position":3,"name":"日職農場化、「有原式」FA 的質疑：探析入札制度所掀起的陣陣漣漪","url":"https:\/\/www.sportsv.net\/articles\/118618","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/38d510f9-94ae-40ed-905d-123a762fbec0.png"},{"@type":"ListItem","position":4,"name":"MLB》變了味的強投對決，Sean Murphy 復出首戰四打點率勇士收下系列賽開門紅","url":"https:\/\/www.sportsv.net\/articles\/118642","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/a4640b2c-e044-47b9-9330-8eec9498ac1d.jpg"},{"@type":"ListItem","position":5,"name":"自始至終的第二順位，Vladimir Guerrero Jr. 是如何簽下五億的延長合約？","url":"https:\/\/www.sportsv.net\/articles\/118605","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/4d69a740-cdbd-4560-9fd4-c0a108ac8e60.jpg"},{"@type":"ListItem","position":6,"name":"【MLB2025】Francisco Lindor達陣生涯1500安，力挺千賀滉大擊敗馬林魚勝投開胡","url":"https:\/\/www.sportsv.net\/articles\/118615","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/602c8f19-14a5-475e-a7c8-72321285f9d1.png"},{"@type":"ListItem","position":7,"name":"農場淬鍊脫穎而出，旅美小將鄭宗哲晉升匹茲堡海盜隊一員","url":"https:\/\/www.sportsv.net\/articles\/118617","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/27b47ea5-cfdf-4c8b-9694-886c54d35eb1.jpg"},{"@type":"ListItem","position":8,"name":"MLB》大破大立刪減薪資開創王朝盛事，洛杉磯道奇如何一步步成為「邪惡帝國」？","url":"https:\/\/www.sportsv.net\/articles\/118544","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/0ca05b56-87be-4888-816c-9453ad4058fc.jpg"},{"@type":"ListItem","position":9,"name":"成為一輩子的藍鳥人！Vladimir Guerrero Jr.史上第三大約永留多倫多","url":"https:\/\/www.sportsv.net\/articles\/118609","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg"},{"@type":"ListItem","position":10,"name":"【MLB2025】單場三響砲對決連三場開轟，天使強勢解決守護者打出新風采","url":"https:\/\/www.sportsv.net\/articles\/118600","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg"},{"@type":"ListItem","position":11,"name":"五年熬出頭，鄭宗哲成史上第 18 位大聯盟台將","url":"https:\/\/www.sportsv.net\/articles\/118610","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg"},{"@type":"ListItem","position":12,"name":"《站上顛峰的武士》─ 村神的經典一擊！日本武士起死回生挺進冠軍戰","url":"https:\/\/www.sportsv.net\/articles\/118386","image":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/04\/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg"}]}</script>
# </link></link></meta></head>
# <body>
# <div class="gototop js-top">
# <a class="js-gotop" href="#">
# <i class="fa fa-fw fa-arrow-up"></i>
# </a>
# </div>
# <a class="header_translation_block-mobile toggleLan_tw_cn" href="#">
# <span class="lanText-tw active">繁</span><span class="lanText-cn">簡</span>
# </a>
# <!-- Navigation -->
# <nav class="navbar navbar-inverse" role="navigation">
# <tnlmedia-header lang="zh-tw"></tnlmedia-header>
# <div class="brand">
# <div class="container relative">
# <div class="row">
# <!-- 會員通知 -->
# <div class="popo notice bottom">
# <div class="arrow"></div>
# <h3 class="popover-title">重要通知</h3>
# <div class="popover-content">
# <div class="notice_infon" id="notice_infon">
# </div>
# </div>
# </div>
# <!-- 會員管理 -->
# <div class="popo member bottom">
# <div class="arrow"></div>
# <div class="popover-content">
# <div class="item">
# <p class="username"></p>
# <div class="menber-menu">
# <div class="menber-menu__item">
# <h4 class="menber-menu__title">會員服務</h4>
# <ul>
# <li><a href="/member/newsletter"><i class="fas fa-envelope"></i>電子報</a></li>
# <li><a href="/member/comment"><i class="fas fa-comment-dots"></i>個人留言</a></li>
# <li><a href="/member/saved-articles"><i class="fas fa-bookmark"></i>好文收藏</a></li>
# <li><a href="/member/saved-author"><i class="fas fa-heart"></i>訂閱作者</a></li>
# </ul>
# </div>
# <div class="menber-menu__item">
# <h4 class="menber-menu__title">帳號管理</h4>
# <ul>
# <li><a href="https://member.tnlmedia.com/profile" target="_blank"><i class="fas fa-user-circle"></i>個人資料</a></li>
# <li>
# <a href="https://member.tnlmedia.com/subscription" target="_blank"><i class="fa-solid fa-circle-dollar"></i>管理付費訂閱
#                             </a>
# </li>
# <li id="cabinet_btn" style="display:none">
# <a href="https://cabinet.tnlmedia.com" target="_blank"><i class="fa-solid fa-bookmark"></i>文章管理
#                             </a>
# </li>
# <li id="admin_btn" style="display:none">
# <a href="/admin/member/articles"><i class="fa-solid fa-circle-dollar"></i>稿費數據
#                             </a>
# </li>
# </ul>
# </div>
# </div>
# <a class="logout" href="/logout">登出</a>
# </div>
# </div>
# </div>
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <a class="navbar-brand" href="/"><img alt="運動視界" height="100%" src="https://www.sportsv.net/assets/images/logo.svg" title="運動視界" width="100%"/></a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="navbar-collapse" id="Brand-navbar-collapse">
# <ul class="nav navbar-nav navbar-right">
# <li>
# <a class="header_translation_block toggleLan_tw_cn" href="#">
# <span class="lanText-tw active">繁</span> / <span class="lanText-cn">簡</span>
# </a>
# </li>
# <li>
# <a href="https://www.thenewslens.com/subscription">無廣告服務</a>
# </li>
# <li>
# <a class="joinauthors" href="/joinauthors" target="_blank">成為作者</a>
# </li>
# <li id="nav-unlogingin">
# <a href="/login">
# <span>登入</span> / <span>註冊</span>
# </a>
# </li>
# <li id="nav-notice" style="display:none">
# <a class="notice" id="noticeBtn">
# <i class="fas fa-bell" id="notice-icon"></i>
# </a>
# </li>
# <li id="nav-logingin" style="display:none">
# <a class="member" id="memberBtn">
# <span class="nickname" id="memberNickname">N</span>
# </a>
# </li>
# <li>
# <div class="search_form" method="get" role="search">
# <input class="js-search_input search_input" id="search_input" name="q" placeholder="搜尋" type="text" value=""/>
# <button aria-label="搜尋" class="js-search_submit search_submit icon-search" id="search_submit">
# <i class="fa fa-fw fa-search"></i>
# </button>
# </div>
# </li>
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# <div class="overlay" id="overlay"></div>
# </div>
# <!-- /.container -->
# </div>
# <div class="navbar-content gtco-nav">
# <div class="container">
# <div class="row">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li>
# <a href="/basketball">籃球
#                             </a>
# </li>
# <li>
# <a class="active" href="/baseball">棒球
#                             </a>
# </li>
# <li>
# <a href="/sportslife">健康生活</a>
# </li>
# <li>
# <a href="/tennis">網球
#                             </a>
# </li>
# <li>
# <a href="/football">足球
#                             </a>
# </li>
# <li>
# <a href="/racing">賽車</a>
# </li>
# <li>
# <a href="/running">跑步</a>
# </li>
# <li>
# <a href="/outdoorlife">戶外</a>
# </li>
# <li>
# <a href="#" id="othersports">更多運動</a>
# </li>
# <li>
# <a href="/feature">專題</a>
# </li>
# <li>
# <a href="/gallery">圖輯</a>
# </li>
# <li>
# <a href="/authorsgroup">作者群</a>
# </li>
# <li>
# <a class="text-highlight" href="/feature/SportsvPA">PODCAST</a>
# </li>
# <li>
# <a class="text-highlight" href="/feature/aws">AI 與運動</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- 其他運動選單 -->
# <div class="navbar-content-second" id="othersports-menu">
# <div class="container">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li>
# <a href="/volleyball">
#                     排球</a>
# </li>
# <li>
# <a href="/badminton">
#                     羽球</a>
# </li>
# <li>
# <a href="/nfl">
#                     NFL</a>
# </li>
# <li>
# <a href="/wrestling">
#                     格鬥/摔角</a>
# </li>
# <li>
# <a href="/cycling">
#                     自行車</a>
# </li>
# <li>
# <a href="/triathlon">
#                     鐵人三項</a>
# </li>
# <li>
# <a href="/golf">
#                     高爾夫</a>
# </li>
# <li>
# <a href="/tabletennis">
#                     桌球</a>
# </li>
# <li>
# <a href="/trackandfield">
#                     田徑</a>
# </li>
# <li>
# <a href="/unboxing">
#                     開箱/收藏</a>
# </li>
# <li>
# <a href="/othersports">
#                     綜合運動</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="navbar-content-second">
# <div class="container">
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li>
# <a class="active" href="/baseball/mlb">MLB</a>
# </li>
# <li>
# <a href="/baseball/cpbl">中職</a>
# </li>
# <li>
# <a href="/baseball/npb">日職</a>
# </li>
# <li>
# <a href="/baseball/student">三級棒球</a>
# </li>
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# </div>
# <!-- /.container -->
# </nav>
# <!-- 廣告欄位01 -->
# <div class="adv01" style="min-height: 350px;">
# <p>請繼續往下閱讀</p>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"cabinet":["0"],"page_key":["baseball"],"page_name":["baseball"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"]},"type":"flux","slot":"\/21870649235\/sv_list_top","size":[[970,250],[300,250],[1,1]],"mapping":[[[980,0],[[970,250],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_list_top"}</script>
# </div>
# </div>
# <!-- 頭條文章 -->
# <!-- 第二列表大圖輪播 unit Carousel -->
# <header class="unit_slides_wrapper">
# <div class="unit_box">
# <div class="container unit-ct">
# <div class="unit-title pc">MLB</div>
# <div class="row">
# <div class="owl-carousel owl-unit-carousel">
# <div class="item">
# <div class="row">
# <div class="col-md-8">
# <div class="unit-title ph">MLB</div>
# <a href="https://www.sportsv.net/articles/118662">
# <div class="panel-default">
# <img class="cover" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 1200w"/>
# <div class="mask"></div>
# </div>
# </a>
# </div>
# <div class="col-md-4">
# <div class="narrative">
# <h1>
# <a href="https://www.sportsv.net/articles/118662">【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰</a>
# </h1>
# <div class="btn btn-unit">
# <a href="https://www.sportsv.net/articles/118662">閱讀完整文章
#                         <i class="fa fa-angle-right"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="row">
# <div class="col-md-8">
# <div class="unit-title ph">MLB</div>
# <a href="https://www.sportsv.net/articles/118618">
# <div class="panel-default">
# <img class="cover" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png 1200w"/>
# <div class="mask"></div>
# </div>
# </a>
# </div>
# <div class="col-md-4">
# <div class="narrative">
# <h1>
# <a href="https://www.sportsv.net/articles/118618">日職農場化、「有原式」FA 的質疑：探析入札制度所掀起的陣陣漣漪</a>
# </h1>
# <div class="btn btn-unit">
# <a href="https://www.sportsv.net/articles/118618">閱讀完整文章
#                         <i class="fa fa-angle-right"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="row">
# <div class="col-md-8">
# <div class="unit-title ph">MLB</div>
# <a href="https://www.sportsv.net/articles/118609">
# <div class="panel-default">
# <img class="cover" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg 1200w"/>
# <div class="mask"></div>
# </div>
# </a>
# </div>
# <div class="col-md-4">
# <div class="narrative">
# <h1>
# <a href="https://www.sportsv.net/articles/118609">成為一輩子的藍鳥人！Vladimir Guerrero Jr.史上第三大約永留多倫多</a>
# </h1>
# <div class="btn btn-unit">
# <a href="https://www.sportsv.net/articles/118609">閱讀完整文章
#                         <i class="fa fa-angle-right"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="row">
# <div class="col-md-8">
# <div class="unit-title ph">MLB</div>
# <a href="https://www.sportsv.net/articles/118610">
# <div class="panel-default">
# <img class="cover" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 1200w"/>
# <div class="mask"></div>
# </div>
# </a>
# </div>
# <div class="col-md-4">
# <div class="narrative">
# <h1>
# <a href="https://www.sportsv.net/articles/118610">五年熬出頭，鄭宗哲成史上第 18 位大聯盟台將</a>
# </h1>
# <div class="btn btn-unit">
# <a href="https://www.sportsv.net/articles/118610">閱讀完整文章
#                         <i class="fa fa-angle-right"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="item">
# <div class="row">
# <div class="col-md-8">
# <div class="unit-title ph">MLB</div>
# <a href="https://www.sportsv.net/articles/118597">
# <div class="panel-default">
# <img class="cover" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ccbe04ac-f610-4f05-9157-c8571021075c.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ccbe04ac-f610-4f05-9157-c8571021075c.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/ccbe04ac-f610-4f05-9157-c8571021075c.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/ccbe04ac-f610-4f05-9157-c8571021075c.jpg 1200w"/>
# <div class="mask"></div>
# </div>
# </a>
# </div>
# <div class="col-md-4">
# <div class="narrative">
# <h1>
# <a href="https://www.sportsv.net/articles/118597">MLB》雙方各退一步成就完美佳話，Vladimir Guerrero Jr. 五億延長合約續留藍鳥隊</a>
# </h1>
# <div class="btn btn-unit">
# <a href="https://www.sportsv.net/articles/118597">閱讀完整文章
#                         <i class="fa fa-angle-right"></i>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="individual_bg_orange p_left"></div>
# </div>
# </header>
# <!-- 編輯嚴選 -->
# <!-- 熱門文章 -->
# <section id="popular_articles">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h2 class="page-header">熱門文章</h2>
# </div>
# </div>
# <!-- 熱門文章 Post Row -->
# <div class="row list">
# <div class="col-xs-6">
# <div class="row item">
# <div class="col-md-5">
# <div class="panel-default">
# <a href="https://www.sportsv.net/articles/118610">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 800w"/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-md-7 infon">
# <div class="date">2025/04/08</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h4>
# <a href="https://www.sportsv.net/articles/118610">五年熬出頭，鄭宗哲成史上第 18 位大聯盟台將</a>
# </h4>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/slashyouth"><img alt="小聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon2.png" title="小聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/slashyouth">斜槓青年</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118610">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-6">
# <div class="row item">
# <div class="col-md-5">
# <div class="panel-default">
# <a href="https://www.sportsv.net/articles/118600">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 800w"/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-md-7 infon">
# <div class="date">2025/04/08</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h4>
# <a href="https://www.sportsv.net/articles/118600">【MLB2025】單場三響砲對決連三場開轟，天使強勢解決守護者打出新風采</a>
# </h4>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118600">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-6">
# <div class="row item">
# <div class="col-md-5">
# <div class="panel-default">
# <a href="https://www.sportsv.net/articles/118592">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/71adaee0-cb3a-450b-accc-49a405d396a3.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/71adaee0-cb3a-450b-accc-49a405d396a3.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/71adaee0-cb3a-450b-accc-49a405d396a3.jpg 800w"/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-md-7 infon">
# <div class="date">2025/04/07</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h4>
# <a href="https://www.sportsv.net/articles/118592">MLB》42 歲仍不言退，Justin Verlander 的到來已經對巨人隊內部產生正面影響</a>
# </h4>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/sportsveditor"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118592">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-6">
# <div class="row item">
# <div class="col-md-5">
# <div class="panel-default">
# <a href="https://www.sportsv.net/articles/118544">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/0ca05b56-87be-4888-816c-9453ad4058fc.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/0ca05b56-87be-4888-816c-9453ad4058fc.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/0ca05b56-87be-4888-816c-9453ad4058fc.jpg 800w"/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-md-7 infon">
# <div class="date">2025/04/08</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h4>
# <a href="https://www.sportsv.net/articles/118544">MLB》大破大立刪減薪資開創王朝盛事，洛杉磯道奇如何一步步成為「邪惡帝國」？</a>
# </h4>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/sportsveditor"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118544">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-6">
# <div class="row item">
# <div class="col-md-5">
# <div class="panel-default">
# <a href="https://www.sportsv.net/articles/118609">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg 800w"/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-md-7 infon">
# <div class="date">2025/04/08</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h4>
# <a href="https://www.sportsv.net/articles/118609">成為一輩子的藍鳥人！Vladimir Guerrero Jr.史上第三大約永留多倫多</a>
# </h4>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/marasportwu"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/marasportwu">Brownson</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118609">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# </div>
# </div>
# <div class="col-xs-6">
# <div class="row item">
# <div class="col-md-5">
# <div class="panel-default">
# <a href="https://www.sportsv.net/articles/118597">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ccbe04ac-f610-4f05-9157-c8571021075c.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ccbe04ac-f610-4f05-9157-c8571021075c.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/ccbe04ac-f610-4f05-9157-c8571021075c.jpg 800w"/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-md-7 infon">
# <div class="date">2025/04/07</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h4>
# <a href="https://www.sportsv.net/articles/118597">MLB》雙方各退一步成就完美佳話，Vladimir Guerrero Jr. 五億延長合約續留藍鳥隊</a>
# </h4>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/sportsveditor"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118597">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- /.row -->
# <div class="list_more">
# <div class="row">
# <div class="col-md-12">
# <!--
#                     <a class="btn btn-default" href="#">更多熱門文章
#                         <i class="fa fa-angle-right"></i>
#                     </a>
#                     -->
# <hr/>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- /.section -->
# <!--精選專題-->
# <section id="featured_individual">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h2 class="page-header">精選專題</h2>
# </div>
# </div>
# <div class="row item offset-t-80">
# <div class="col-md-6 left-col">
# <div class="panel-default">
# <a href="https://www.sportsv.net/feature/2025-mlb-preview">
# <img class="fill" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/b9723050-fae2-4333-a5ef-ecbdea4cd7aa.png" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/b9723050-fae2-4333-a5ef-ecbdea4cd7aa.png 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/03/b9723050-fae2-4333-a5ef-ecbdea4cd7aa.png 800w"/>
# </a>
# </div>
# </div>
# <div class="col-md-6 right-col">
# <div class="narrative">
# <ul class="crumb">
# <li>
#                 棒球
#                                     <i class="fa fa-chevron-right"></i>
# </li>
# <li>
#                 MLB
#             </li>
# </ul>
# <h1>
# <a href="https://www.sportsv.net/feature/2025-mlb-preview">誰是挑戰者？2025 MLB 開季專題</a>
# </h1>
# <p>道奇奪冠後，並未因此停下補強的腳步，企圖心十足的休賽季，誓言成為 21 世紀以來大聯盟第一支連霸隊伍的企圖心昭然若揭。究竟有誰能夠阻止這支持續壯大的冠軍之師？
#     </p>
# <div class="btn_featured">
# <a href="https://www.sportsv.net/feature/2025-mlb-preview">完整專題
#             <i class="fa fa-angle-right"></i>
# </a>
# </div>
# </div>
# </div>
# <div class="individual_bg p_right"></div>
# </div>
# <div class="row item">
# <div class="col-md-6">
# <div class="narrative">
# <ul class="crumb">
# <li>
#                 棒球
#                                     <i class="fa fa-chevron-right"></i>
# </li>
# <li>
#                 MLB
#             </li>
# </ul>
# <h1>
# <a href="https://www.sportsv.net/feature/chen16">永遠的台灣「殷」雄 陳偉殷退休完整專題</a>
# </h1>
# <p>立足於日本以及美國兩大職業棒球最高殿堂，生涯累積 96 勝的「台灣殷雄」陳偉殷正式退休。他的成功道路不只前無來者，之後恐怕也難再有人能夠複製。當提到台灣史上最強投手時，陳偉殷這個名字一定會被提起。就讓此專題向這位台灣棒球史上的傳奇左投致上最高敬意。
#     </p>
# <div class="btn_featured">
# <a href="https://www.sportsv.net/feature/chen16">完整專題
#             <i class="fa fa-angle-right"></i>
# </a>
# </div>
# </div>
# </div>
# <div class="col-md-6">
# <div class="panel-default">
# <a href="https://www.sportsv.net/feature/chen16">
# <img class="fill" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/fd2d591a-6df1-43cf-9743-416307b4dc3f.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/fd2d591a-6df1-43cf-9743-416307b4dc3f.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/03/fd2d591a-6df1-43cf-9743-416307b4dc3f.jpg 800w"/>
# </a>
# </div>
# </div>
# <div class="individual_bg p_left"></div>
# </div>
# <div class="list_more">
# <div class="row">
# <div class="col-md-12">
# <a class="btn btn-default" href="https://www.sportsv.net/feature">更多精選專題
#                         <i class="fa fa-angle-right"></i>
# </a>
# <hr/>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!--最新文章-->
# <section id="latest_articles">
# <div class="container">
# <div class="row">
# <div class="col-lg-12">
# <h2 class="page-header">最新文章</h2>
# </div>
# </div>
# <div class="row relative">
# <div class="col-md-12">
# <div class="item_lish">
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118662">
# <div class="panel-default">
# ...
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118609">
# <div class="panel-default">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/f8b1967f-30bc-44c4-8b19-7587bfec5cba.jpg 800w"/>
# </div>
# </a>
# </div>
# <div class="col-md-7">
# <div class="date">2025/04/08</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h3>
# <a href="https://www.sportsv.net/articles/118609">成為一輩子的藍鳥人！Vladimir Guerrero Jr.史上第三大約永留多倫多</a>
# </h3>
# <p class="description">剛過26歲的Vladimir Guerrero Jr.收到了一份超級生日大禮，歷經許多次的談判，雖然在開季前沒有談妥，但多倫多藍鳥的鍥而不捨終於把握住這塊建隊基石，端出總計14年5億美金合約成功留人，Guerrero確定終身待在藍鳥。比起許多簽下超級大約的球星，普遍被認為實力超群只是合約太貴，Guerrero生涯的成績卻讓人懷疑是否真的有5億的水準，我們今天就來聊聊開季眾多延長合約至今最大筆的主角Guerrero以及藍鳥隊。</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/marasportwu"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/marasportwu">Brownson</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118609">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/Mlb">Mlb</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Vladimir Guerrero Jr.">Vladimir Guerrero Jr.</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118600">
# <div class="panel-default">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 800w"/>
# </div>
# </a>
# </div>
# <div class="col-md-7">
# <div class="date">2025/04/08</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h3>
# <a href="https://www.sportsv.net/articles/118600">【MLB2025】單場三響砲對決連三場開轟，天使強勢解決守護者打出新風采</a>
# </h3>
# <p class="description">上賽季僅差1敗就得加入百敗俱樂部的天使，今年開季可是有不同展現，除了連續拿下三個系列賽優勢外，面對守護者三戰更是砲火猛烈，帶來勢不可擋的氣焰。首戰雖有José Ramírez三響砲打通關，但Mike Trout與Logan O'Hoppe可沒有坐以待斃，將好手感維持到後續兩場比賽，搭配牛棚投手的出色展現，打出隊史最佳的戰績開局，以下就一同來回顧雙方的精采交鋒。</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118600">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/洛杉磯天使">洛杉磯天使</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/菊池雄星">菊池雄星</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/單場三響砲">單場三響砲</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/克里夫蘭守護者">克里夫蘭守護者</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Mike Trout">Mike Trout</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/José Ramírez">José Ramírez</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Logan O'Hoppe">Logan O'Hoppe</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118610">
# <div class="panel-default">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 800w"/>
# </div>
# </a>
# </div>
# <div class="col-md-7">
# <div class="date">2025/04/08</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h3>
# <a href="https://www.sportsv.net/articles/118610">五年熬出頭，鄭宗哲成史上第 18 位大聯盟台將</a>
# </h3>
# <p class="description">備受矚目的鄭宗哲於老婆生日當天（臺灣時間４月７日），因海盜陣中金手套內野手Jared Triolo進入傷兵名單，生涯首度升上大聯盟，成為臺灣本季第一位升上大聯盟的球員。</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/slashyouth"><img alt="小聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon2.png" title="小聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/slashyouth">斜槓青年</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118610">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/Mlb">Mlb</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/大聯盟">大聯盟</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/海盜隊">海盜隊</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/鄭宗哲">鄭宗哲</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/旅美台將">旅美台將</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118386">
# <div class="panel-default">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg 800w"/>
# </div>
# </a>
# </div>
# <div class="col-md-7">
# <div class="date">2025/04/07</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h3>
# <a href="https://www.sportsv.net/articles/118386">《站上顛峰的武士》─ 村神的經典一擊！日本武士起死回生挺進冠軍戰</a>
# </h3>
# <p class="description">日本休息室所有人都衝上了場，簇擁著打出經典一擊的村上。「兩隊都打出了精彩表現，兩隊的投球也都出色。沒有哪隊想過要放棄，雖然是日本晉級，但這一晚，是屬於棒球界的勝利！」</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/sportsveditor"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118386">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/棒球">棒球</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/大谷翔平">大谷翔平</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/日職">日職</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/書摘">書摘</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/站上顛峰的武士">站上顛峰的武士</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/畢方出版">畢方出版</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <div class="pagination">
# <ul>
# <li>
# <a aria-label="prev page" href="#"><i class="fa fa-fw fa-arrow-left"></i></a>
# </li>
# <li class="active">
# <a href="#">1</a>
# </li>
#
# <li>
# <a href="https://www.sportsv.net/baseball/mlb?page=2#latest_articles">2</a>
# </li>
#
# <li>
# <a href="https://www.sportsv.net/baseball/mlb?page=3#latest_articles">3</a>
# </li>
#
# <li>
# <a href="https://www.sportsv.net/baseball/mlb?page=4#latest_articles">4</a>
# </li>
#
# <li>
# <a aria-label="next page" href="https://www.sportsv.net/baseball/mlb?page=2#latest_articles">
# <i class="fa fa-fw fa-arrow-right"></i>
# </a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!--最新圖輯-->
# <section id="latest_gallery">
# <div class="container">
# <div class="row">
# <div class="col-md-6 gtco-heading">
# <h2>最新圖輯</h2>
# <p>
#                     呈現給您：場上精采瞬間、球星故事回顧、重大排行盤點、經典語錄智慧
#                     </p>
# <div class="btn btn-border m-t-30">
# <a href="/gallery?category=baseball&amp;sub_category=mlb#gallery_filter">更多圖輯
#                             <i class="fa fa-angle-right"></i>
# </a>
# </div>
# </div>
# <div class="col-md-6">
# <div class="owl-carousel owl-latest-gallery">
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/553">
# <span class="post-date">01</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/708f49c5-1ecc-46e2-abc5-e21371c5da02.jpg);">
# </div>
# <h2 class="post-title">2022-23 MLB自由球員圖鑑</h2>
# </a>
# </div>
# </div>
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/552">
# <span class="post-date">02</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/855b2fb8-ecdd-43bf-ae02-5b787cbf2f12.jpg);">
# </div>
# <h2 class="post-title">MLB史上奪三座賽揚獎以上的名投</h2>
# </a>
# </div>
# </div>
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/551">
# <span class="post-date">03</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/35db7d9f-f1d7-4540-823d-ceb188ec61a3.jpg);">
# </div>
# <h2 class="post-title">MLB 2022 年賽季 WAR 值榜</h2>
# </a>
# </div>
# </div>
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/534">
# <span class="post-date">04</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/0d63d881-e8fe-4245-b407-3945ddc4a357.jpg);">
# </div>
# <h2 class="post-title">MLB生涯超過10座金手套的球員</h2>
# </a>
# </div>
# </div>
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/550">
# <span class="post-date">05</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/f4f9a55c-dd86-46af-acf0-c685439b56e2.jpg);">
# </div>
# <h2 class="post-title">MLB單季60轟巨砲</h2>
# </a>
# </div>
# </div>
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/548">
# <span class="post-date">06</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/25f0d643-e2b7-433e-839a-309aeca14a3d.jpg);">
# </div>
# <h2 class="post-title">MLB生涯投超過5000局的投手</h2>
# </a>
# </div>
# </div>
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/547">
# <span class="post-date">07</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/051943ab-5c4c-47cf-ab25-fd47a8a54288.jpg);">
# </div>
# <h2 class="post-title">MLB生涯出賽3000場以上的球員</h2>
# </a>
# </div>
# </div>
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/546">
# <span class="post-date">08</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/96d51312-18be-4382-98f6-46628fba8a68.jpg);">
# </div>
# <h2 class="post-title">MLB 兩千勝的名教頭</h2>
# </a>
# </div>
# </div>
# <div class="item">
# <div class="gtco-item">
# <a href="https://www.sportsv.net/album/22">
# <span class="post-date">09</span>
# <div class="work" style="background-image: url(https://bucket-image.inkmaginecms.com/version/list/1/image/2024/04/0799cbb8-b10b-407a-8f0a-7c3334c90cc3.jpg);">
# </div>
# <h2 class="post-title">大聯盟三千安俱樂部</h2>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- Footer -->
# <footer>
# <div class="container inner">
# <div class="row">
# <div class="col-md-5 col-sm-6">
# <a class="navbar-brand" href="/"><img alt="運動視界" height="100%" loading="lazy" src="https://www.sportsv.net/assets/images/logo.svg" title="運動視界" width="203"/></a>
# <h4>愛你的運動，秀你的視界！</h4>
# <p>
#                 《運動視界》是一個「為了帶給喜愛運動的朋友們收穫與感動而存在的組織、平台與社群」，希望讓大家每天能樂在其中，一起發掘，專屬於你的運動見解。
#                 </p>
# </div>
# <div class="col-md-5 col-md-offset-2 col-sm-6">
# <ul class="list-unstyled list-inline list-social-icons">
# <li>
# <a aria-label="feacbook link" href="https://www.facebook.com/SportsV.net" target="_blank">
# <i class="fab fa-facebook-square"></i>
# </a>
# </li>
# <li>
# <a aria-label="instagram link" href="https://www.instagram.com/sportsvnet/" target="_blank">
# <i class="fab fa-instagram"></i>
# </a>
# </li>
# <li>
# <a aria-label="line link" href="http://line.me/ti/p/%40gec9366m" target="_blank">
# <i class="fab fa-line"></i>
# </a>
# </li>
# <li>
# <a aria-label="rss link" href="/feed" rel="alternate" target="_blank" type="application/rss+xml">
# <i class="fas fa-rss-square"></i>
# </a>
# </li>
# </ul>
# <div class="subscription">
# <h5 class="title">訂閱運動視界電子報</h5>
# <a href="/member/newsletter" target="_blank">
# <form autocomplete="off" class="fbds-search__form fbds-search__form--open" id="templates-search-form" method="get">
# <input class="fbds-search__input" id="subscribe-newsletter-email" name="search" readonly="" required="" type="search"/>
# <a class="fbds-search__icon" href="/member/newsletter" target="_blank">訂閱</a>
# </form>
# </a>
# </div>
# </div>
# <div class="col-sm-12">
# <div class="widget">
# <div class="row">
# <div class="col-sm-3 col-xs-6">
# <ul class="post-list">
# <li>
# <h6>關於運動視界</h6>
# </li>
# <li>
# <h6>
# <a href="https://www.tnlmediagene.com/zh-tw/media/sportsv" target="_blank">關於我們</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/joinauthors">成為作者</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/qa">常見問題</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/announce">站方公告</a>
# </h6>
# </li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <ul class="post-list">
# <li>
# <h6>作者相關權益</h6>
# </li>
# <li>
# <h6>
# <a href="/terms">服務條款</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/authorterms">作者條款</a>
# </h6>
# </li>
# </ul>
# </div>
# <div class="col-sm-6 col-xs-12">
# <ul class="post-list">
# <li>
# <h6>聯絡我們</h6>
# </li>
# <li><h6>
# <a href="mailto:contactus@sportsv.net" target="_blank">內容檢舉、其他意見<span>contactus@sportsv.net</span></a>
# </h6>
# </li>
# <li><h6><a href="mailto:editor@sportsv.net" target="_blank">新聞採訪、作者發文相關問題<span>editor@sportsv.net</span></a></h6></li>
# <li><h6><a href="mailto:sales@sportsv.net" target="_blank">廣告採購、授權詢問、業務相關合作<span>sales@sportsv.net</span></a></h6></li>
# <li><h6><a href="mailto:partnership@sportsv.net" target="_blank">非業務相關行銷合作洽詢<span>partnership@sportsv.net</span></a></h6></li>
# </ul>
# </div>
# </div>
# <!-- /.post-list -->
# </div>
# <!-- /.widget -->
# </div>
# </div>
# </div>
# <tnlmedia-footer lang="zh-tw"></tnlmedia-footer>
# </footer>
# <!-- Float -->
# <div>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"cabinet":["0"],"page_key":["baseball"],"page_name":["baseball"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"]},"type":"flux","slot":"\/21870649235\/sv_all_float_inner","size":[[1,1]],"mapping":[[[0,0],[[1,1]]]],"name":"sv_all_float_inner"}</script>
# </div>
# </div>
# <link href="https://www.sportsv.net/assets/assets/vendor-BIB0qm4L.js" rel="modulepreload"/><link href="https://www.sportsv.net/assets/assets/_commonjsHelpers-Cpj98o6Y.js" rel="modulepreload"/><script src="https://www.sportsv.net/assets/assets/vendor-BIB0qm4L.js" type="module"></script> <link href="https://www.sportsv.net/assets/assets/main-kUc6ua8r.js" rel="modulepreload"/><script src="https://www.sportsv.net/assets/assets/main-kUc6ua8r.js" type="module"></script>
# <script src="https://s.skimresources.com/js/255443X1762629.skimlinks.js" type="text/javascript"></script>
# <div>
# <div class="tmgad tmgad-type-general tmgad-new">
# <script type="application/json">{"targeting":{"cabinet":["0"],"page_key":["baseball"],"page_name":["baseball"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"]},"type":"general","slot":"\/21870649235\/sv_all_bottom_mobile_special","size":[[320,100],[1,1]],"mapping":[[0,0],[[320,100],[1,1]]],"name":"sv_all_bottom_mobile_special"}</script>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# ## Where are the news links?
#
# 觀察一下網頁內容，你要爬取的連結在哪一個標籤裡面?

# %% [raw]
# <ul id="jsMainList" class="mainList imgModule">

# %%
newpage = page.find('div',{'class':"item_lish"})

# %%
newpage
# Out:
# <div class="item_lish">
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118662">
# <div class="panel-default">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 800w"/>
# </div>
# </a>
# </div>
# <div class="col-md-7">
# <div class="date">2025/04/10</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h3>
# <a href="https://www.sportsv.net/articles/118662">【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰</a>
# </h3>
# <p class="description">就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差一點就能出現，整體展現可圈可點值得驕傲。一路相持不下的兩隊，是激戰到突破僵局的第十三局才分出勝負，紅雀牛棚自找麻煩堆成滿壘，Joey Bart一棒就讓比賽畫下句點，究竟賽況與鄭宗哲表現為何，以下一同回顧。</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118662">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/聖路易紅雀">聖路易紅雀</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/匹茲堡海盜">匹茲堡海盜</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/突破僵局制">突破僵局制</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/大聯盟初登場">大聯盟初登場</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/鄭宗哲">鄭宗哲</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Erick Fedde">Erick Fedde</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Mitch Keller">Mitch Keller</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Tsung-Che Cheng">Tsung-Che Cheng</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/
MLB2025】單場三響砲對決連三場開轟，天使強勢解決守護者打出新風采</a>
# </h3>
# <p class="description">上賽季僅差1敗就得加入百敗俱樂部的天使，今年開季可是有不同展現，除了連續拿下三個系列賽優勢外，面對守護者三戰更是砲火猛烈，帶來勢不可擋的氣焰。首戰雖有José Ramírez三響砲打通關，但Mike Trout與Logan O'Hoppe可沒有坐以待斃，將好手感維持到後續兩場比賽，搭配牛棚投手的出色展現，打出隊史最佳的戰績開局，以下就一同來回顧雙方的精采交鋒。</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118600">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/洛杉磯天使">洛杉磯天使</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/菊池雄星">菊池雄星</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/單場三響砲">單場三響砲</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/克里夫蘭守護者">克里夫蘭守護者</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Mike Trout">Mike Trout</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/José Ramírez">José Ramírez</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Logan O'Hoppe">Logan O'Hoppe</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118610">
# <div class="panel-default">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/ddd014d6-9885-4b7f-a58f-2aa8c9f12f52.jpg 800w"/>
# </div>
# </a>
# </div>
# <div class="col-md-7">
# <div class="date">2025/04/08</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h3>
# <a href="https://www.sportsv.net/articles/118610">五年熬出頭，鄭宗哲成史上第 18 位大聯盟台將</a>
# </h3>
# <p class="description">備受矚目的鄭宗哲於老婆生日當天（臺灣時間４月７日），因海盜陣中金手套內野手Jared Triolo進入傷兵名單，生涯首度升上大聯盟，成為臺灣本季第一位升上大聯盟的球員。</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/slashyouth"><img alt="小聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon2.png" title="小聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/slashyouth">斜槓青年</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118610">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/Mlb">Mlb</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/大聯盟">大聯盟</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/海盜隊">海盜隊</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/鄭宗哲">鄭宗哲</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/旅美台將">旅美台將</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118386">
# <div class="panel-default">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg 800w"/>
# </div>
# </a>
# </div>
# <div class="col-md-7">
# <div class="date">2025/04/07</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h3>
# <a href="https://www.sportsv.net/articles/118386">《站上顛峰的武士》─ 村神的經典一擊！日本武士起死回生挺進冠軍戰</a>
# </h3>
# <p class="description">日本休息室所有人都衝上了場，簇擁著打出經典一擊的村上。「兩隊都打出了精彩表現，兩隊的投球也都出色。沒有哪隊想過要放棄，雖然是日本晉級，但這一晚，是屬於棒球界的勝利！」</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/sportsveditor"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118386">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/棒球">棒球</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/大谷翔平">大谷翔平</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/日職">日職</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/書摘">書摘</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/站上顛峰的武士">站上顛峰的武士</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/畢方出版">畢方出版</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>

# %% [markdown]
# ## news link is in the "li" tag

# %%
# items = page.find('ul',{'id':"myMainList"}).findAll('li') #兩岸新聞改版成myMainList_Style2
items = newpage.findAll('div',{'class':"row item"})
items
# Out:
# [<div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/118662">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/10</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/118662">【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰</a>
#  </h3>
#  <p class="description">就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差一點就能出現，整體展現可圈可點值得驕傲。一路相持不下的兩隊，是激戰到突破僵局的第十三局才分出勝負，紅雀牛棚自找麻煩堆成滿壘，Joey Bart一棒就讓比賽畫下句點，究竟賽況與鄭宗哲表現為何，以下一同回顧。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118662">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/聖路易紅雀">聖路易紅雀</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/匹茲堡海盜">匹茲堡海盜</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/突破僵局制">突破僵局制</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/大聯盟初登場">大聯盟初登場</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/鄭宗哲">鄭宗哲</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Erick Fedde">Erick Fedde</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Mitch Keller">Mitch Keller</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Tsung-Che Cheng">Tsung-Che Cheng</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Joey Bart">Joey Bart</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/118640">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/09</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/118640">【MLB2025】捕手不同卻是一樣的賽揚實力，Tarik Skubal完美出擊助老虎咬傷洋基</a>
#  </h3>
#  <p class="description">近期橫掃白襪取得連勝的老虎，本週是在主場迎接強火軍團洋基來犯，首戰就已出色壓制延續連勝，這日續由賽揚強投達成封鎖並要到5連勝。即便主戰捕手臨時因傷缺陣，但總教練的未雨綢繆是起到效用，接手任務的Dillon Dingler不僅出色執行，打擊更有亮眼發揮，其與Tarik Skubal如何率隊前行，以下一同回顧。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118640">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/底特律老虎">底特律老虎</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/紐約洋基">紐約洋基</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Paul Goldschmidt">Paul Goldschmidt</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Aaron Judge">Aaron Judge</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Tarik Skubal">Tarik Skubal</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Dillon Dingler">Dillon Dingler</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/A.J.Hinch">A.J.Hinch</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/83288">
#  <div class="panel-default">
#  <div class="sponsor right top">BRAND STUDIO</div>
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg 1200w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2021/04/29</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/83288">棒球迷的最佳選擇：最新《MLB九局職棒21》，帶給玩家更愛不釋手的遊戲體驗</a>
#  </h3>
#  <p class="description">MLB九局職棒推出2021年版本，將整個介面大幅改版，讓玩家可以在最舒適的環境中盡情享受遊戲體驗。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/svspy"><img alt="合作夥伴" loading="lazy" src="https://www.sportsv.net/assets/images/level-role-icon2.png" title="合作夥伴"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/svspy">運動特務</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/83288">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/Mlb">Mlb</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/陳金鋒">陳金鋒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/棒球">棒球</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/王建民">王建民</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/職棒">職棒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/九局職棒">九局職棒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/MLB九局職棒21">MLB九局職棒21</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/118618">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/09</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/

#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/Mlb">Mlb</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/大聯盟">大聯盟</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/海盜隊">海盜隊</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/鄭宗哲">鄭宗哲</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/旅美台將">旅美台將</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/118386">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/07</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/118386">《站上顛峰的武士》─ 村神的經典一擊！日本武士起死回生挺進冠軍戰</a>
#  </h3>
#  <p class="description">日本休息室所有人都衝上了場，簇擁著打出經典一擊的村上。「兩隊都打出了精彩表現，兩隊的投球也都出色。沒有哪隊想過要放棄，雖然是日本晉級，但這一晚，是屬於棒球界的勝利！」</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/sportsveditor"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118386">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/棒球">棒球</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/大谷翔平">大谷翔平</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/日職">日職</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/書摘">書摘</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/站上顛峰的武士">站上顛峰的武士</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/畢方出版">畢方出版</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>]

# %% [markdown]
# ## Get title

# %% [raw]
# <li><a href="https://www.cna.com.tw/news/aipl/202103140086.aspx"><div class="wrap"><img alt="防覆艇意外  軍方高雄桃子園海灘建置監控系統" src="https://imgcdn.cna.com.tw/www/WebPhotos/400/20210314/1200x903_71068052983.jpg"/></div><div class="listInfo"><h2><span>防覆艇意外  軍方高雄桃子園海灘建置監控系統</span></h2><div class="date">2021/03/14 14:10</div></div></a></li>

# %%
item = items[0]

# %%
item
# Out:
# <div class="row item">
# <div class="col-md-5">
# <a href="https://www.sportsv.net/articles/118662">
# <div class="panel-default">
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 800w"/>
# </div>
# </a>
# </div>
# <div class="col-md-7">
# <div class="date">2025/04/10</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# <h3>
# <a href="https://www.sportsv.net/articles/118662">【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰</a>
# </h3>
# <p class="description">就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差一點就能出現，整體展現可圈可點值得驕傲。一路相持不下的兩隊，是激戰到突破僵局的第十三局才分出勝負，紅雀牛棚自找麻煩堆成滿壘，Joey Bart一棒就讓比賽畫下句點，究竟賽況與鄭宗哲表現為何，以下一同回顧。</p>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118662">
# <i class="fa fa-comments"></i>0</a>
# </div>
# <div id="tags">
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/聖路易紅雀">聖路易紅雀</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/匹茲堡海盜">匹茲堡海盜</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/突破僵局制">突破僵局制</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/大聯盟初登場">大聯盟初登場</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/鄭宗哲">鄭宗哲</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Erick Fedde">Erick Fedde</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Mitch Keller">Mitch Keller</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Tsung-Che Cheng">Tsung-Che Cheng</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/Joey Bart">Joey Bart</a>
# </li>
# </ul>
# </div>
# </div>
# </div>

# %%
item.find('h3').text.strip()
# Out:
# '【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰'

# %% [markdown]
# ## Get link

# %%
item.find('a').get('href')
# Out:
# 'https://www.sportsv.net/articles/118662'

# %% [markdown]
# ## Get  news time and convert to the format of "2022-04-20"

# %%
from datetime import datetime

# %%
item.find('div', {'class':"date"}).text
# Out:
# '2025/04/10'

# %% [markdown]
# ## Get photo_link
#     <img src=...
#     <img data-scr=...
#
#     <img alt="防覆艇意外  軍方高雄桃子園海灘建置監控系統" src="https://imgcdn.cna.com.tw/www/WebPhotos/400/20210314/1200x903_71068052983.jpg"/>
#
#
#     <img data-src="https://imgcdn.cna.com.tw/www/WebPhotos/400/20210314/1155x768_20210314000038.jpg" class=" lazyloaded" alt="游錫堃：落實開放國會行動方案  方便人民參與" src="https://imgcdn.cna.com.tw/www/WebPhotos/400/20210314/1155x768_20210314000038.jpg">

# %%
item = items[1]

# %%
item.find('img')
# Out:
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg 800w"/>

# %%
# src
#item.find('img').get('src')

# %%
# data-src
item.find('img').get('src')
# Out:
# 'https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg'

# %%
# check if element has_attr('data-src')
item.find('img').has_attr('src')
# Out:
# True

# %%
# Use if else to deal with it
if item.find('img').has_attr('data-src'):
    photo_link = item.find('img').get('data-src')
else:
    photo_link = item.find('img').get('src')

# %%
photo_link
# Out:
# 'https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg'

# %% [markdown]
# ## Error occurs if the news has no photo link
#
# NoneType

# %%
item = items[1]

# %%
item.find('img')
# Out:
# <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg 800w"/>

# %%
type(item.find('img'))
# Out:
# bs4.element.Tag

# %%
# An error arises!
item.find('img').get('src')
# Out:
# 'https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg'

# %%
try:
    photo_link=item.find('img').get('src')
except:
    print('No photo link!')
    photo_link=''

# %%
try:
    # Use if else to deal with it
    if item.find('img').has_attr('data-src'):
        photo_link = item.find('img').get('data-src')
    else:
        photo_link = item.find('img').get('src')
except:
    print('No photo link!')
    photo_link=''

# %%
photo_link
# Out:
# 'https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg'

# %% [markdown]
# # Fail to  get news content Why?

# %%
article_url = items[0].find('a').get('href')

# %%
article_url
# Out:
# 'https://www.sportsv.net/articles/118662'

# %%
# 最新的新聞列表之新聞連結:開頭缺少"https://www.cna.com.tw"
if article_url.startswith("/news"):
    article_url ="https://www.cna.com.tw"+article_url

# %%
article_url = "https://www.sportsv.net/articles/118233"
article_url
# Out:
# 'https://www.sportsv.net/articles/118233'

# %%
# req = requests.get( article_url )
req = requests.get(article_url, headers={ 'user-agent': user_agent.random }, timeout=5)

# page = BeautifulSoup(req.text,'lxml')
page = BeautifulSoup(req.text, 'html.parser')

# %%
page
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant-TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="lXZ68cAF22bJNAHAcQIyydzjwlJKCMzVVkIdrUxz" name="_token">
# <link href="https://www.sportsv.net/assets/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊 - MLB - 棒球 | 運動視界 Sports Vision</title>
# <meta content="2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希" name="description"/>
# <meta content="2025-03-23 08:53:48" property="article:modified_time"/>
# <meta content="2025-03-19 16:00:00" property="article:published_time"/>
# <meta content="棒球" property="article:section"/>
# <link href="https://www.sportsv.net/articles/118233" rel="canonical"/>
# <meta content="MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊 - MLB - 棒球 | 運動視界 Sports Vision" property="og:title"/>
# <meta content="2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希" property="og:description"/>
# <meta content="運動視界 Sports Vision" property="og:site_name"/>
# <meta content="zh_TW" property="og:locale"/>
# <meta content="https://bucket-image.inkmaginecms.com/version/social/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg" property="og:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="運動視界 Sports Vision" name="twitter:site"/>
# <meta content="運動視界 Sports Vision" name="twitter:creator"/>
# <meta content="MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊 - MLB - 棒球 | 運動視界 Sports Vision" name="twitter:title"/>
# <meta content="2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希" name="twitter:description"/>
# <meta content="https://bucket-image.inkmaginecms.com/version/social/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg" name="twitter:image"/>
# <meta content="all" name="robots"/>
# <link as="style" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" rel="preload"><link as="style" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" rel="preload"><link href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" rel="stylesheet"/><link href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" rel="stylesheet"/> <script>
#           window.pbjs = window.pbjs || {que: []};
#                 window.googletag = window.googletag || {cmd: []};
#       </script>
# <script async="" src="https://flux-cdn.com/client/1000265/sportsv_01465.min.js"></script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#     window.fluxtag = {
#       readyBids: {prebid: false, amazon: false, google: false},
#       failSafeTimeout: 3000,
#       isFn: function (object) {
#         var _t = 'Function';
#         var toString = Object.prototype.toString;
#         return toString.call(object) === '[object ' + _t + ']';
#       },
#       launchAdServer: function () {
#         if (!fluxtag.readyBids.prebid || !fluxtag.readyBids.amazon) {
#           return;
#         }
#         fluxtag.requestAdServer();
#       },
#       requestAdServer: function () {
#         if (!fluxtag.readyBids.google) {
#           fluxtag.readyBids.google = true;
#           googletag.cmd.push(function () {
#             if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {
#               pbjs.que.push(function () { pbjs.setTargetingForGPTAsync(); });
#             }
#             googletag.pubads().refresh();
#           });
#         }
#       },
#       renderAds: function (lines, failSafeTimeout) {
#         googletag.cmd.push(function () {
#           var failSafeTimeout = failSafeTimeout || window.fluxtag.failSafeTimeout;
#           var bidRequestTimeout = (failSafeTimeout - 500) > 0 ? failSafeTimeout - 500 : failSafeTimeout;
#           var refreshLines = [];
#           var params = (function () {
#             var readyBids = {amazon: false, google: false, prebid: false};
#             var definedSlots = [];
#             var adsInfo = {
#               gpt: {slots: [], displayDivIds: []},
#               aps: {slots: [], divIds: []},
#               pb: {divIds: []},
#             };
#             var getSizeList = function (width, height, sizeMappings) {
#               const sizeMapping = sizeMappings.filter(function (mappingObject) {
#                 return mappingObject[0][0] <= width && mappingObject[0][1] <= height;
#               }).reduce(function (a, b) {
#                 return (Math.abs(b[0][0] - width) <= Math.abs(a[0][0] - width) && Math.abs(b[0][1] - height) <= Math.abs(a[0][1] - height)) ? b : a;
#               });
#               if (!sizeMapping[1].length) {
#                 sizeMapping[1].push([]);
#               }
#               return sizeMapping[1];
#             };
#             googletag.pubads().getSlots().forEach(function (slot) {
#               definedSlots[slot.getSlotElementId()] = slot;
#             });
#             lines.forEach(function (line) {
#               var divId = line.divId;
#               adsInfo.pb.divIds.push(divId);
#               refreshLines.push({code: line.gpt.unitCode, id: divId});
#               if (definedSlots[divId]) {
#                 adsInfo.gpt.slots.push(definedSlots[divId]);
#               } else {
#                 var slot = googletag.defineSlot(line.gpt.unitCode, line.gpt.sizes, divId).addService(googletag.pubads());
#                 if (line.gpt.sizeMapping && line.gpt.sizeMapping.length > 0) {
#                   var sizeMapping = googletag.sizeMapping();
#                   line.gpt.sizeMapping.forEach(function (size) {
#                     sizeMapping.addSize(size[0], size[1]);
#                   });
#                   slot.defineSizeMapping(sizeMapping.build());
#                 }
#                 if (line.gpt.keyValues && line.gpt.keyValues.length > 0) {
#                   line.gpt.keyValues.forEach(function (param) {
#                     slot.setTargeting(param.key, param.value);
#                   });
#                 }
#                 adsInfo.gpt.slots.push(slot);
#                 adsInfo.gpt.displayDivIds.push(divId);
#               }
#               if (!!line.aps) {
#                 if (line.gpt.sizeMapping && line.gpt.sizeMapping.length > 0) {
#                   line.aps.sizes = getSizeList(window.innerWidth, window.innerHeight, line.gpt.sizeMapping);
#                 }
#                 adsInfo.aps.slots.push({
#                   slotID: divId,
#                   slotName: line.aps.slotName,
#                   sizes: line.aps.sizes,
#                 });
#                 adsInfo.aps.divIds.push(divId);
#               }
#             });
#             if (adsInfo.aps.slots.length === 0) {
#               readyBids.amazon = true;
#             }
#             var adServerSend = function () {
#               if (!readyBids.amazon || !readyBids.prebid) {
#                 return;
#               }
#               if (!readyBids.google) {
#                 readyBids.google = true;
#                 adsInfo.gpt.displayDivIds.forEach(function (divId) {
#                   googletag.display(divId);
#                 });
#                 if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {
#                   pbjs.que.push(function () {
#                     pbjs.setTargetingForGPTAsync(adsInfo.pb.divIds);
#                   });
#                 }
#                 if (adsInfo.aps.slots.length > 0 && !!(window.apstag) && fluxtag.isFn(window.apstag.fetchBids)) {
#                   window.apstag.setDisplayBids(adsInfo.aps.divIds);
#                 }
#                 googletag.pubads().refresh(adsInfo.gpt.slots);
#               }
#             };
#             var apsCallback = function () {
#               readyBids.amazon = true;
#               adServerSend();
#             };
#             var pbCallback = function () {
#               readyBids.prebid = true;
#               adServerSend();
#             };
#             setTimeout(function () {
#               readyBids.amazon = true;
#               readyBids.prebid = true;
#               adServerSend();
#             }, failSafeTimeout);
#             return {aps: {slots: adsInfo.aps.slots, callback: apsCallback}, prebid: {callback: pbCallback}};
#           })();
#           if (!!(window.pbFlux) && window.pbFlux.refresh && fluxtag.isFn(window.pbFlux.refresh)) {
#             pbjs.que.push(function () {
#               window.pbFlux.refresh({
#                 lines: refreshLines,
#                 callback: params.prebid.callback,
#                 timeout: bidRequestTimeout,
#               });
#             });
#           } else {
#             params.prebid.callback();
#           }
#           if (params.aps.slots.length > 0 && !!(window.apstag) && fluxtag.isFn(window.apstag.fetchBids)) {
#             window.apstag.fetchBids({
#               slots: params.aps.slots,
#               timeout: bidRequestTimeout,
#             }, function (bids) { params.aps.callback(); });
#           } else {
#             params.aps.callback();
#           }
#         });
#       },
#     };
#   </script>
# <script>
#     googletag.cmd.push(function () {
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().collapseEmptyDivs();
#                         googletag.enableServices();
#     });
#   </script>
# <script>
#     window.tmgad = {
#       serial: 0,
#       loaded: false,
#       scan: function () {
#         googletag.cmd.push(function () {
#           let list = document.querySelectorAll('.tmgad-new');
#           for (let i = 0; i < list.length; i++) {
#             tmgad.build(list[i]);
#           }
#         });
#         if (!tmgad.loaded) {
#           document.addEventListener('DOMContentLoaded', function () {
#             tmgad.scan();
#           });
#           tmgad.loaded = true;
#         }
#       },
#       build: function (target) {
#         if (!target.classList.contains('tmgad-new')) {
#           console.log('TMGAD build: Pass ' + target.getAttribute('class'));
#           return;
#         }
#         try { target.classList.remove('tmgad-new'); } catch (e) {}
#         let attributes = {id: '', name: '', slot: '', type: 'general', size: [], mapping: [], targeting: {}};
#         try {
#           attributes = Object.assign(attributes, JSON.parse(target.querySelector('script').textContent.trim()));
#           tmgad.serial++;
#           attributes.id = 'tmgad-' + attributes.name + '-' + tmgad.serial;
#           target.setAttribute('id', attributes.id);
#           switch (attributes.type) {
#             case 'flux':
#               let flux = {
#                 divId: attributes.id,
#                 gpt: {
#                   unitCode: attributes.slot,
#                   sizes: attributes.size,
#                   sizeMapping: attributes.mapping,
#                   keyValues: [],
#                 },
#               };
#               for (let targeting in attributes.targeting) {
#                 if (!attributes.targeting[targeting].length) {
#                   continue;
#                 }
#                 flux.gpt.keyValues.push({key: targeting, value: attributes.targeting[targeting]});
#               }
#               window.fluxtag.renderAds([flux]);
#               return;
#           }
#           let mapping = googletag.sizeMapping();
#           for (let i = 0; i < attributes.mapping.length; i++) {
#             if (!attributes.mapping[i][1].length) {
#               continue;
#             }
#             mapping = mapping.addSize(attributes.mapping[i][0], attributes.mapping[i][1]);
#           }
#           let service = googletag.pubads();
#           for (let targeting in attributes.targeting) {
#             if (!attributes.targeting[targeting].length) {
#               continue;
#             }
#             service.setTargeting(targeting, attributes.targeting[targeting]);
#           }
#           googletag.cmd.push(function () {
#             let slot;
#             switch (attributes.type) {
#               case 'oop':
#                 slot = googletag.defineOutOfPageSlot(attributes.slot, attributes.id)
#                   .addService(service);
#                 break;
#               default:
#                 slot = googletag.defineSlot(attributes.slot, attributes.size, attributes.id)
#                   .defineSizeMapping(mapping.build()).addService(service);
#                 break;
#             }
#             googletag.display(attributes.id);
#             googletag.pubads().refresh([slot]);
#           });
#         } catch (e) {
#           console.warn('TMGAD build: [' + attributes.id + ']' + e.message);
#           return false;
#         }
#       },
#     };
#   </script>
# <script id="sportsv_info" type="application/json">{"article_id":118233,"article_url":"https:\/\/www.sportsv.net\/articles\/118233","article_title":"MLB\u6771\u4eac\u8cfd\u300b\u829d\u52a0\u54e5\u5c0f\u718avs\u6d1b\u6749\u78ef\u9053\u5947 \u6587\u5b57\u76f4\u64ad\uff1a\u5927\u8c37\u7fd4\u5e73\u672c\u5b63\u9996\u8f5f\u5728\u5167\u55ae\u5834\u4e09\u8f5f\uff0c\u9053\u5947\u968a\u5169\u6230\u6a6b\u6383\u5c0f\u718a\u968a - MLB - \u68d2\u7403 | \u904b\u52d5\u8996\u754c Sports Vision","article_author_id":61,"datalayer_sets":{"analyticsAuthors":[{"key":"sportsveditor","name":"\u904b\u52d5\u8996\u754c\u7de8\u8f2f"}],"analyticsTerms":[{"type":"category","key":"mlb","name":"MLB"},{"type":"category","key":"baseball","name":"\u68d2\u7403"},{"type":"tag","key":162,"name":"\u6d1b\u6749\u78ef\u9053\u5947"},{"type":"tag","key":220,"name":"\u5927\u8c37\u7fd4\u5e73"},{"type":"tag","key":1862,"name":"\u829d\u52a0\u54e5\u5c0f\u718a"},{"type":"tag","key":19656,"name":"\u9234\u6728\u8aa0\u4e5f"},{"type":"tag","key":32474,"name":"\u4f50\u4f50\u6728\u6717\u5e0c"}]},"is_drinking_warning":0,"is_infinite":1,"is_ad":1}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-XYPFETDX47&amp;l=ga4DataLayer"></script>
# <script>
#     window.ga4DataLayer = window.ga4DataLayer || [];
#     function ga4_tag(){ga4DataLayer.push(arguments);}
#     ga4_tag('js', new Date());
#     ga4_tag('config', 'G-XYPFETDX47');
#     (function () {
#         try {
#             window.Sportsv = window.Sportsv || {};
#             if (!window.Sportsv.sourceMaterial) {
#                 window.Sportsv.sourceMaterial = {};
#                 window.Sportsv.sourceMaterial = JSON.parse(document.getElementById('sportsv_info').textContent)
#             }
#             let source = window.Sportsv?.sourceMaterial
#             source.datalayer_sets.analyticsAuthors.forEach(function (value){
#                 ga4_tag('event', 'Counter-Author', {
#                     'action': 'trigger',
#                     'label': value.name
#                 })
#             })
#             source.datalayer_sets.analyticsTerms.forEach(function (value){
#                 ga4_tag('event', 'Counter-Term', {
#                     'action': 'trigger',
#                     'label': value.name
#                 })
#             })
#         } catch (e) {}
#     })();
# </script>
# <script>
#     window.BrandGtmDataLayer = window.BrandGtmDataLayer || [];
#     window.DaexGtmDataLayer = window.DaexGtmDataLayer || [];
#     window.TNLMGTagDataLayer = window.TNLMGTagDataLayer || [];
#     DaexGtmDataLayer.push({'ID' : 'D-100007'});
#     TNLMGTagDataLayer.push({
#         event: 'config',
#         config_id: 'a2fdd15c62e51c434bff7452b5025520e5deca2c45a198aa2da0b04aef7b4a7f',
#     });
#     let memberId = localStorage.getItem('member_id');
#     if (memberId) {
#         TNLMGTagDataLayer.push({
#             event: 'set_member_id',
#             member_id: memberId,
#         });
#     }
#     (function () {
#         try {
#             let source = window.Sportsv?.sourceMaterial
#
#             BrandGtmDataLayer.push(source.datalayer_sets);
#             DaexGtmDataLayer.push(source.datalayer_sets);
#
#
#             //BrandGtmDataLayer.push({'event': 'UserLoaded'})
#             //DaexGtmDataLayer.push({'event': 'UserLoaded'})
#
#             TNLMGTagDataLayer.push({event: 'pageview'});
#
#                         try {
#                 let source = window.Sportsv?.sourceMaterial
#                 let articleId = source?.article_id ? String(source?.article_id) : undefined;
#
#                 articleId && TNLMGTagDataLayer.push({event: 'view_article', view_article_payload: {article_id: articleId}});
#             } catch (e) { console.log(e); }
#                     } catch (e) {}
#     })();
#
#     // BRAND
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','BrandGtmDataLayer','GTM-TX847V4');
#
#     // DAEX
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','DaexGtmDataLayer','GTM-5THSZR9');
#
#     /* TNLMGTag */
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','TNLMGTagDataLayer','GTM-5HR8SM3V');
#
#     /* Inkmagine */
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','inkmagineDataLayer','GTM-MGHRKMRV');
# </script>
# <!-- Begin Comscore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({c1: "2", c2: "17728543", options: {enableFirstPartyCookie: true, bypassUserConsentRequirementFor1PCookie: true}});
#     (function () {
#         var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#         s.async = true; s.src = "https://sb.scorecardresearch.com/cs/17728543/beacon.js";
#         el.parentNode.insertBefore(s, el);
#     })();
# </script>
# <!--End Comscore Tag-->
# <script type="text/javascript">
#     (function() {
#         let sections = [];
#         let authors = [];
#         try {
#             let source = window.Sportsv?.sourceMaterial;
#             source.datalayer_sets.analyticsAuthors.forEach(function (value){
#                 authors.push(value.name);
#             });
#             source.datalayer_sets.analyticsTerms.forEach(function (value){
#                 if (value.type == 'category') {
#                     sections.push(value.name);
#                 }
#             });
#         }catch(e) {}
#         /** CONFIGURATION START **/
#         var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
#         _sf_async_config.uid = 61305;
#         _sf_async_config.domain = 'sportsv.net'; //CHANGE THIS TO THE ROOT DOMAIN
#         _sf_async_config.flickerControl = false;
#         _sf_async_config.useCanonical = true;
#         _sf_async_config.useCanonicalDomain = true;
#         _sf_async_config.sections = sections.join(','); // CHANGE THIS TO YOUR SECTION NAME(s)
#         _sf_async_config.authors = authors.join(','); // CHANGE THIS TO YOUR AUTHOR NAME(s)
#         /** CONFIGURATION END **/
#         function loadChartbeat() {
#             var e = document.createElement('script');
#             var n = document.getElementsByTagName('script')[0];
#             e.type = 'text/javascript';
#             e.async = true;
#             e.src = '//static.chartbeat.com/js/chartbeat.js';;
#             n.parentNode.insertBefore(e, n);
#         }
#         loadChartbeat();
#     })();
# </script>
# <script async="" src="//static.chartbeat.com/js/chartbeat_mab.js"></script>
# <script>
#     !function(f,b,e,v,n,t,s)
#         {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                         n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#                 if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#                 n.queue=[];t=b.createElement(e);t.async=!0;
#                 t.src=v;s=b.getElementsByTagName(e)[0];
#                 s.parentNode.insertBefore(t,s)}(window, document,'script',
#                                 'https://connect.facebook.net/zh_TW/fbevents.js');
#     fbq('init', '2210311835696207');
#     fbq('track', 'PageView');
# </script>
# <script>
#     fbq('track', 'ViewContent');
# </script>
# <script defer="" src="https://resource.tnlmediagene.com/assets/v1/js/tnlmedia-header-footer.js"></script>
# <script async="" src="https://www.sportsv.net/assets/assets/head-D73q8ojf.js" type="module"></script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebSite","url":"https:\/\/www.sportsv.net","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.sportsv.net\/search?q={search_term_string}","query-input":"required name=search_term_string"},"publisher":{"@type":"Organization","name":"運動視界Sports Vision","logo":"https:\/\/www.sportsv.net\/assets\/images\/logo.png"}}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebPage","name":"MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊","description":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希","keywords":["洛杉磯道奇","大谷翔平","芝加哥小熊","鈴木誠也","佐佐木朗希"],"dateCreated":"2025-03-19T15:19:15+08:00","dateModified":"2025-03-23T08:53:48+08:00","datePublished":"2025-03-19T16:00:00+08:00","primaryImageOfPage":{"@type":"ImageObject","contentUrl":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/03\/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg"},"commentCount":0}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"運動視界Sports Vision","item":"https:\/\/www.sportsv.net"},{"@type":"ListItem","position":2,"name":"棒球","item":"https:\/\/www.sportsv.net\/baseball"},{"@type":"ListItem","position":3,"name":"MLB","item":"https:\/\/www.sportsv.net\/baseball\/mlb"},{"@type":"ListItem","position":4,"name":"MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊","item":"https:\/\/www.sportsv.net\/articles\/118233"}]}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","url":"https:\/\/www.sportsv.net\/articles\/118233","description":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希","thumbnailUrl":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/03\/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg","keywords":["洛杉磯道奇","大谷翔平","芝加哥小熊","鈴木誠也","佐佐木朗希"],"dateCreated":"2025-03-19T15:19:15+08:00","dateModified":"2025-03-23T08:53:48+08:00","datePublished":"2025-03-19T16:00:00+08:00","articleBody":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。繼 2000 年後再度來到東京巨蛋舉行海外開幕戰的小熊隊，在主要陣容沒有太多變動的情況下，休賽季引進了將於季後投入自由市場的明星外野手 Kyle Tucker，搭配聯盟前段的先發投手群以及守備，在總教練 Craig Counsell 第二年的領軍下能否暌違五年之後再度於完整賽季重返季後賽將備受關注。2024 年世界大賽冠軍道奇隊並未因順利登頂而在這個休賽季停下補強的腳步，不惜持續推高團隊薪資以及被冠上新生代「邪惡帝國」的標籤，也要引進 Blake Snell、Tanner Scott 和佐佐木朗希等堅實的戰力，都宣示了他們成為 21 世紀第一支成功衛冕冠軍隊伍的企圖心。究竟大聯盟會不會睽違 25 年再度出現連續兩年登頂成功的隊伍？絕對是新賽季的一大看點。與山本由伸聯手貢獻關鍵戰力 大谷翔平坦言難得感到緊張把握對手換投機會，道奇逆轉收下賽季首勝山本由伸徜徉首次日籍投手開幕對決，大谷翔平雙安領軍道奇笑納勝利《2025 MLB 開季分析》洛杉磯道奇—壓力山大的超級戰艦《2025 MLB 開季分析》芝加哥小熊—Hoyer的烏紗帽保衛戰道奇隊先發打線小熊隊先發打線1.大谷翔平, DH2.Tommy Edman, 2B3.Teoscar Hernández, RF4.Will Smith, C5.Max Muncy, 3B6.Kiké Hernández, 1B7.Michael Conforto, LF8.Miguel Rojas, SS9.Andy Pages, CF1.Ian Happ, LF2.鈴木誠也, DH3.Kyle Tucker, RF4.Michael Busch, 1B5.Matt Shaw, 3B6.Dansby Swanson, SS7.Pete Crow-Armstrong, CF8.Carson Kelly, C9.Jon Berti, 2B先發投手：佐佐木朗希（10勝5敗, 111 局、防禦率 2.35）先發投手：Justin Steele（5勝5敗, 134⅔ 局、防禦率 2.91）&nbsp;&nbsp;1局2局3局4局5局6局7局8局9局得分安打失誤道奇隊（1-0）021210000670小熊隊（0-1）０01110000380&nbsp;【九局下】道奇隊更換投手：Alex Vesia第一棒 Ian Happ：本壘後方飛球接殺出局，一出局第二棒 鈴木誠也：三振出局，兩出局第三棒 Kyle Tucker左外野方向二壘安打，兩出局二壘有人Justin Turner 代打 Michael Busch第四棒 Justin Turner：四壞球保送第五棒 Matt Shaw：游擊方向滾地球刺殺出局，三人出局&nbsp;【九局上】小熊隊更換投手：Ryan Pressly第七棒 Michael Conforto：二壘方向滾地球刺殺出局，一出局第八棒 Miguel Rojas：四壞球保送，一出局一壘有人第九棒 Andy Pages：四壞球保送，一出局一、二壘有人第一棒 大谷翔平：四壞球保送，一出局滿壘第二棒 Tommy Edman：二壘方向滾地球形成雙殺，三人出局&nbsp;【八局下】道奇隊更換投手：Kirby Yates第六棒 Dansby Swanson：三振出局，一出局第七棒 Pete Crow-Armstrong：三振出局，兩出局第八棒 Carson Kelly：左外野方向平飛安打，兩出局一壘有人第九棒 Jon Berti：二壘後方飛球接殺出局，三人出局&nbsp;【八局上】小熊隊更換投手：Porter Hodge&nbsp;第三棒 Teoscar Hernández：三壘方向滾地球刺殺出局，一出局第四棒 Will Smith：四壞球保送，一出局一壘有人第五棒 Max Muncy：二壘方向滾地球傳向一壘刺殺出局，跑者上到二壘，兩出局二壘有人第六棒 Kiké Hernández：三振出局&nbsp;【七局下】道奇隊投手：Landon Knack第三棒 Kyle Tucker：一壘上空高飛球接殺出局，一出局第四棒 Michael Busch：三振出局，兩出局第五棒 Matt Shaw：三振出局，三人出局&nbsp;【七局上】小熊隊更換投手：Julian Merryweather第七棒 Michael Conforto：四壞球保送，一壘有人第八棒 Miguel Rojas：二壘方向滾地球形成雙殺，兩出局第九棒 Andy Pages：右外野方向二壘安打，兩出局二壘有人第一棒 大谷翔平：故意四壞保送，兩出局二、三壘有人第二棒 Tommy Edman：三壘方向強勁滾地球，三壘手飛撲攔下傳向一壘刺殺出局，三人出局&nbsp;【六局下】道奇隊更換投手：Landon Knack第八棒 Carson Kelly：游擊方向滾地球刺殺出局，一出局第九棒 Jon Berti：中線穿越安打，一出局一壘有人第一棒 Ian Happ：三振出局，兩出局一壘有人第二棒 鈴木誠也：三壘方向滾地球傳向二壘封殺出局，三人出局&nbsp;【六局上】小熊隊更換投手：Caleb Thielbar第四棒 Will Smith：三壘方向滾地球刺殺出局，一出局第五棒 Max Muncy：三振出局，兩出局第六棒 Kiké Hernández：本壘後方高飛球接殺出局，三人出局&nbsp;【五局下】道奇隊更換投手：Jack Dreyer（生涯初登板）第三棒 Kyle Tucker：中外野深遠飛球接殺出局，一出局第四棒 Michael Busch：三振出局，兩出局第五棒 Matt Shaw：投手前滾地球未能處裡乾淨形成內野安打，兩出局一壘有人（生涯首安）第六棒 Dansby Swanson：左外野平飛三壘安打，一壘跑者回來得分，小熊隊追至 6：3，兩出局三壘有人第七棒 Pete Crow-Armstrong：右外野方向飛球接殺出局，三人出局【五局上】小熊隊更換投手：Nate Pearson第九棒 Andy Pages：三振出局，一出局第一棒 大谷翔平：陽春全壘打，道奇擴大領先 6：2第二棒 Tommy Edman：三振出局，兩出局第三棒 Teoscar Hernández：左外野方向飛球接殺出局，三人出局&nbsp;【四局下】道奇隊更換投手：Luis García第六棒 Dansby Swanson：三振出局，一出局第七棒 Pete Crow-Armstrong：三振出局，兩出局第八棒 Carson Kelly：四壞球，兩出局一壘有人第九棒 Jon Berti：中外野平飛安打，兩出局一、二壘有人第一棒 Ian Happ：左外野方向落地安打，二壘跑者回來得分，小熊隊追成 5：2，兩出局一、二壘有人第二棒 鈴木誠也：三振出局，三人出局&nbsp;【四局上】小熊隊先發投手：Justin Steele第四棒 Will Smith：二壘安打，二壘有人第五棒 Max Muncy：游擊手後方飛球，一出局一壘有人第六棒 Kiké Hernández：兩分全壘打，道奇擴大領先 5：1第七棒 Michael Conforto：三振出局，兩出局第八棒 Miguel Rojas：三振出局，三人出局&nbsp;【三局下】道奇隊先發投手：佐佐木朗希第八棒 Carson Kelly：一壘方向滾地球一壘手自踩壘包，一出局第九棒 Jon Berti：三壘方向滾地球形成內野安打，一出局一壘有人Berti 盜壘成功，一出局二壘有人第一棒 Ian Happ：四壞球保送，一出局一、二壘有人第二棒 鈴木誠也：四壞球保送，一出局滿壘第三棒 Kyle Tucker：四壞球保送，三壘跑者回來得分，小熊追回 ...
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"NewsArticle","url":"https:\/\/www.sportsv.net\/articles\/118233","description":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希","thumbnailUrl":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/03\/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg","keywords":["洛杉磯道奇","大谷翔平","芝加哥小熊","鈴木誠也","佐佐木朗希"],"dateCreated":"2025-03-19T15:19:15+08:00","dateModified":"2025-03-23T08:53:48+08:00","datePublished":"2025-03-19T16:00:00+08:00","articleBody":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。繼 2000 年後再度來到東京巨蛋舉行海外開幕戰的小熊隊，在主要陣容沒有太多變動的情況下，休賽季引進了將於季後投入自由市場的明星外野手 Kyle Tucker，搭配聯盟前段的先發投手群以及守備，在總教練 Craig Counsell 第二年的領軍下能否暌違五年之後再度於完整賽季重返季後賽將備受關注。2024 年世界大賽冠軍道奇隊並未因順利登頂而在這個休賽季停下補強的腳步，不惜持續推高團隊薪資以及被冠上新生代「邪惡帝國」的標籤，也要引進 Blake Snell、Tanner Scott 和佐佐木朗希等堅實的戰力，都宣示了他們成為 21 世紀第一支成功衛冕冠軍隊伍的企圖心。究竟大聯盟會不會睽違 25 年再度出現連續兩年登頂成功的隊伍？絕對是新賽季的一大看點。與山本由伸聯手貢獻關鍵戰力 大谷翔平坦言難得感到緊張把握對手換投機會，道奇逆轉收下賽季首勝山本由伸徜徉首次日籍投手開幕對決，大谷翔平雙安領軍道奇笑納勝利《2025 MLB 開季分析》洛杉磯道奇—壓力山大的超級戰艦《2025 MLB 開季分析》芝加哥小熊—Hoyer的烏紗帽保衛戰道奇隊先發打線小熊隊先發打線1.大谷翔平, DH2.Tommy Edman, 2B3.Teoscar Hernández, RF4.Will Smith, C5.Max Muncy, 3B6.Kiké Hernández, 1B7.Michael Conforto, LF8.Miguel Rojas, SS9.Andy Pages, CF1.Ian Happ, LF2.鈴木誠也, DH3.Kyle Tucker, RF4.Michael Busch, 1B5.Matt Shaw, 3B6.Dansby Swanson, SS7.Pete Crow-Armstrong, CF8.Carson Kelly, C9.Jon Berti, 2B先發投手：佐佐木朗希（10勝5敗, 111 局、防禦率 2.35）先發投手：Justin Steele（5勝5敗, 134⅔ 局、防禦率 2.91）&nbsp;&nbsp;1局2局3局4局5局6局7局8局9局得分安打失誤道奇隊（1-0）021210000670小熊隊（0-1）０01110000380&nbsp;【九局下】道奇隊更換投手：Alex Vesia第一棒 Ian Happ：本壘後方飛球接殺出局，一出局第二棒 鈴木誠也：三振出局，兩出局第三棒 Kyle Tucker左外野方向二壘安打，兩出局二壘有人Justin Turner 代打 Michael Busch第四棒 Justin Turner：四壞球保送第五棒 Matt Shaw：游擊方向滾地球刺殺出局，三人出局&nbsp;【九局上】小熊隊更換投手：Ryan Pressly第七棒 Michael Conforto：二壘方向滾地球刺殺出局，一出局第八棒 Miguel Rojas：四壞球保送，一出局一壘有人第九棒 Andy Pages：四壞球保送，一出局一、二壘有人第一棒 大谷翔平：四壞球保送，一出局滿壘第二棒 Tommy Edman：二壘方向滾地球形成雙殺，三人出局&nbsp;【八局下】道奇隊更換投手：Kirby Yates第六棒 Dansby Swanson：三振出局，一出局第七棒 Pete Crow-Armstrong：三振出局，兩出局第八棒 Carson Kelly：左外野方向平飛安打，兩出局一壘有人第九棒 Jon Berti：二壘後方飛球接殺出局，三人出局&nbsp;【八局上】小熊隊更換投手：Porter Hodge&nbsp;第三棒 Teoscar Hernández：三壘方向滾地球刺殺出局，一出局第四棒 Will Smith：四壞球保送，一出局一壘有人第五棒 Max Muncy：二壘方向滾地球傳向一壘刺殺出局，跑者上到二壘，兩出局二壘有人第六棒 Kiké Hernández：三振出局&nbsp;【七局下】道奇隊投手：Landon Knack第三棒 Kyle Tucker：一壘上空高飛球接殺出局，一出局第四棒 Michael Busch：三振出局，兩出局第五棒 Matt Shaw：三振出局，三人出局&nbsp;【七局上】小熊隊更換投手：Julian Merryweather第七棒 Michael Conforto：四壞球保送，一壘有人第八棒 Miguel Rojas：二壘方向滾地球形成雙殺，兩出局第九棒 Andy Pages：右外野方向二壘安打，兩出局二壘有人第一棒 大谷翔平：故意四壞保送，兩出局二、三壘有人第二棒 Tommy Edman：三壘方向強勁滾地球，三壘手飛撲攔下傳向一壘刺殺出局，三人出局&nbsp;【六局下】道奇隊更換投手：Landon Knack第八棒 Carson Kelly：游擊方向滾地球刺殺出局，一出局第九棒 Jon Berti：中線穿越安打，一出局一壘有人第一棒 Ian Happ：三振出局，兩出局一壘有人第二棒 鈴木誠也：三壘方向滾地球傳向二壘封殺出局，三人出局&nbsp;【六局上】小熊隊更換投手：Caleb Thielbar第四棒 Will Smith：三壘方向滾地球刺殺出局，一出局第五棒 Max Muncy：三振出局，兩出局第六棒 Kiké Hernández：本壘後方高飛球接殺出局，三人出局&nbsp;【五局下】道奇隊更換投手：Jack Dreyer（生涯初登板）第三棒 Kyle Tucker：中外野深遠飛球接殺出局，一出局第四棒 Michael Busch：三振出局，兩出局第五棒 Matt Shaw：投手前滾地球未能處裡乾淨形成內野安打，兩出局一壘有人（生涯首安）第六棒 Dansby Swanson：左外野平飛三壘安打，一壘跑者回來得分，小熊隊追至 6：3，兩出局三壘有人第七棒 Pete Crow-Armstrong：右外野方向飛球接殺出局，三人出局【五局上】小熊隊更換投手：Nate Pearson第九棒 Andy Pages：三振出局，一出局第一棒 大谷翔平：陽春全壘打，道奇擴大領先 6：2第二棒 Tommy Edman：三振出局，兩出局第三棒 Teoscar Hernández：左外野方向飛球接殺出局，三人出局&nbsp;【四局下】道奇隊更換投手：Luis García第六棒 Dansby Swanson：三振出局，一出局第七棒 Pete Crow-Armstrong：三振出局，兩出局第八棒 Carson Kelly：四壞球，兩出局一壘有人第九棒 Jon Berti：中外野平飛安打，兩出局一、二壘有人第一棒 Ian Happ：左外野方向落地安打，二壘跑者回來得分，小熊隊追成 5：2，兩出局一、二壘有人第二棒 鈴木誠也：三振出局，三人出局&nbsp;【四局上】小熊隊先發投手：Justin Steele第四棒 Will Smith：二壘安打，二壘有人第五棒 Max Muncy：游擊手後方飛球，一出局一壘有人第六棒 Kiké Hernández：兩分全壘打，道奇擴大領先 5：1第七棒 Michael Conforto：三振出局，兩出局第八棒 Miguel Rojas：三振出局，三人出局&nbsp;【三局下】道奇隊先發投手：佐佐木朗希第八棒 Carson Kelly：一壘方向滾地球一壘手自踩壘包，一出局第九棒 Jon Berti：三壘方向滾地球形成內野安打，一出局一壘有人Berti 盜壘成功，一出局二壘有人第一棒 Ian Happ：四壞球保送，一出局一、二壘有人第二棒 鈴木誠也：四壞球保送，一出局滿壘第三棒 Kyle Tucker：四壞球保送，三壘跑者回來得分， ...
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Person","name":"運動視界編輯"}</script>
# <script type="application/ld+json">{"@type":"ItemList","@context":"https:\/\/schema.org","itemListElement":[{"url":"https:\/\/www.youtube.com\/watch?v=HQOR6Ng4eQI","name":"Dodgers vs. Cubs Tokyo Series Game Highlights (3\/18\/25) | MLB Highlights","@type":"VideoObject","embedUrl":"https:\/\/www.youtube.com\/watch?v=HQOR6Ng4eQI","position":1,"uploadDate":"2025-03-18T07:55:38-07:00","description":"Dodgers vs. Cubs full Tokyo Series game highlights from 3\/18\/25Don't forget to subscribe! https:\/\/www.youtube.com\/mlbFollow us elsewhere too:Twitter: https:\/...","thumbnailUrl":"https:\/\/i.ytimg.com\/vi\/HQOR6Ng4eQI\/hqdefault.jpg"},{"url":"https:\/\/streamable.com\/m\/roki-sasaki-set-for-highly-anticipated-debut?partnerId=web_multimedia-search_video-share","name":"Roki Sasaki set for highly-anticipated debut","@type":"VideoObject","embedUrl":"https:\/\/streamable.com\/m\/roki-sasaki-set-for-highly-anticipated-debut?partnerId=web_multimedia-search_video-share","position":2,"uploadDate":"2025-03-20T15:07:18+08:00","description":"Watch this embedded Streamable video."},{"url":"https:\/\/streamable.com\/m\/shohei-ohtani-homers-1-on-a-fly-ball-to-right-center-field-hbrxsl?partnerId=web_multimedia-search_video-share","name":"Shohei Ohtani's first homer of 2025","@type":"VideoObject","embedUrl":"https:\/\/streamable.com\/m\/shohei-ohtani-homers-1-on-a-fly-ball-to-right-center-field-hbrxsl?partnerId=web_multimedia-search_video-share","position":3,"uploadDate":"2025-03-20T15:07:18+08:00","description":"Watch this embedded Streamable video."},{"url":"https:\/\/streamable.com\/m\/enrique-hernandez-homers-1-on-a-fly-ball-to-left-field-will-smith-scores?partnerId=web_multimedia-search_video-share","name":"Enrique Hern\u00e1ndez's two-run homer (1)","@type":"VideoObject","embedUrl":"https:\/\/streamable.com\/m\/enrique-hernandez-homers-1-on-a-fly-ball-to-left-field-will-smith-scores?partnerId=web_multimedia-search_video-share","position":4,"uploadDate":"2025-03-20T15:07:19+08:00","description":"Watch this embedded Streamable video."},{"url":"https:\/\/streamable.com\/m\/sasaki-gets-back-to-back-strikeouts-to-limit-damage?partnerId=web_multimedia-search_video-share","name":"Sasaki gets back-to-back strikeouts to limit damage","@type":"VideoObject","embedUrl":"https:\/\/streamable.com\/m\/sasaki-gets-back-to-back-strikeouts-to-limit-damage?partnerId=web_multimedia-search_video-share","position":5,"uploadDate":"2025-03-20T15:07:20+08:00","description":"Watch this embedded Streamable video."}]}</script>
# <link href="https://www.sportsv.net/articles/118233?page=2" rel="next"/>
# </link></link></meta></head>
# <body>
# <div class="gototop js-top">
# <a class="js-gotop" href="#">
# <i class="fa fa-fw fa-arrow-up"></i>
# </a>
# </div>
# <a class="header_translation_block-mobile toggleLan_tw_cn" href="#">
# <span class="lanText-tw active">繁</span><span class="lanText-cn">簡</span>
# </a>
# <!-- Navigation -->
# <nav class="navbar navbar-inverse" role="navigation">
# <tnlmedia-header lang="zh-tw"></tnlmedia-header>
# <div class="brand">
# <div class="container relative">
# <div class="row">
# <!-- 會員通知 -->
# <div class="popo notice bottom">
# <div class="arrow"></div>
# <h3 class="popover-title">重要通知</h3>
# <div class="popover-content">
# <div class="notice_infon" id="notice_infon">
# </div>
# </div>
# </div>
# <!-- 會員管理 -->
# <div class="popo member bottom">
# <div class="arrow"></div>
# <div class="popover-content">
# <div class="item">
# <p class="username"></p>
# <div class="menber-menu">
# <div class="menber-menu__item">
# <h4 class="menber-menu__title">會員服務</h4>
# <ul>
# <li><a href="/member/newsletter"><i class="fas fa-envelope"></i>電子報</a></li>
# <li><a href="/member/comment"><i class="fas fa-comment-dots"></i>個人留言</a></li>
# <li><a href="/member/saved-articles"><i class="fas fa-bookmark"></i>好文收藏</a></li>
# <li><a href="/member/saved-author"><i class="fas fa-heart"></i>訂閱作者</a></li>
# </ul>
# </div>
# <div class="menber-menu__item">
# <h4 class="menber-menu__title">帳號管理</h4>
# <ul>
# <li><a href="https://member.tnlmedia.com/profile" target="_blank"><i class="fas fa-user-circle"></i>個人資料</a></li>
# <li>
# <a href="https://member.tnlmedia.com/subscription" target="_blank"><i class="fa-solid fa-circle-dollar"></i>管理付費訂閱
#                             </a>
# </li>
# <li id="cabinet_btn" style="display:none">
# <a href="https://cabinet.tnlmedia.com" target="_blank"><i class="fa-solid fa-bookmark"></i>文章管理
#                             </a>
# </li>
# <li id="admin_btn" style="display:none">
# <a href="/admin/member/articles"><i class="fa-solid fa-circle-dollar"></i>稿費數據
#                             </a>
# </li>
# </ul>
# </div>
# </div>
# <a class="logout" href="/logout">登出</a>
# </div>
# </div>
# </div>
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <a class="navbar-brand" href="/"><img alt="運動視界" height="100%" src="https://www.sportsv.net/assets/images/logo.svg" title="運動視界" width="100%"/></a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="navbar-collapse" id="Brand-navbar-collapse">
# <ul class="nav navbar-nav navbar-right">
# <li>
# <a class="header_translation_block toggleLan_tw_cn" href="#">
# <span class="lanText-tw active">繁</span> / <span class="lanText-cn">簡</span>
# </a>
# </li>
# <li>
# <a href="https://www.thenewslens.com/subscription">無廣告服務</a>
# </li>
# <li>
# <a class="joinauthors" href="/joinauthors" target="_blank">成為作者</a>
# </li>
# <li id="nav-unlogingin">
# <a href="/login">
# <span>登入</span> / <span>註冊</span>
# </a>
# </li>
# <li id="nav-notice" style="display:none">
# <a class="notice" id="noticeBtn">
# <i class="fas fa-bell" id="notice-icon"></i>
# </a>
# </li>
# <li id="nav-logingin" style="display:none">
# <a class="member" id="memberBtn">
# <span class="nickname" id="memberNickname">N</span>
# </a>
# </li>
# <li>
# <div class="search_form" method="get" role="search">
# <input class="js-search_input search_input" id="search_input" name="q" placeholder="搜尋" type="text" value=""/>
# <button aria-label="搜尋" class="js-search_submit search_submit icon-search" id="search_submit">
# <i class="fa fa-fw fa-search"></i>
# </button>
# </div>
# </li>
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# <div class="overlay" id="overlay"></div>
# </div>
# <!-- /.container -->
# </div>
# <div class="navbar-content gtco-nav">
# <div class="container">
# <div class="row">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li>
# <a href="/basketball">籃球
#                             </a>
# </li>
# <li>
# <a class="active" href="/baseball">棒球
#                             </a>
# </li>
# <li>
# <a href="/sportslife">健康生活</a>
# </li>
# <li>
# <a href="/tennis">網球
#                             </a>
# </li>
# <li>
# <a href="/football">足球
#                             </a>
# </li>
# <li>
# <a href="/racing">賽車</a>
# </li>
# <li>
# <a href="/running">跑步</a>
# </li>
# <li>
# <a href="/outdoorlife">戶外</a>
# </li>
# <li>
# <a href="#" id="othersports">更多運動</a>
# </li>
# <li>
# <a href="/feature">專題</a>
# </li>
# <li>
# <a href="/gallery">圖輯</a>
# </li>
# <li>
# <a href="/authorsgroup">作者群</a>
# </li>
# <li>
# <a class="text-highlight" href="/feature/SportsvPA">PODCAST</a>
# </li>
# <li>
# <a class="text-highlight" href="/feature/aws">AI 與運動</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- 其他運動選單 -->
# <div class="navbar-content-second" id="othersports-menu">
# <div class="container">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li>
# <a href="/volleyball">
#                     排球</a>
# </li>
# <li>
# <a href="/badminton">
#                     羽球</a>
# </li>
# <li>
# <a href="/nfl">
#                     NFL</a>
# </li>
# <li>
# <a href="/wrestling">
#                     格鬥/摔角</a>
# </li>
# <li>
# <a href="/cycling">
#                     自行車</a>
# </li>
# <li>
# <a href="/triathlon">
#                     鐵人三項</a>
# </li>
# <li>
# <a href="/golf">
#                     高爾夫</a>
# </li>
# <li>
# <a href="/tabletennis">
#                     桌球</a>
# </li>
# <li>
# <a href="/trackandfield">
#                     田徑</a>
# </li>
# <li>
# <a href="/unboxing">
#                     開箱/收藏</a>
# </li>
# <li>
# <a href="/othersports">
#                     綜合運動</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- /.container -->
# </nav>
# <article class="js-general-article-page-wrapper" data-type="Main">
# <div class="article_full first_article">
# <!-- 廣告欄位top -->
# <div class="adv01" style="min-height: 350px;">
# <p>請繼續往下閱讀</p>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_a_top","size":[[970,250],[300,250],[1,1]],"mapping":[[[980,0],[[970,250],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_a_top"}</script>
# </div>
# </div>
# <header class="article_hero">
# <div class="panel-default">
# <div class="fill bg-blur"><img alt="MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 1200w"/></div>
# <div class="mask"></div>
# </div>
# <div class="narrative">
# <div class="container">
# <div class="row">
# <div class="col-md-10 col-md-offset-1">
# <div class="panel-default">
# <div class="fill"><img alt="MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 1200w"/></div>
# <div class="mask"></div>
# </div>
# <div class="panel-content">
# <div class="infon">
# <div class="date">2025/03/19</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# </div>
# <h1>MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊</h1>
# <p>2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。</p>
# <div class="infon">
# <div class="author_name">作者：<a href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a></div>
# <div class="author">
# <a class="author_comments js-comment" href="#">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# <div class="article-share">
# <ul>
# <li class="as-fb">
# <iframe allowtransparency="true" frameborder="0" scrolling="no" src="https://www.facebook.com/plugins/like.php?href=https://www.sportsv.net/articles/118233&amp;width&amp;layout=button_count&amp;action=like&amp;show_faces=false&amp;share=true&amp;height=21&amp;appId=564475400335832" style="border:none; overflow:hidden; width:auto; height:21px;"></iframe>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div id="article_top"></div>
# <!-- 留言視窗 -->
# <section class="comments_modal">
# <div id="comment_temp">
# </div>
# <div id="comment"></div>
# </section>
# <!-- 文章開始 -->
# <section class="article">
# <div class="container relative">
# <div class="row">
# <div class="col-md-1 article_comment">
# <div class="toolbox">
# <a class="js-sub" href="#" id="article-collection-btn">
# <i class="fa fas fa-bookmark fa-2x">
# <span>收藏</span></i>
# </a>
# <a class="js-comment" href="#">
# <i class="fa fas fa-comments fa-2x">
# <span>留言</span></i>
# </a>
# </div>
# </div>
# <div class="col-md-10">
# <div class="row">
# <div class="col-md-9">
# <!-- 文章內容 -->
# <div class="article-content">
# <p class="ck-section">2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。</p><p class="ck-section">繼 2000 年後再度來到東京巨蛋舉行海外開幕戰的小熊隊，在主要陣容沒有太多變動的情況下，休賽季引進了將於季後投入自由市場的明星外野手 <span style="background-color:rgb(255,255,255);color:rgb(34,34,34);">Kyle Tucker，搭配聯盟前段的先發投手群以及守備，在總教練 Craig Counsell 第二年的領軍下能否暌違五年之後再度於完整賽季重返季後賽將備受關注。</span></p><div class="adv01 adv-article-content" style="min-height: 360px;">
# <div class="remind">請繼續往下閱讀</div>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_a_p2","size":[[640,480],[640,360],[300,250],[1,1]],"mapping":[[[980,0],[[640,480],[640,360],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_a_p2"}</script>
# </div>
# </div>
# ...
# <div class="remind">請繼續往下閱讀</div>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_a_p10","size":[[640,480],[640,360],[300,250],[1,1]],"mapping":[[[980,0],[[640,480],[640,360],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_a_p10"}</script>
# </div>
# </div>
# <p class="ck-section">第三棒 Kyle Tucker左外野方向二壘安打，兩出局二壘有人</p><p class="ck-section">Justin Turner 代打 Michael Busch</p><p class="ck-section">第四棒 Justin Turner：四壞球保送</p><p class="ck-section">第五棒 Matt Shaw：游擊方向滾地球刺殺出局，三人出局</p><p class="ck-section"> </p><p class="ck-section">【九局上】</p><p class="ck-section"><strong><u>小熊隊更換投手：Ryan Pressly</u></strong></p><p class="ck-section">第七棒 Michael Conforto：二壘方向滾地球刺殺出局，一出局</p><p class="ck-section">第八棒 Miguel Rojas：四壞球保送，一出局一壘有人</p><p class="ck-section">第九棒 Andy Pages：四壞球保送，一出局一、二壘有人</p><p class="ck-section">第一棒 大谷翔平：四壞球保送，一出局滿壘</p><p class="ck-section">第二棒 Tommy Edman：二壘方向滾地球形成雙殺，三人出局</p><p class="ck-section"> </p><p class="ck-section">【八局下】</p><p class="ck-section"><strong><u>道奇隊更換投手：Kirby Yates</u></strong></p><p class="ck-section">第六棒 Dansby Swanson：三振出局，一出局</p><p class="ck-section">第七棒 Pete Crow-Armstrong：三振出局，兩出局</p><p class="ck-section">第八棒 Carson Kelly：左外野方向平飛安打，兩出局一壘有人</p><p class="ck-section">第九棒 Jon Berti：二壘後方飛球接殺出局，三人出局</p><p class="ck-section"> </p><p class="ck-section">【八局上】</p><p class="ck-section"><strong><u>小熊隊更換投手：Porter Hodge </u></strong></p><p class="ck-section">第三棒 Teoscar Hernández：三壘方向滾地球刺殺出局，一出局</p><p class="ck-section">第四棒 Will Smith：四壞球保送，一出局一壘有人</p><p class="ck-section">第五棒 Max Muncy：二壘方向滾地球傳向一壘刺殺出局，跑者上到二壘，兩出局二壘有人</p><p class="ck-section">第六棒 Kiké Hernández：三振出局</p><p class="ck-section"> </p><p class="ck-section">【七局下】</p><p class="ck-section">道奇隊投手：Landon Knack</p><p class="ck-section">第三棒 Kyle Tucker：一壘上空高飛球接殺出局，一出局</p><p class="ck-section">第四棒 Michael Busch：三振出局，兩出局</p><p class="ck-section">第五棒 Matt Shaw：三振出局，三人出局</p><p class="ck-section"> </p><p class="ck-section">【七局上】</p><p class="ck-section"><strong><u>小熊隊更換投手：Julian Merryweather</u></strong></p><p class="ck-section">第七棒 Michael Conforto：四壞球保送，一壘有人</p><p class="ck-section">第八棒 Miguel Rojas：二壘方向滾地球形成雙殺，兩出局</p>
# </div>
# <div class="pagination">
# <ul>
# <li>
# <a aria-label="prev page" href="#"><i class="fa fa-fw fa-arrow-left"></i></a>
# </li>
# <li class="active">
# <a href="#">1</a>
# </li>
#
# <li>
# <a href="https://www.sportsv.net/articles/118233?page=2#article_top">2</a>
# </li>
#
# <li>
# <a href="https://www.sportsv.net/articles/118233?page=3#article_top">3</a>
# </li>
#
# <li>
# <a aria-label="next page" href="https://www.sportsv.net/articles/118233?page=2#article_top">
# <i class="fa fa-fw fa-arrow-right"></i>
# </a>
# </li>
# </ul>
# </div>
# <!-- 廣告欄位bottom -->
# <div class="adv01" style="margin:65px 0 15px; clear:both; min-height: 360px;">
# <p>請繼續往下閱讀</p>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_a_bottom","size":[[640,360],[640,480],[320,250],[1,1]],"mapping":[[[980,0],[[640,360],[640,480],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_a_bottom"}</script>
# </div>
# </div>
# <!-- 文章標籤 -->
# <div id="tags">
# <h4>標籤</h4>
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/洛杉磯道奇">洛杉磯道奇</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/大谷翔平">大谷翔平</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/芝加哥小熊">芝加哥小熊</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/鈴木誠也">鈴木誠也</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/佐佐木朗希">佐佐木朗希</a>
# </li>
# </ul>
# </div>
# <!-- /.文章內容 -->
# </div>
# <div class="col-md-3">
# <!-- 作者介紹卡片 -->
# <!-- 作者介紹卡片 -->
# <div class="author_card">
# <div class="author_default">
# <div class="author_pic">
# <a href="https://www.sportsv.net/authors/sportsveditor">
# <img alt="運動視界編輯" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/avatar/1/image/2024/04/deef6e89-57f3-4415-a978-2daf0c728cbb.jpg" width="100%"/>
# </a>
# </div>
# <div class="author_infon">
# <h4 class="name">運動視界編輯</h4>
# <p class="honor">大聯盟</p>
# </div>
# </div>
# <div class="author_sub">
# <ul class="list-unstyled list-inline list-social-icons">
# <li>
# <a class="social-white" href="https://www.facebook.com/SportsV.net/" target="_blank" title="追蹤粉絲團">
# <i class="fab fa-facebook-square fa-2x"></i>
# </a>
# </li>
# <li>
# <a class="social-white social-bookmark-sub" href="https://www.sportsv.net/authors/sportsveditor" target="_blank" title="追蹤作者">
# <i class="fas fa-bookmark fa-2x"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="author_featured">
# <div class="title">最新文章</div>
# <ul class="item">
# <li><a href="https://www.sportsv.net/articles/118646">NBA》Curry復甦輕鬆打  勇士痛宰太陽持續前進</a></li>
# <li><a href="https://www.sportsv.net/articles/118642">MLB》變了味的強投對決，Sean Murphy 復出首戰四打點率勇士收下系列賽開門紅</a></li>
# <li><a href="https://www.sportsv.net/articles/118606">NBA》仍需被解釋的決策 Taylor Jenkins的解僱謎團</a></li>
# </ul>
# </div>
# </div>
# <!-- /.作者介紹卡片 -->
# <!-- /.作者介紹卡片 -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </article>
# <!-- 文章頁面 - 未 滿 十 八 歲 禁 止 飲 酒 -->
# <div class="wine-legal legal wine-legal-disable">
# <span>禁</span>
# <span>止</span>
# <span>酒</span>
# <span>駕</span>
# <img alt="禁止酒駕未 滿十八歲禁止飲酒" height="38" loading="lazy" src="https://www.sportsv.net/assets/assets/icon_warning-qKdhhtgW.png" width="38"/>
# <span>未</span>
# <span>滿</span>
# <span>十</span>
# <span>八</span>
# <span>歲</span>
# <span>禁</span>
# <span>止</span>
# <span>飲</span>
# <span>酒</span>
# </div>
# <!-- 文章頁面 - 熱門文章 -->
# <section class="hot_articles">
# <div class="container">
# <h2 class="page-header">熱門文章</h2>
# </div>
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-3">
# <div class="row">
# <div class="panel-default full">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118506">台灣職棒球場「新莊棒球場」導入纖維強度提升約1.7倍的全新人工草皮 採用美津濃棒球專用人工草皮「MS CRAFT BASEBALL TURF-V」</a>
# </h3>
# </div>
# <a href="https://www.sportsv.net/articles/118506">
# <div class="mask"></div>
# <div class="fill"><img alt="台灣職棒球場「新莊棒球場」導入纖維強度提升約1.7倍的全新人工草皮 採用美津濃棒球專用人工草皮「MS CRAFT BASEBALL TURF-V」" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg 1200w"/></div>
# </a>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <div class="row">
# <div class="panel-default half">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118601">《鏡象閒話》戰報第一篇：詹子賢的棒次安排</a>
# </h3>
# </div>
# <a href="#">
# <!-- <div class="mask"></div> -->
# <div class="fill bg-gray-lighter"></div>
# </a>
# </div>
# </div>
# <div class="row">
# <div class="panel-default half">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118610">五年熬出頭，鄭宗哲成史上第 18 位大聯盟台將</a>
# </h3>
# </div>
# <a href="#">
# <!-- <div class="mask"></div> -->
# <div class="fill bg-specia"></div>
# </a>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <div class="row">
# <div class="panel-default full">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118600">【MLB2025】單場三響砲對決連三場開轟，天使強勢解決守護者打出新風采</a>
# </h3>
# </div>
# <a href="https://www.sportsv.net/articles/118600">
# <div class="mask"></div>
# <div class="fill"><img alt="【MLB2025】單場三響砲對決連三場開轟，天使強勢解決守護者打出新風采" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 1200w"/></div>
# </a>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <div class="row">
# <div class="panel-default half">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118581">O3站前話中職(2025 Week 1+2)-鳴槍起跑猿跌倒，乘勢而起龍飛高。</a>
# </h3>
# </div>
# <a href="#">
# <!-- <div class="mask"></div> -->
# <div class="fill bg-specia"></div>
# </a>
# </div>
# </div>
# <div class="row">
# <div class="panel-default half">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118438">到底要怎麼打才有長打...失去優勢的蘇智傑如何再起？</a>
# </h3>
# </div>
# <a href="#">
# <!-- <div class="mask"></div> -->
# <div class="fill bg-gray-lighter"></div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- Footer -->
# <footer>
# <div class="container inner">
# <div class="row">
# <div class="col-md-5 col-sm-6">
# <a class="navbar-brand" href="/"><img alt="運動視界" height="100%" loading="lazy" src="https://www.sportsv.net/assets/images/logo.svg" title="運動視界" width="203"/></a>
# <h4>愛你的運動，秀你的視界！</h4>
# <p>
#                 《運動視界》是一個「為了帶給喜愛運動的朋友們收穫與感動而存在的組織、平台與社群」，希望讓大家每天能樂在其中，一起發掘，專屬於你的運動見解。
#                 </p>
# </div>
# <div class="col-md-5 col-md-offset-2 col-sm-6">
# <ul class="list-unstyled list-inline list-social-icons">
# <li>
# <a aria-label="feacbook link" href="https://www.facebook.com/SportsV.net" target="_blank">
# <i class="fab fa-facebook-square"></i>
# </a>
# </li>
# <li>
# <a aria-label="instagram link" href="https://www.instagram.com/sportsvnet/" target="_blank">
# <i class="fab fa-instagram"></i>
# </a>
# </li>
# <li>
# <a aria-label="line link" href="http://line.me/ti/p/%40gec9366m" target="_blank">
# <i class="fab fa-line"></i>
# </a>
# </li>
# <li>
# <a aria-label="rss link" href="/feed" rel="alternate" target="_blank" type="application/rss+xml">
# <i class="fas fa-rss-square"></i>
# </a>
# </li>
# </ul>
# <div class="subscription">
# <h5 class="title">訂閱運動視界電子報</h5>
# <a href="/member/newsletter" target="_blank">
# <form autocomplete="off" class="fbds-search__form fbds-search__form--open" id="templates-search-form" method="get">
# <input class="fbds-search__input" id="subscribe-newsletter-email" name="search" readonly="" required="" type="search"/>
# <a class="fbds-search__icon" href="/member/newsletter" target="_blank">訂閱</a>
# </form>
# </a>
# </div>
# </div>
# <div class="col-sm-12">
# <div class="widget">
# <div class="row">
# <div class="col-sm-3 col-xs-6">
# <ul class="post-list">
# <li>
# <h6>關於運動視界</h6>
# </li>
# <li>
# <h6>
# <a href="https://www.tnlmediagene.com/zh-tw/media/sportsv" target="_blank">關於我們</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/joinauthors">成為作者</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/qa">常見問題</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/announce">站方公告</a>
# </h6>
# </li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <ul class="post-list">
# <li>
# <h6>作者相關權益</h6>
# </li>
# <li>
# <h6>
# <a href="/terms">服務條款</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/authorterms">作者條款</a>
# </h6>
# </li>
# </ul>
# </div>
# <div class="col-sm-6 col-xs-12">
# <ul class="post-list">
# <li>
# <h6>聯絡我們</h6>
# </li>
# <li><h6>
# <a href="mailto:contactus@sportsv.net" target="_blank">內容檢舉、其他意見<span>contactus@sportsv.net</span></a>
# </h6>
# </li>
# <li><h6><a href="mailto:editor@sportsv.net" target="_blank">新聞採訪、作者發文相關問題<span>editor@sportsv.net</span></a></h6></li>
# <li><h6><a href="mailto:sales@sportsv.net" target="_blank">廣告採購、授權詢問、業務相關合作<span>sales@sportsv.net</span></a></h6></li>
# <li><h6><a href="mailto:partnership@sportsv.net" target="_blank">非業務相關行銷合作洽詢<span>partnership@sportsv.net</span></a></h6></li>
# </ul>
# </div>
# </div>
# <!-- /.post-list -->
# </div>
# <!-- /.widget -->
# </div>
# </div>
# </div>
# <tnlmedia-footer lang="zh-tw"></tnlmedia-footer>
# </footer>
# <!-- Float -->
# <div>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_all_float_inner","size":[[1,1]],"mapping":[[[0,0],[[1,1]]]],"name":"sv_all_float_inner"}</script>
# </div>
# </div>
# <link href="https://www.sportsv.net/assets/assets/vendor-BIB0qm4L.js" rel="modulepreload"/><link href="https://www.sportsv.net/assets/assets/_commonjsHelpers-Cpj98o6Y.js" rel="modulepreload"/><script src="https://www.sportsv.net/assets/assets/vendor-BIB0qm4L.js" type="module"></script> <link href="https://www.sportsv.net/assets/assets/main-kUc6ua8r.js" rel="modulepreload"/><script src="https://www.sportsv.net/assets/assets/main-kUc6ua8r.js" type="module"></script>
# <link href="https://www.sportsv.net/assets/assets/article-D8puTOd8.js" rel="modulepreload"/><link href="https://www.sportsv.net/assets/assets/_commonjsHelpers-Cpj98o6Y.js" rel="modulepreload"/><script src="https://www.sportsv.net/assets/assets/article-D8puTOd8.js" type="module"></script>
# <script src="https://s.skimresources.com/js/255443X1762629.skimlinks.js" type="text/javascript"></script>
# <div>
# <div class="tmgad tmgad-type-general tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"general","slot":"\/21870649235\/sv_all_bottom_mobile_special","size":[[320,100],[1,1]],"mapping":[[0,0],[[320,100],[1,1]]],"name":"sv_all_bottom_mobile_special"}</script>
# </div>
# </div>
# </body>
# </html>

# %% [markdown]
# # Request page using fake_useragent

# %%
# headers = {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/95.0.4638.54 Safari/537.36'}

# %%
from fake_useragent import UserAgent
user_agent = UserAgent()

# %%
user_agent.random
# Out:
# 'Mozilla/5.0 (Windows NT 10.0; rv:109.0) Gecko/20100101 Firefox/118.0'

# %%
req = requests.get(article_url, headers={ 'user-agent': user_agent.random })

# %%
page = BeautifulSoup(req.text, 'html.parser')
# page = BeautifulSoup(req.text,'lxml')

# %%
page
# Out:
# <!DOCTYPE html>
#
# <html lang="zh-Hant-TW">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="b4GDCkS6abBuk8SzU8xqo6rj0JRTX4hTgVMu0VIr" name="_token">
# <link href="https://www.sportsv.net/assets/images/favicon.ico" rel="shortcut icon" type="image/x-icon"/>
# <title>MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊 - MLB - 棒球 | 運動視界 Sports Vision</title>
# <meta content="2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希" name="description"/>
# <meta content="2025-03-23 08:53:48" property="article:modified_time"/>
# <meta content="2025-03-19 16:00:00" property="article:published_time"/>
# <meta content="棒球" property="article:section"/>
# <link href="https://www.sportsv.net/articles/118233" rel="canonical"/>
# <meta content="MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊 - MLB - 棒球 | 運動視界 Sports Vision" property="og:title"/>
# <meta content="2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希" property="og:description"/>
# <meta content="運動視界 Sports Vision" property="og:site_name"/>
# <meta content="zh_TW" property="og:locale"/>
# <meta content="https://bucket-image.inkmaginecms.com/version/social/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg" property="og:image"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="運動視界 Sports Vision" name="twitter:site"/>
# <meta content="運動視界 Sports Vision" name="twitter:creator"/>
# <meta content="MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊 - MLB - 棒球 | 運動視界 Sports Vision" name="twitter:title"/>
# <meta content="2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希" name="twitter:description"/>
# <meta content="https://bucket-image.inkmaginecms.com/version/social/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg" name="twitter:image"/>
# <meta content="all" name="robots"/>
# <link as="style" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" rel="preload"><link as="style" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" rel="preload"><link href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" rel="stylesheet"/><link href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" rel="stylesheet"/> <script>
#           window.pbjs = window.pbjs || {que: []};
#                 window.googletag = window.googletag || {cmd: []};
#       </script>
# <script async="" src="https://flux-cdn.com/client/1000265/sportsv_01465.min.js"></script>
# <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>
# <script>
#     window.fluxtag = {
#       readyBids: {prebid: false, amazon: false, google: false},
#       failSafeTimeout: 3000,
#       isFn: function (object) {
#         var _t = 'Function';
#         var toString = Object.prototype.toString;
#         return toString.call(object) === '[object ' + _t + ']';
#       },
#       launchAdServer: function () {
#         if (!fluxtag.readyBids.prebid || !fluxtag.readyBids.amazon) {
#           return;
#         }
#         fluxtag.requestAdServer();
#       },
#       requestAdServer: function () {
#         if (!fluxtag.readyBids.google) {
#           fluxtag.readyBids.google = true;
#           googletag.cmd.push(function () {
#             if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {
#               pbjs.que.push(function () { pbjs.setTargetingForGPTAsync(); });
#             }
#             googletag.pubads().refresh();
#           });
#         }
#       },
#       renderAds: function (lines, failSafeTimeout) {
#         googletag.cmd.push(function () {
#           var failSafeTimeout = failSafeTimeout || window.fluxtag.failSafeTimeout;
#           var bidRequestTimeout = (failSafeTimeout - 500) > 0 ? failSafeTimeout - 500 : failSafeTimeout;
#           var refreshLines = [];
#           var params = (function () {
#             var readyBids = {amazon: false, google: false, prebid: false};
#             var definedSlots = [];
#             var adsInfo = {
#               gpt: {slots: [], displayDivIds: []},
#               aps: {slots: [], divIds: []},
#               pb: {divIds: []},
#             };
#             var getSizeList = function (width, height, sizeMappings) {
#               const sizeMapping = sizeMappings.filter(function (mappingObject) {
#                 return mappingObject[0][0] <= width && mappingObject[0][1] <= height;
#               }).reduce(function (a, b) {
#                 return (Math.abs(b[0][0] - width) <= Math.abs(a[0][0] - width) && Math.abs(b[0][1] - height) <= Math.abs(a[0][1] - height)) ? b : a;
#               });
#               if (!sizeMapping[1].length) {
#                 sizeMapping[1].push([]);
#               }
#               return sizeMapping[1];
#             };
#             googletag.pubads().getSlots().forEach(function (slot) {
#               definedSlots[slot.getSlotElementId()] = slot;
#             });
#             lines.forEach(function (line) {
#               var divId = line.divId;
#               adsInfo.pb.divIds.push(divId);
#               refreshLines.push({code: line.gpt.unitCode, id: divId});
#               if (definedSlots[divId]) {
#                 adsInfo.gpt.slots.push(definedSlots[divId]);
#               } else {
#                 var slot = googletag.defineSlot(line.gpt.unitCode, line.gpt.sizes, divId).addService(googletag.pubads());
#                 if (line.gpt.sizeMapping && line.gpt.sizeMapping.length > 0) {
#                   var sizeMapping = googletag.sizeMapping();
#                   line.gpt.sizeMapping.forEach(function (size) {
#                     sizeMapping.addSize(size[0], size[1]);
#                   });
#                   slot.defineSizeMapping(sizeMapping.build());
#                 }
#                 if (line.gpt.keyValues && line.gpt.keyValues.length > 0) {
#                   line.gpt.keyValues.forEach(function (param) {
#                     slot.setTargeting(param.key, param.value);
#                   });
#                 }
#                 adsInfo.gpt.slots.push(slot);
#                 adsInfo.gpt.displayDivIds.push(divId);
#               }
#               if (!!line.aps) {
#                 if (line.gpt.sizeMapping && line.gpt.sizeMapping.length > 0) {
#                   line.aps.sizes = getSizeList(window.innerWidth, window.innerHeight, line.gpt.sizeMapping);
#                 }
#                 adsInfo.aps.slots.push({
#                   slotID: divId,
#                   slotName: line.aps.slotName,
#                   sizes: line.aps.sizes,
#                 });
#                 adsInfo.aps.divIds.push(divId);
#               }
#             });
#             if (adsInfo.aps.slots.length === 0) {
#               readyBids.amazon = true;
#             }
#             var adServerSend = function () {
#               if (!readyBids.amazon || !readyBids.prebid) {
#                 return;
#               }
#               if (!readyBids.google) {
#                 readyBids.google = true;
#                 adsInfo.gpt.displayDivIds.forEach(function (divId) {
#                   googletag.display(divId);
#                 });
#                 if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {
#                   pbjs.que.push(function () {
#                     pbjs.setTargetingForGPTAsync(adsInfo.pb.divIds);
#                   });
#                 }
#                 if (adsInfo.aps.slots.length > 0 && !!(window.apstag) && fluxtag.isFn(window.apstag.fetchBids)) {
#                   window.apstag.setDisplayBids(adsInfo.aps.divIds);
#                 }
#                 googletag.pubads().refresh(adsInfo.gpt.slots);
#               }
#             };
#             var apsCallback = function () {
#               readyBids.amazon = true;
#               adServerSend();
#             };
#             var pbCallback = function () {
#               readyBids.prebid = true;
#               adServerSend();
#             };
#             setTimeout(function () {
#               readyBids.amazon = true;
#               readyBids.prebid = true;
#               adServerSend();
#             }, failSafeTimeout);
#             return {aps: {slots: adsInfo.aps.slots, callback: apsCallback}, prebid: {callback: pbCallback}};
#           })();
#           if (!!(window.pbFlux) && window.pbFlux.refresh && fluxtag.isFn(window.pbFlux.refresh)) {
#             pbjs.que.push(function () {
#               window.pbFlux.refresh({
#                 lines: refreshLines,
#                 callback: params.prebid.callback,
#                 timeout: bidRequestTimeout,
#               });
#             });
#           } else {
#             params.prebid.callback();
#           }
#           if (params.aps.slots.length > 0 && !!(window.apstag) && fluxtag.isFn(window.apstag.fetchBids)) {
#             window.apstag.fetchBids({
#               slots: params.aps.slots,
#               timeout: bidRequestTimeout,
#             }, function (bids) { params.aps.callback(); });
#           } else {
#             params.aps.callback();
#           }
#         });
#       },
#     };
#   </script>
# <script>
#     googletag.cmd.push(function () {
#       googletag.pubads().enableSingleRequest();
#       googletag.pubads().disableInitialLoad();
#       googletag.pubads().enableAsyncRendering();
#       googletag.pubads().collapseEmptyDivs();
#                         googletag.enableServices();
#     });
#   </script>
# <script>
#     window.tmgad = {
#       serial: 0,
#       loaded: false,
#       scan: function () {
#         googletag.cmd.push(function () {
#           let list = document.querySelectorAll('.tmgad-new');
#           for (let i = 0; i < list.length; i++) {
#             tmgad.build(list[i]);
#           }
#         });
#         if (!tmgad.loaded) {
#           document.addEventListener('DOMContentLoaded', function () {
#             tmgad.scan();
#           });
#           tmgad.loaded = true;
#         }
#       },
#       build: function (target) {
#         if (!target.classList.contains('tmgad-new')) {
#           console.log('TMGAD build: Pass ' + target.getAttribute('class'));
#           return;
#         }
#         try { target.classList.remove('tmgad-new'); } catch (e) {}
#         let attributes = {id: '', name: '', slot: '', type: 'general', size: [], mapping: [], targeting: {}};
#         try {
#           attributes = Object.assign(attributes, JSON.parse(target.querySelector('script').textContent.trim()));
#           tmgad.serial++;
#           attributes.id = 'tmgad-' + attributes.name + '-' + tmgad.serial;
#           target.setAttribute('id', attributes.id);
#           switch (attributes.type) {
#             case 'flux':
#               let flux = {
#                 divId: attributes.id,
#                 gpt: {
#                   unitCode: attributes.slot,
#                   sizes: attributes.size,
#                   sizeMapping: attributes.mapping,
#                   keyValues: [],
#                 },
#               };
#               for (let targeting in attributes.targeting) {
#                 if (!attributes.targeting[targeting].length) {
#                   continue;
#                 }
#                 flux.gpt.keyValues.push({key: targeting, value: attributes.targeting[targeting]});
#               }
#               window.fluxtag.renderAds([flux]);
#               return;
#           }
#           let mapping = googletag.sizeMapping();
#           for (let i = 0; i < attributes.mapping.length; i++) {
#             if (!attributes.mapping[i][1].length) {
#               continue;
#             }
#             mapping = mapping.addSize(attributes.mapping[i][0], attributes.mapping[i][1]);
#           }
#           let service = googletag.pubads();
#           for (let targeting in attributes.targeting) {
#             if (!attributes.targeting[targeting].length) {
#               continue;
#             }
#             service.setTargeting(targeting, attributes.targeting[targeting]);
#           }
#           googletag.cmd.push(function () {
#             let slot;
#             switch (attributes.type) {
#               case 'oop':
#                 slot = googletag.defineOutOfPageSlot(attributes.slot, attributes.id)
#                   .addService(service);
#                 break;
#               default:
#                 slot = googletag.defineSlot(attributes.slot, attributes.size, attributes.id)
#                   .defineSizeMapping(mapping.build()).addService(service);
#                 break;
#             }
#             googletag.display(attributes.id);
#             googletag.pubads().refresh([slot]);
#           });
#         } catch (e) {
#           console.warn('TMGAD build: [' + attributes.id + ']' + e.message);
#           return false;
#         }
#       },
#     };
#   </script>
# <script id="sportsv_info" type="application/json">{"article_id":118233,"article_url":"https:\/\/www.sportsv.net\/articles\/118233","article_title":"MLB\u6771\u4eac\u8cfd\u300b\u829d\u52a0\u54e5\u5c0f\u718avs\u6d1b\u6749\u78ef\u9053\u5947 \u6587\u5b57\u76f4\u64ad\uff1a\u5927\u8c37\u7fd4\u5e73\u672c\u5b63\u9996\u8f5f\u5728\u5167\u55ae\u5834\u4e09\u8f5f\uff0c\u9053\u5947\u968a\u5169\u6230\u6a6b\u6383\u5c0f\u718a\u968a - MLB - \u68d2\u7403 | \u904b\u52d5\u8996\u754c Sports Vision","article_author_id":61,"datalayer_sets":{"analyticsAuthors":[{"key":"sportsveditor","name":"\u904b\u52d5\u8996\u754c\u7de8\u8f2f"}],"analyticsTerms":[{"type":"category","key":"mlb","name":"MLB"},{"type":"category","key":"baseball","name":"\u68d2\u7403"},{"type":"tag","key":162,"name":"\u6d1b\u6749\u78ef\u9053\u5947"},{"type":"tag","key":220,"name":"\u5927\u8c37\u7fd4\u5e73"},{"type":"tag","key":1862,"name":"\u829d\u52a0\u54e5\u5c0f\u718a"},{"type":"tag","key":19656,"name":"\u9234\u6728\u8aa0\u4e5f"},{"type":"tag","key":32474,"name":"\u4f50\u4f50\u6728\u6717\u5e0c"}]},"is_drinking_warning":0,"is_infinite":1,"is_ad":1}</script>
# <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-XYPFETDX47&amp;l=ga4DataLayer"></script>
# <script>
#     window.ga4DataLayer = window.ga4DataLayer || [];
#     function ga4_tag(){ga4DataLayer.push(arguments);}
#     ga4_tag('js', new Date());
#     ga4_tag('config', 'G-XYPFETDX47');
#     (function () {
#         try {
#             window.Sportsv = window.Sportsv || {};
#             if (!window.Sportsv.sourceMaterial) {
#                 window.Sportsv.sourceMaterial = {};
#                 window.Sportsv.sourceMaterial = JSON.parse(document.getElementById('sportsv_info').textContent)
#             }
#             let source = window.Sportsv?.sourceMaterial
#             source.datalayer_sets.analyticsAuthors.forEach(function (value){
#                 ga4_tag('event', 'Counter-Author', {
#                     'action': 'trigger',
#                     'label': value.name
#                 })
#             })
#             source.datalayer_sets.analyticsTerms.forEach(function (value){
#                 ga4_tag('event', 'Counter-Term', {
#                     'action': 'trigger',
#                     'label': value.name
#                 })
#             })
#         } catch (e) {}
#     })();
# </script>
# <script>
#     window.BrandGtmDataLayer = window.BrandGtmDataLayer || [];
#     window.DaexGtmDataLayer = window.DaexGtmDataLayer || [];
#     window.TNLMGTagDataLayer = window.TNLMGTagDataLayer || [];
#     DaexGtmDataLayer.push({'ID' : 'D-100007'});
#     TNLMGTagDataLayer.push({
#         event: 'config',
#         config_id: 'a2fdd15c62e51c434bff7452b5025520e5deca2c45a198aa2da0b04aef7b4a7f',
#     });
#     let memberId = localStorage.getItem('member_id');
#     if (memberId) {
#         TNLMGTagDataLayer.push({
#             event: 'set_member_id',
#             member_id: memberId,
#         });
#     }
#     (function () {
#         try {
#             let source = window.Sportsv?.sourceMaterial
#
#             BrandGtmDataLayer.push(source.datalayer_sets);
#             DaexGtmDataLayer.push(source.datalayer_sets);
#
#
#             //BrandGtmDataLayer.push({'event': 'UserLoaded'})
#             //DaexGtmDataLayer.push({'event': 'UserLoaded'})
#
#             TNLMGTagDataLayer.push({event: 'pageview'});
#
#                         try {
#                 let source = window.Sportsv?.sourceMaterial
#                 let articleId = source?.article_id ? String(source?.article_id) : undefined;
#
#                 articleId && TNLMGTagDataLayer.push({event: 'view_article', view_article_payload: {article_id: articleId}});
#             } catch (e) { console.log(e); }
#                     } catch (e) {}
#     })();
#
#     // BRAND
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','BrandGtmDataLayer','GTM-TX847V4');
#
#     // DAEX
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','DaexGtmDataLayer','GTM-5THSZR9');
#
#     /* TNLMGTag */
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#         new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#             j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#             'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','TNLMGTagDataLayer','GTM-5HR8SM3V');
#
#     /* Inkmagine */
#     (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#             new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#         j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#         'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#     })(window,document,'script','inkmagineDataLayer','GTM-MGHRKMRV');
# </script>
# <!-- Begin Comscore Tag -->
# <script>
#     var _comscore = _comscore || [];
#     _comscore.push({c1: "2", c2: "17728543", options: {enableFirstPartyCookie: true, bypassUserConsentRequirementFor1PCookie: true}});
#     (function () {
#         var s = document.createElement("script"), el = document.getElementsByTagName("script")[0];
#         s.async = true; s.src = "https://sb.scorecardresearch.com/cs/17728543/beacon.js";
#         el.parentNode.insertBefore(s, el);
#     })();
# </script>
# <!--End Comscore Tag-->
# <script type="text/javascript">
#     (function() {
#         let sections = [];
#         let authors = [];
#         try {
#             let source = window.Sportsv?.sourceMaterial;
#             source.datalayer_sets.analyticsAuthors.forEach(function (value){
#                 authors.push(value.name);
#             });
#             source.datalayer_sets.analyticsTerms.forEach(function (value){
#                 if (value.type == 'category') {
#                     sections.push(value.name);
#                 }
#             });
#         }catch(e) {}
#         /** CONFIGURATION START **/
#         var _sf_async_config = window._sf_async_config = (window._sf_async_config || {});
#         _sf_async_config.uid = 61305;
#         _sf_async_config.domain = 'sportsv.net'; //CHANGE THIS TO THE ROOT DOMAIN
#         _sf_async_config.flickerControl = false;
#         _sf_async_config.useCanonical = true;
#         _sf_async_config.useCanonicalDomain = true;
#         _sf_async_config.sections = sections.join(','); // CHANGE THIS TO YOUR SECTION NAME(s)
#         _sf_async_config.authors = authors.join(','); // CHANGE THIS TO YOUR AUTHOR NAME(s)
#         /** CONFIGURATION END **/
#         function loadChartbeat() {
#             var e = document.createElement('script');
#             var n = document.getElementsByTagName('script')[0];
#             e.type = 'text/javascript';
#             e.async = true;
#             e.src = '//static.chartbeat.com/js/chartbeat.js';;
#             n.parentNode.insertBefore(e, n);
#         }
#         loadChartbeat();
#     })();
# </script>
# <script async="" src="//static.chartbeat.com/js/chartbeat_mab.js"></script>
# <script>
#     !function(f,b,e,v,n,t,s)
#         {if(f.fbq)return;n=f.fbq=function(){n.callMethod?
#                         n.callMethod.apply(n,arguments):n.queue.push(arguments)};
#                 if(!f._fbq)f._fbq=n;n.push=n;n.loaded=!0;n.version='2.0';
#                 n.queue=[];t=b.createElement(e);t.async=!0;
#                 t.src=v;s=b.getElementsByTagName(e)[0];
#                 s.parentNode.insertBefore(t,s)}(window, document,'script',
#                                 'https://connect.facebook.net/zh_TW/fbevents.js');
#     fbq('init', '2210311835696207');
#     fbq('track', 'PageView');
# </script>
# <script>
#     fbq('track', 'ViewContent');
# </script>
# <script defer="" src="https://resource.tnlmediagene.com/assets/v1/js/tnlmedia-header-footer.js"></script>
# <script async="" src="https://www.sportsv.net/assets/assets/head-D73q8ojf.js" type="module"></script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebSite","url":"https:\/\/www.sportsv.net","potentialAction":{"@type":"SearchAction","target":"https:\/\/www.sportsv.net\/search?q={search_term_string}","query-input":"required name=search_term_string"},"publisher":{"@type":"Organization","name":"運動視界Sports Vision","logo":"https:\/\/www.sportsv.net\/assets\/images\/logo.png"}}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"WebPage","name":"MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊","description":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希","keywords":["洛杉磯道奇","大谷翔平","芝加哥小熊","鈴木誠也","佐佐木朗希"],"dateCreated":"2025-03-19T15:19:15+08:00","dateModified":"2025-03-23T08:53:48+08:00","datePublished":"2025-03-19T16:00:00+08:00","primaryImageOfPage":{"@type":"ImageObject","contentUrl":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/03\/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg"},"commentCount":0}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"BreadcrumbList","itemListElement":[{"@type":"ListItem","position":1,"name":"運動視界Sports Vision","item":"https:\/\/www.sportsv.net"},{"@type":"ListItem","position":2,"name":"棒球","item":"https:\/\/www.sportsv.net\/baseball"},{"@type":"ListItem","position":3,"name":"MLB","item":"https:\/\/www.sportsv.net\/baseball\/mlb"},{"@type":"ListItem","position":4,"name":"MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊","item":"https:\/\/www.sportsv.net\/articles\/118233"}]}</script>
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"Article","url":"https:\/\/www.sportsv.net\/articles\/118233","description":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希","thumbnailUrl":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/03\/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg","keywords":["洛杉磯道奇","大谷翔平","芝加哥小熊","鈴木誠也","佐佐木朗希"],"dateCreated":"2025-03-19T15:19:15+08:00","dateModified":"2025-03-23T08:53:48+08:00","datePublished":"2025-03-19T16:00:00+08:00","articleBody":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。繼 2000 年後再度來到東京巨蛋舉行海外開幕戰的小熊隊，在主要陣容沒有太多變動的情況下，休賽季引進了將於季後投入自由市場的明星外野手 Kyle Tucker，搭配聯盟前段的先發投手群以及守備，在總教練 Craig Counsell 第二年的領軍下能否暌違五年之後再度於完整賽季重返季後賽將備受關注。2024 年世界大賽冠軍道奇隊並未因順利登頂而在這個休賽季停下補強的腳步，不惜持續推高團隊薪資以及被冠上新生代「邪惡帝國」的標籤，也要引進 Blake Snell、Tanner Scott 和佐佐木朗希等堅實的戰力，都宣示了他們成為 21 世紀第一支成功衛冕冠軍隊伍的企圖心。究竟大聯盟會不會睽違 25 年再度出現連續兩年登頂成功的隊伍？絕對是新賽季的一大看點。與山本由伸聯手貢獻關鍵戰力 大谷翔平坦言難得感到緊張把握對手換投機會，道奇逆轉收下賽季首勝山本由伸徜徉首次日籍投手開幕對決，大谷翔平雙安領軍道奇笑納勝利《2025 MLB 開季分析》洛杉磯道奇—壓力山大的超級戰艦《2025 MLB 開季分析》芝加哥小熊—Hoyer的烏紗帽保衛戰道奇隊先發打線小熊隊先發打線1.大谷翔平, DH2.Tommy Edman, 2B3.Teoscar Hernández, RF4.Will Smith, C5.Max Muncy, 3B6.Kiké Hernández, 1B7.Michael Conforto, LF8.Miguel Rojas, SS9.Andy Pages, CF1.Ian Happ, LF2.鈴木誠也, DH3.Kyle Tucker, RF4.Michael Busch, 1B5.Matt Shaw, 3B6.Dansby Swanson, SS7.Pete Crow-Armstrong, CF8.Carson Kelly, C9.Jon Berti, 2B先發投手：佐佐木朗希（10勝5敗, 111 局、防禦率 2.35）先發投手：Justin Steele（5勝5敗, 134⅔ 局、防禦率 2.91）&nbsp;&nbsp;1局2局3局4局5局6局7局8局9局得分安打失誤道奇隊（1-0）021210000670小熊隊（0-1）０01110000380&nbsp;【九局下】道奇隊更換投手：Alex Vesia第一棒 Ian Happ：本壘後方飛球接殺出局，一出局第二棒 鈴木誠也：三振出局，兩出局第三棒 Kyle Tucker左外野方向二壘安打，兩出局二壘有人Justin Turner 代打 Michael Busch第四棒 Justin Turner：四壞球保送第五棒 Matt Shaw：游擊方向滾地球刺殺出局，三人出局&nbsp;【九局上】小熊隊更換投手：Ryan Pressly第七棒 Michael Conforto：二壘方向滾地球刺殺出局，一出局第八棒 Miguel Rojas：四壞球保送，一出局一壘有人第九棒 Andy Pages：四壞球保送，一出局一、二壘有人第一棒 大谷翔平：四壞球保送，一出局滿壘第二棒 Tommy Edman：二壘方向滾地球形成雙殺，三人出局&nbsp;【八局下】道奇隊更換投手：Kirby Yates第六棒 Dansby Swanson：三振出局，一出局第七棒 Pete Crow-Armstrong：三振出局，兩出局第八棒 Carson Kelly：左外野方向平飛安打，兩出局一壘有人第九棒 Jon Berti：二壘後方飛球接殺出局，三人出局&nbsp;【八局上】小熊隊更換投手：Porter Hodge&nbsp;第三棒 Teoscar Hernández：三壘方向滾地球刺殺出局，一出局第四棒 Will Smith：四壞球保送，一出局一壘有人第五棒 Max Muncy：二壘方向滾地球傳向一壘刺殺出局，跑者上到二壘，兩出局二壘有人第六棒 Kiké Hernández：三振出局&nbsp;【七局下】道奇隊投手：Landon Knack第三棒 Kyle Tucker：一壘上空高飛球接殺出局，一出局第四棒 Michael Busch：三振出局，兩出局第五棒 Matt Shaw：三振出局，三人出局&nbsp;【七局上】小熊隊更換投手：Julian Merryweather第七棒 Michael Conforto：四壞球保送，一壘有人第八棒 Miguel Rojas：二壘方向滾地球形成雙殺，兩出局第九棒 Andy Pages：右外野方向二壘安打，兩出局二壘有人第一棒 大谷翔平：故意四壞保送，兩出局二、三壘有人第二棒 Tommy Edman：三壘方向強勁滾地球，三壘手飛撲攔下傳向一壘刺殺出局，三人出局&nbsp;【六局下】道奇隊更換投手：Landon Knack第八棒 Carson Kelly：游擊方向滾地球刺殺出局，一出局第九棒 Jon Berti：中線穿越安打，一出局一壘有人第一棒 Ian Happ：三振出局，兩出局一壘有人第二棒 鈴木誠也：三壘方向滾地球傳向二壘封殺出局，三人出局&nbsp;【六局上】小熊隊更換投手：Caleb Thielbar第四棒 Will Smith：三壘方向滾地球刺殺出局，一出局第五棒 Max Muncy：三振出局，兩出局第六棒 Kiké Hernández：本壘後方高飛球接殺出局，三人出局&nbsp;【五局下】道奇隊更換投手：Jack Dreyer（生涯初登板）第三棒 Kyle Tucker：中外野深遠飛球接殺出局，一出局第四棒 Michael Busch：三振出局，兩出局第五棒 Matt Shaw：投手前滾地球未能處裡乾淨形成內野安打，兩出局一壘有人（生涯首安）第六棒 Dansby Swanson：左外野平飛三壘安打，一壘跑者回來得分，小熊隊追至 6：3，兩出局三壘有人第七棒 Pete Crow-Armstrong：右外野方向飛球接殺出局，三人出局【五局上】小熊隊更換投手：Nate Pearson第九棒 Andy Pages：三振出局，一出局第一棒 大谷翔平：陽春全壘打，道奇擴大領先 6：2第二棒 Tommy Edman：三振出局，兩出局第三棒 Teoscar Hernández：左外野方向飛球接殺出局，三人出局&nbsp;【四局下】道奇隊更換投手：Luis García第六棒 Dansby Swanson：三振出局，一出局第七棒 Pete Crow-Armstrong：三振出局，兩出局第八棒 Carson Kelly：四壞球，兩出局一壘有人第九棒 Jon Berti：中外野平飛安打，兩出局一、二壘有人第一棒 Ian Happ：左外野方向落地安打，二壘跑者回來得分，小熊隊追成 5：2，兩出局一、二壘有人第二棒 鈴木誠也：三振出局，三人出局&nbsp;【四局上】小熊隊先發投手：Justin Steele第四棒 Will Smith：二壘安打，二壘有人第五棒 Max Muncy：游擊手後方飛球，一出局一壘有人第六棒 Kiké Hernández：兩分全壘打，道奇擴大領先 5：1第七棒 Michael Conforto：三振出局，兩出局第八棒 Miguel Rojas：三振出局，三人出局&nbsp;【三局下】道奇隊先發投手：佐佐木朗希第八棒 Carson Kelly：一壘方向滾地球一壘手自踩壘包，一出局第九棒 Jon Berti：三壘方向滾地球形成內野安打，一出局一壘有人Berti 盜壘成功，一出局二壘有人第一棒 Ian Happ：四壞球保送，一出局一、二壘有人第二棒 鈴木誠也：四壞球保送，一出局滿壘第三棒 Kyle Tucker：四壞球保送，三壘跑者回來得分，小熊追回 ...
# <script type="application/ld+json">{"@context":"https:\/\/schema.org","@type":"NewsArticle","url":"https:\/\/www.sportsv.net\/articles\/118233","description":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。 標籤:洛杉磯道奇,大谷翔平,芝加哥小熊,鈴木誠也,佐佐木朗希","thumbnailUrl":"https:\/\/bucket-image.inkmaginecms.com\/version\/social\/1\/image\/2025\/03\/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg","keywords":["洛杉磯道奇","大谷翔平","芝加哥小熊","鈴木誠也","佐佐木朗希"],"dateCreated":"2025-03-19T15:19:15+08:00","dateModified":"2025-03-23T08:53:48+08:00","datePublished":"2025-03-19T16:00:00+08:00","articleBody":"2025 大聯盟賽季在昨日（3\/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。繼 2000 年後再度來到東京巨蛋舉行海外開幕戰的小熊隊，在主要陣容沒有太多變動的情況下，休賽季引進了將於季後投入自由市場的明星外野手 Kyle Tucker，搭配聯盟前段的先發投手群以及守備，在總教練 Craig Counsell 第二年的領軍下能否暌違五年之後再度於完整賽季重返季後賽將備受關注。2024 年世界大賽冠軍道奇隊並未因順利登頂而在這個休賽季停下補強的腳步，不惜持續推高團隊薪資以及被冠上新生代「邪惡帝國」的標籤，也要引進 Blake Snell、Tanner Scott 和佐佐木朗希等堅實的戰力，都宣示了他們成為 21 世紀第一支成功衛冕冠軍隊伍的企圖心。究竟大聯盟會不會睽違 25 年再度出現連續兩年登頂成功的隊伍？絕對是新賽季的一大看點。與山本由伸聯手貢獻關鍵戰力 大谷翔平坦言難得感到緊張把握對手換投機會，道奇逆轉收下賽季首勝山本由伸徜徉首次日籍投手開幕對決，大谷翔平雙安領軍道奇笑納勝利《2025 MLB 開季分析》洛杉磯道奇—壓力山大的超級戰艦《2025 MLB 開季分析》芝加哥小熊—Hoyer的烏紗帽保衛戰道奇隊先發打線小熊隊先發打線1.大谷翔平, DH2.Tommy Edman, 2B3.Teoscar Hernández, RF4.Will Smith, C5.Max Muncy, 3B6.Kiké Hernández, 1B7.Michael Conforto, LF8.Miguel Rojas, SS9.Andy Pages, CF1.Ian Happ, LF2.鈴木誠也, DH3.Kyle Tucker,
ggleLan_tw_cn" href="#">
# <span class="lanText-tw active">繁</span><span class="lanText-cn">簡</span>
# </a>
# <!-- Navigation -->
# <nav class="navbar navbar-inverse" role="navigation">
# <tnlmedia-header lang="zh-tw"></tnlmedia-header>
# <div class="brand">
# <div class="container relative">
# <div class="row">
# <!-- 會員通知 -->
# <div class="popo notice bottom">
# <div class="arrow"></div>
# <h3 class="popover-title">重要通知</h3>
# <div class="popover-content">
# <div class="notice_infon" id="notice_infon">
# </div>
# </div>
# </div>
# <!-- 會員管理 -->
# <div class="popo member bottom">
# <div class="arrow"></div>
# <div class="popover-content">
# <div class="item">
# <p class="username"></p>
# <div class="menber-menu">
# <div class="menber-menu__item">
# <h4 class="menber-menu__title">會員服務</h4>
# <ul>
# <li><a href="/member/newsletter"><i class="fas fa-envelope"></i>電子報</a></li>
# <li><a href="/member/comment"><i class="fas fa-comment-dots"></i>個人留言</a></li>
# <li><a href="/member/saved-articles"><i class="fas fa-bookmark"></i>好文收藏</a></li>
# <li><a href="/member/saved-author"><i class="fas fa-heart"></i>訂閱作者</a></li>
# </ul>
# </div>
# <div class="menber-menu__item">
# <h4 class="menber-menu__title">帳號管理</h4>
# <ul>
# <li><a href="https://member.tnlmedia.com/profile" target="_blank"><i class="fas fa-user-circle"></i>個人資料</a></li>
# <li>
# <a href="https://member.tnlmedia.com/subscription" target="_blank"><i class="fa-solid fa-circle-dollar"></i>管理付費訂閱
#                             </a>
# </li>
# <li id="cabinet_btn" style="display:none">
# <a href="https://cabinet.tnlmedia.com" target="_blank"><i class="fa-solid fa-bookmark"></i>文章管理
#                             </a>
# </li>
# <li id="admin_btn" style="display:none">
# <a href="/admin/member/articles"><i class="fa-solid fa-circle-dollar"></i>稿費數據
#                             </a>
# </li>
# </ul>
# </div>
# </div>
# <a class="logout" href="/logout">登出</a>
# </div>
# </div>
# </div>
# <!-- Brand and toggle get grouped for better mobile display -->
# <div class="navbar-header">
# <a class="navbar-brand" href="/"><img alt="運動視界" height="100%" src="https://www.sportsv.net/assets/images/logo.svg" title="運動視界" width="100%"/></a>
# </div>
# <!-- Collect the nav links, forms, and other content for toggling -->
# <div class="navbar-collapse" id="Brand-navbar-collapse">
# <ul class="nav navbar-nav navbar-right">
# <li>
# <a class="header_translation_block toggleLan_tw_cn" href="#">
# <span class="lanText-tw active">繁</span> / <span class="lanText-cn">簡</span>
# </a>
# </li>
# <li>
# <a href="https://www.thenewslens.com/subscription">無廣告服務</a>
# </li>
# <li>
# <a class="joinauthors" href="/joinauthors" target="_blank">成為作者</a>
# </li>
# <li id="nav-unlogingin">
# <a href="/login">
# <span>登入</span> / <span>註冊</span>
# </a>
# </li>
# <li id="nav-notice" style="display:none">
# <a class="notice" id="noticeBtn">
# <i class="fas fa-bell" id="notice-icon"></i>
# </a>
# </li>
# <li id="nav-logingin" style="display:none">
# <a class="member" id="memberBtn">
# <span class="nickname" id="memberNickname">N</span>
# </a>
# </li>
# <li>
# <div class="search_form" method="get" role="search">
# <input class="js-search_input search_input" id="search_input" name="q" placeholder="搜尋" type="text" value=""/>
# <button aria-label="搜尋" class="js-search_submit search_submit icon-search" id="search_submit">
# <i class="fa fa-fw fa-search"></i>
# </button>
# </div>
# </li>
# </ul>
# </div>
# <!-- /.navbar-collapse -->
# </div>
# <div class="overlay" id="overlay"></div>
# </div>
# <!-- /.container -->
# </div>
# <div class="navbar-content gtco-nav">
# <div class="container">
# <div class="row">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li>
# <a href="/basketball">籃球
#                             </a>
# </li>
# <li>
# <a class="active" href="/baseball">棒球
#                             </a>
# </li>
# <li>
# <a href="/sportslife">健康生活</a>
# </li>
# <li>
# <a href="/tennis">網球
#                             </a>
# </li>
# <li>
# <a href="/football">足球
#                             </a>
# </li>
# <li>
# <a href="/racing">賽車</a>
# </li>
# <li>
# <a href="/running">跑步</a>
# </li>
# <li>
# <a href="/outdoorlife">戶外</a>
# </li>
# <li>
# <a href="#" id="othersports">更多運動</a>
# </li>
# <li>
# <a href="/feature">專題</a>
# </li>
# <li>
# <a href="/gallery">圖輯</a>
# </li>
# <li>
# <a href="/authorsgroup">作者群</a>
# </li>
# <li>
# <a class="text-highlight" href="/feature/SportsvPA">PODCAST</a>
# </li>
# <li>
# <a class="text-highlight" href="/feature/aws">AI 與運動</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# <!-- 其他運動選單 -->
# <div class="navbar-content-second" id="othersports-menu">
# <div class="container">
# <div class="navbar-collapse">
# <ul class="nav navbar-nav">
# <li>
# <a href="/volleyball">
#                     排球</a>
# </li>
# <li>
# <a href="/badminton">
#                     羽球</a>
# </li>
# <li>
# <a href="/nfl">
#                     NFL</a>
# </li>
# <li>
# <a href="/wrestling">
#                     格鬥/摔角</a>
# </li>
# <li>
# <a href="/cycling">
#                     自行車</a>
# </li>
# <li>
# <a href="/triathlon">
#                     鐵人三項</a>
# </li>
# <li>
# <a href="/golf">
#                     高爾夫</a>
# </li>
# <li>
# <a href="/tabletennis">
#                     桌球</a>
# </li>
# <li>
# <a href="/trackandfield">
#                     田徑</a>
# </li>
# <li>
# <a href="/unboxing">
#                     開箱/收藏</a>
# </li>
# <li>
# <a href="/othersports">
#                     綜合運動</a>
# </li>
# </ul>
# </div>
# </div>
# </div>
# <!-- /.container -->
# </nav>
# <article class="js-general-article-page-wrapper" data-type="Main">
# <div class="article_full first_article">
# <!-- 廣告欄位top -->
# <div class="adv01" style="min-height: 350px;">
# <p>請繼續往下閱讀</p>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_a_top","size":[[970,250],[300,250],[1,1]],"mapping":[[[980,0],[[970,250],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_a_top"}</script>
# </div>
# </div>
# <header class="article_hero">
# <div class="panel-default">
# <div class="fill bg-blur"><img alt="MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 1200w"/></div>
# <div class="mask"></div>
# </div>
# <div class="narrative">
# <div class="container">
# <div class="row">
# <div class="col-md-10 col-md-offset-1">
# <div class="panel-default">
# <div class="fill"><img alt="MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/03/3f48693f-a80d-4228-aa22-b89ca2189ec9.jpg 1200w"/></div>
# <div class="mask"></div>
# </div>
# <div class="panel-content">
# <div class="infon">
# <div class="date">2025/03/19</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# </div>
# <h1>MLB東京賽》芝加哥小熊vs洛杉磯道奇 文字直播：大谷翔平本季首轟在內單場三轟，道奇隊兩戰橫掃小熊隊</h1>
# <p>2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。</p>
# <div class="infon">
# <div class="author_name">作者：<a href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a></div>
# <div class="author">
# <a class="author_comments js-comment" href="#">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# <div class="article-share">
# <ul>
# <li class="as-fb">
# <iframe allowtransparency="true" frameborder="0" scrolling="no" src="https://www.facebook.com/plugins/like.php?href=https://www.sportsv.net/articles/118233&amp;width&amp;layout=button_count&amp;action=like&amp;show_faces=false&amp;share=true&amp;height=21&amp;appId=564475400335832" style="border:none; overflow:hidden; width:auto; height:21px;"></iframe>
# </li>
# </ul>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# </header>
# <div id="article_top"></div>
# <!-- 留言視窗 -->
# <section class="comments_modal">
# <div id="comment_temp">
# </div>
# <div id="comment"></div>
# </section>
# <!-- 文章開始 -->
# <section class="article">
# <div class="container relative">
# <div class="row">
# <div class="col-md-1 article_comment">
# <div class="toolbox">
# <a class="js-sub" href="#" id="article-collection-btn">
# <i class="fa fas fa-bookmark fa-2x">
# <span>收藏</span></i>
# </a>
# <a class="js-comment" href="#">
# <i class="fa fas fa-comments fa-2x">
# <span>留言</span></i>
# </a>
# </div>
# </div>
# <div class="col-md-10">
# <div class="row">
# <div class="col-md-9">
# <!-- 文章內容 -->
# <div class="article-content">
# <p class="ck-section">2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。</p><p class="ck-section">繼 2000 年後再度來到東京巨蛋舉行海外開幕戰的小熊隊，在主要陣容沒有太多變動的情況下，休賽季引進了將於季後投入自由市場的明星外野手 <span style="background-color:rgb(255,255,255);color:rgb(34,34,34);">Kyle Tucker，搭配聯盟前段的先發投手群以及守備，在總教練 Craig Counsell 第二年的領軍下能否暌違五年之後再度於完整賽季重返季後賽將備受關注。</span></p><div class="adv01 adv-article-content" style="min-height: 360px;">
# <div class="remind">請繼續往下閱讀</div>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_a_p2","size":[[640,480],[640,360],[300,250],[1,1]],"mapping":[[[980,0],[[640,480],[640,360],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_a_p2"}</script>
# </div>
# </div>
# ...
# <div class="remind">請繼續往下閱讀</div>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_a_p10","size":[[640,480],[640,360],[300,250],[1,1]],"mapping":[[[980,0],[[640,480],[640,360],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_a_p10"}</script>
# </div>
# </div>
# <p class="ck-section">第三棒 Kyle Tucker左外野方向二壘安打，兩出局二壘有人</p><p class="ck-section">Justin Turner 代打 Michael Busch</p><p class="ck-section">第四棒 Justin Turner：四壞球保送</p><p class="ck-section">第五棒 Matt Shaw：游擊方向滾地球刺殺出局，三人出局</p><p class="ck-section"> </p><p class="ck-section">【九局上】</p><p class="ck-section"><strong><u>小熊隊更換投手：Ryan Pressly</u></strong></p><p class="ck-section">第七棒 Michael Conforto：二壘方向滾地球刺殺出局，一出局</p><p class="ck-section">第八棒 Miguel Rojas：四壞球保送，一出局一壘有人</p><p class="ck-section">第九棒 Andy Pages：四壞球保送，一出局一、二壘有人</p><p class="ck-section">第一棒 大谷翔平：四壞球保送，一出局滿壘</p><p class="ck-section">第二棒 Tommy Edman：二壘方向滾地球形成雙殺，三人出局</p><p class="ck-section"> </p><p class="ck-section">【八局下】</p><p class="ck-section"><strong><u>道奇隊更換投手：Kirby Yates</u></strong></p><p class="ck-section">第六棒 Dansby Swanson：三振出局，一出局</p><p class="ck-section">第七棒 Pete Crow-Armstrong：三振出局，兩出局</p><p class="ck-section">第八棒 Carson Kelly：左外野方向平飛安打，兩出局一壘有人</p><p class="ck-section">第九棒 Jon Berti：二壘後方飛球接殺出局，三人出局</p><p class="ck-section"> </p><p class="ck-section">【八局上】</p><p class="ck-section"><strong><u>小熊隊更換投手：Porter Hodge </u></strong></p><p class="ck-section">第三棒 Teoscar Hernández：三壘方向滾地球刺殺出局，一出局</p><p class="ck-section">第四棒 Will Smith：四壞球保送，一出局一壘有人</p><p class="ck-section">第五棒 Max Muncy：二壘方向滾地球傳向一壘刺殺出局，跑者上到二壘，兩出局二壘有人</p><p class="ck-section">第六棒 Kiké Hernández：三振出局</p><p class="ck-section"> </p><p class="ck-section">【七局下】</p><p class="ck-section">道奇隊投手：Landon Knack</p><p class="ck-section">第三棒 Kyle Tucker：一壘上空高飛球接殺出局，一出局</p><p class="ck-section">第四棒 Michael Busch：三振出局，兩出局</p><p class="ck-section">第五棒 Matt Shaw：三振出局，三人出局</p><p class="ck-section"> </p><p class="ck-section">【七局上】</p><p class="ck-section"><strong><u>小熊隊更換投手：Julian Merryweather</u></strong></p><p class="ck-section">第七棒 Michael Conforto：四壞球保送，一壘有人</p><p class="ck-section">第八棒 Miguel Rojas：二壘方向滾地球形成雙殺，兩出局</p>
# </div>
# <div class="pagination">
# <ul>
# <li>
# <a aria-label="prev page" href="#"><i class="fa fa-fw fa-arrow-left"></i></a>
# </li>
# <li class="active">
# <a href="#">1</a>
# </li>
#
# <li>
# <a href="https://www.sportsv.net/articles/118233?page=2#article_top">2</a>
# </li>
#
# <li>
# <a href="https://www.sportsv.net/articles/118233?page=3#article_top">3</a>
# </li>
#
# <li>
# <a aria-label="next page" href="https://www.sportsv.net/articles/118233?page=2#article_top">
# <i class="fa fa-fw fa-arrow-right"></i>
# </a>
# </li>
# </ul>
# </div>
# <!-- 廣告欄位bottom -->
# <div class="adv01" style="margin:65px 0 15px; clear:both; min-height: 360px;">
# <p>請繼續往下閱讀</p>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_a_bottom","size":[[640,360],[640,480],[320,250],[1,1]],"mapping":[[[980,0],[[640,360],[640,480],[1,1]]],[[480,0],[[300,250],[1,1]]],[[0,0],[[300,250],[1,1]]]],"name":"sv_a_bottom"}</script>
# </div>
# </div>
# <!-- 文章標籤 -->
# <div id="tags">
# <h4>標籤</h4>
# <ul class="tagcloud-list">
# <li>
# <a class="tag-link" href="/tags/洛杉磯道奇">洛杉磯道奇</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/大谷翔平">大谷翔平</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/芝加哥小熊">芝加哥小熊</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/鈴木誠也">鈴木誠也</a>
# </li>
# <li>
# <a class="tag-link" href="/tags/佐佐木朗希">佐佐木朗希</a>
# </li>
# </ul>
# </div>
# <!-- /.文章內容 -->
# </div>
# <div class="col-md-3">
# <!-- 作者介紹卡片 -->
# <!-- 作者介紹卡片 -->
# <div class="author_card">
# <div class="author_default">
# <div class="author_pic">
# <a href="https://www.sportsv.net/authors/sportsveditor">
# <img alt="運動視界編輯" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/avatar/1/image/2024/04/deef6e89-57f3-4415-a978-2daf0c728cbb.jpg" width="100%"/>
# </a>
# </div>
# <div class="author_infon">
# <h4 class="name">運動視界編輯</h4>
# <p class="honor">大聯盟</p>
# </div>
# </div>
# <div class="author_sub">
# <ul class="list-unstyled list-inline list-social-icons">
# <li>
# <a class="social-white" href="https://www.facebook.com/SportsV.net/" target="_blank" title="追蹤粉絲團">
# <i class="fab fa-facebook-square fa-2x"></i>
# </a>
# </li>
# <li>
# <a class="social-white social-bookmark-sub" href="https://www.sportsv.net/authors/sportsveditor" target="_blank" title="追蹤作者">
# <i class="fas fa-bookmark fa-2x"></i>
# </a>
# </li>
# </ul>
# </div>
# <div class="author_featured">
# <div class="title">最新文章</div>
# <ul class="item">
# <li><a href="https://www.sportsv.net/articles/118646">NBA》Curry復甦輕鬆打  勇士痛宰太陽持續前進</a></li>
# <li><a href="https://www.sportsv.net/articles/118642">MLB》變了味的強投對決，Sean Murphy 復出首戰四打點率勇士收下系列賽開門紅</a></li>
# <li><a href="https://www.sportsv.net/articles/118606">NBA》仍需被解釋的決策 Taylor Jenkins的解僱謎團</a></li>
# </ul>
# </div>
# </div>
# <!-- /.作者介紹卡片 -->
# <!-- /.作者介紹卡片 -->
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# </div>
# </article>
# <!-- 文章頁面 - 未 滿 十 八 歲 禁 止 飲 酒 -->
# <div class="wine-legal legal wine-legal-disable">
# <span>禁</span>
# <span>止</span>
# <span>酒</span>
# <span>駕</span>
# <img alt="禁止酒駕未 滿十八歲禁止飲酒" height="38" loading="lazy" src="https://www.sportsv.net/assets/assets/icon_warning-qKdhhtgW.png" width="38"/>
# <span>未</span>
# <span>滿</span>
# <span>十</span>
# <span>八</span>
# <span>歲</span>
# <span>禁</span>
# <span>止</span>
# <span>飲</span>
# <span>酒</span>
# </div>
# <!-- 文章頁面 - 熱門文章 -->
# <section class="hot_articles">
# <div class="container">
# <h2 class="page-header">熱門文章</h2>
# </div>
# <div class="container-fluid">
# <div class="row">
# <div class="col-md-3">
# <div class="row">
# <div class="panel-default full">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118506">台灣職棒球場「新莊棒球場」導入纖維強度提升約1.7倍的全新人工草皮 採用美津濃棒球專用人工草皮「MS CRAFT BASEBALL TURF-V」</a>
# </h3>
# </div>
# <a href="https://www.sportsv.net/articles/118506">
# <div class="mask"></div>
# <div class="fill"><img alt="台灣職棒球場「新莊棒球場」導入纖維強度提升約1.7倍的全新人工草皮 採用美津濃棒球專用人工草皮「MS CRAFT BASEBALL TURF-V」" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg 1200w"/></div>
# </a>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <div class="row">
# <div class="panel-default half">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118601">《鏡象閒話》戰報第一篇：詹子賢的棒次安排</a>
# </h3>
# </div>
# <a href="#">
# <!-- <div class="mask"></div> -->
# <div class="fill bg-gray-lighter"></div>
# </a>
# </div>
# </div>
# <div class="row">
# <div class="panel-default half">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118610">五年熬出頭，鄭宗哲成史上第 18 位大聯盟台將</a>
# </h3>
# </div>
# <a href="#">
# <!-- <div class="mask"></div> -->
# <div class="fill bg-specia"></div>
# </a>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <div class="row">
# <div class="panel-default full">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118600">【MLB2025】單場三響砲對決連三場開轟，天使強勢解決守護者打出新風采</a>
# </h3>
# </div>
# <a href="https://www.sportsv.net/articles/118600">
# <div class="mask"></div>
# <div class="fill"><img alt="【MLB2025】單場三響砲對決連三場開轟，天使強勢解決守護者打出新風采" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2025/04/9a6570c2-b5d0-41de-99f4-6b34f6bf09f4.jpg 1200w"/></div>
# </a>
# </div>
# </div>
# </div>
# <div class="col-md-3">
# <div class="row">
# <div class="panel-default half">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118581">O3站前話中職(2025 Week 1+2)-鳴槍起跑猿跌倒，乘勢而起龍飛高。</a>
# </h3>
# </div>
# <a href="#">
# <!-- <div class="mask"></div> -->
# <div class="fill bg-specia"></div>
# </a>
# </div>
# </div>
# <div class="row">
# <div class="panel-default half">
# <div class="panel-heading">
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# </div>
# <div class="panel-body">
# <h3>
# <a href="https://www.sportsv.net/articles/118438">到底要怎麼打才有長打...失去優勢的蘇智傑如何再起？</a>
# </h3>
# </div>
# <a href="#">
# <!-- <div class="mask"></div> -->
# <div class="fill bg-gray-lighter"></div>
# </a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </section>
# <!-- Footer -->
# <footer>
# <div class="container inner">
# <div class="row">
# <div class="col-md-5 col-sm-6">
# <a class="navbar-brand" href="/"><img alt="運動視界" height="100%" loading="lazy" src="https://www.sportsv.net/assets/images/logo.svg" title="運動視界" width="203"/></a>
# <h4>愛你的運動，秀你的視界！</h4>
# <p>
#                 《運動視界》是一個「為了帶給喜愛運動的朋友們收穫與感動而存在的組織、平台與社群」，希望讓大家每天能樂在其中，一起發掘，專屬於你的運動見解。
#                 </p>
# </div>
# <div class="col-md-5 col-md-offset-2 col-sm-6">
# <ul class="list-unstyled list-inline list-social-icons">
# <li>
# <a aria-label="feacbook link" href="https://www.facebook.com/SportsV.net" target="_blank">
# <i class="fab fa-facebook-square"></i>
# </a>
# </li>
# <li>
# <a aria-label="instagram link" href="https://www.instagram.com/sportsvnet/" target="_blank">
# <i class="fab fa-instagram"></i>
# </a>
# </li>
# <li>
# <a aria-label="line link" href="http://line.me/ti/p/%40gec9366m" target="_blank">
# <i class="fab fa-line"></i>
# </a>
# </li>
# <li>
# <a aria-label="rss link" href="/feed" rel="alternate" target="_blank" type="application/rss+xml">
# <i class="fas fa-rss-square"></i>
# </a>
# </li>
# </ul>
# <div class="subscription">
# <h5 class="title">訂閱運動視界電子報</h5>
# <a href="/member/newsletter" target="_blank">
# <form autocomplete="off" class="fbds-search__form fbds-search__form--open" id="templates-search-form" method="get">
# <input class="fbds-search__input" id="subscribe-newsletter-email" name="search" readonly="" required="" type="search"/>
# <a class="fbds-search__icon" href="/member/newsletter" target="_blank">訂閱</a>
# </form>
# </a>
# </div>
# </div>
# <div class="col-sm-12">
# <div class="widget">
# <div class="row">
# <div class="col-sm-3 col-xs-6">
# <ul class="post-list">
# <li>
# <h6>關於運動視界</h6>
# </li>
# <li>
# <h6>
# <a href="https://www.tnlmediagene.com/zh-tw/media/sportsv" target="_blank">關於我們</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/joinauthors">成為作者</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/qa">常見問題</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/announce">站方公告</a>
# </h6>
# </li>
# </ul>
# </div>
# <div class="col-sm-3 col-xs-6">
# <ul class="post-list">
# <li>
# <h6>作者相關權益</h6>
# </li>
# <li>
# <h6>
# <a href="/terms">服務條款</a>
# </h6>
# </li>
# <li>
# <h6>
# <a href="/authorterms">作者條款</a>
# </h6>
# </li>
# </ul>
# </div>
# <div class="col-sm-6 col-xs-12">
# <ul class="post-list">
# <li>
# <h6>聯絡我們</h6>
# </li>
# <li><h6>
# <a href="mailto:contactus@sportsv.net" target="_blank">內容檢舉、其他意見<span>contactus@sportsv.net</span></a>
# </h6>
# </li>
# <li><h6><a href="mailto:editor@sportsv.net" target="_blank">新聞採訪、作者發文相關問題<span>editor@sportsv.net</span></a></h6></li>
# <li><h6><a href="mailto:sales@sportsv.net" target="_blank">廣告採購、授權詢問、業務相關合作<span>sales@sportsv.net</span></a></h6></li>
# <li><h6><a href="mailto:partnership@sportsv.net" target="_blank">非業務相關行銷合作洽詢<span>partnership@sportsv.net</span></a></h6></li>
# </ul>
# </div>
# </div>
# <!-- /.post-list -->
# </div>
# <!-- /.widget -->
# </div>
# </div>
# </div>
# <tnlmedia-footer lang="zh-tw"></tnlmedia-footer>
# </footer>
# <!-- Float -->
# <div>
# <div class="tmgad tmgad-type-flux tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"flux","slot":"\/21870649235\/sv_all_float_inner","size":[[1,1]],"mapping":[[[0,0],[[1,1]]]],"name":"sv_all_float_inner"}</script>
# </div>
# </div>
# <link href="https://www.sportsv.net/assets/assets/vendor-BIB0qm4L.js" rel="modulepreload"/><link href="https://www.sportsv.net/assets/assets/_commonjsHelpers-Cpj98o6Y.js" rel="modulepreload"/><script src="https://www.sportsv.net/assets/assets/vendor-BIB0qm4L.js" type="module"></script> <link href="https://www.sportsv.net/assets/assets/main-kUc6ua8r.js" rel="modulepreload"/><script src="https://www.sportsv.net/assets/assets/main-kUc6ua8r.js" type="module"></script>
# <link href="https://www.sportsv.net/assets/assets/article-D8puTOd8.js" rel="modulepreload"/><link href="https://www.sportsv.net/assets/assets/_commonjsHelpers-Cpj98o6Y.js" rel="modulepreload"/><script src="https://www.sportsv.net/assets/assets/article-D8puTOd8.js" type="module"></script>
# <script src="https://s.skimresources.com/js/255443X1762629.skimlinks.js" type="text/javascript"></script>
# <div>
# <div class="tmgad tmgad-type-general tmgad-new">
# <script type="application/json">{"targeting":{"tag_key":["162","220","1862","19656","32474"],"tag_name":["\u6d1b\u6749\u78ef\u9053\u5947","\u5927\u8c37\u7fd4\u5e73","\u829d\u52a0\u54e5\u5c0f\u718a","\u9234\u6728\u8aa0\u4e5f","\u4f50\u4f50\u6728\u6717\u5e0c"],"author_key":["sportsveditor"],"author_name":["\u904b\u52d5\u8996\u754c\u7de8\u8f2f"],"category_key":["mlb","baseball"],"category_name":["MLB","\u68d2\u7403"],"page_key":["articles"],"page_name":["articles"],"cabinet":["830523"]},"type":"general","slot":"\/21870649235\/sv_all_bottom_mobile_special","size":[[320,100],[1,1]],"mapping":[[0,0],[[320,100],[1,1]]],"name":"sv_all_bottom_mobile_special"}</script>
# </div>
# </div>
# </body>
# </html>

# %%
content_div = page.find('div', class_='article-content')
paragraphs = content_div.find_all('p')
content = ''.join([p.get_text(strip=True) for p in paragraphs])
content = re.sub(r'1.大谷翔平.*', '', content)
content
# Out:
# '2025 大聯盟賽季在昨日（3/19）於東京巨蛋正式拉開帷幕，這不僅是大聯盟歷史上首次的日本投手（山本由伸對決今永昇太）於開幕戰對決，更是包含兩人在內的五名日本好手重返家鄉、在鄉親父老面前大展身手的絕佳機會。除了陣中日本好手返鄉比賽的這層意義外，與日本淵源頗深的芝加哥小熊與洛杉磯道奇 2025 賽季同樣充滿話題。繼 2000 年後再度來到東京巨蛋舉行海外開幕戰的小熊隊，在主要陣容沒有太多變動的情況下，休賽季引進了將於季後投入自由市場的明星外野手Kyle Tucker，搭配聯盟前段的先發投手群以及守備，在總教練 Craig Counsell 第二年的領軍下能否暌違五年之後再度於完整賽季重返季後賽將備受關注。2024 年世界大賽冠軍道奇隊並未因順利登頂而在這個休賽季停下補強的腳步，不惜持續推高團隊薪資以及被冠上新生代「邪惡帝國」的標籤，也要引進 Blake Snell、Tanner Scott 和佐佐木朗希等堅實的戰力，都宣示了他們成為 21 世紀第一支成功衛冕冠軍隊伍的企圖心。究竟大聯盟會不會睽違 25 年再度出現連續兩年登頂成功的隊伍？絕對是新賽季的一大看點。'

# %% [markdown]
# # Let's crawl all of them
#
# 針對每一個連結項目抓出標題、連結、日期等資訊

# %%
import requests
from bs4 import BeautifulSoup
import re
from datetime import datetime
import time

# %%
category_url = 'https://www.sportsv.net/baseball/mlb'

# req = requests.get(category_url)
req = requests.get(category_url, headers={ 'user-agent': user_agent.random })

# page = BeautifulSoup(req.text, 'lxml')
page = BeautifulSoup(req.text, 'html.parser')

# %%
req.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-Hant-TW">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <meta name="_token" content="37ACK2y0tliBKoN6yAs6u2D33wE3XjYqp7pmWe2g"/>\n        <link rel="shortcut icon" href="https://www.sportsv.net/assets/images/favicon.ico" type="image/x-icon">\n        <title>MLB | 運動視界 Sports Vision</title>\n<meta name="description" content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler">\n<link rel="canonical" href="https://www.sportsv.net/baseball/mlb">\n        <meta property="og:title" content="MLB | 運動視界 Sports Vision">\n<meta property="og:description" content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler">\n<meta property="og:url" content="https://www.sportsv.net/baseball/mlb">\n<meta property="og:site_name" content="運動視界 Sports Vision">\n<meta property="og:locale" content="zh_TW">\n<meta property="og:image" content="https://www.sportsv.net/assets/images/social-share.jpg">\n\n        <meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="運動視界 Sports Vision">\n<meta name="twitter:creator" content="運動視界 Sports Vision">\n<meta name="twitter:title" content="MLB | 運動視界 Sports Vision">\n<meta name="twitter:description" content="MLB就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差... 相關標籤: 聖路易紅雀,匹茲堡海盜,突破僵局制,大聯盟初登場,鄭宗哲,Erick Fedde,Mitch Keller,Tsung-Che Cheng,Joey Bart,底特律老虎,紐約洋基,Paul Goldschmidt,Aaron Judge,Tarik Skubal,Dillon Dingler">\n\n        <meta name="robots" content="all">\n\n        <link rel="preload" as="style" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" /><link rel="preload" as="style" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" /><link rel="stylesheet" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" /><link rel="stylesheet" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" />        <script>\n          window.pbjs = window.pbjs || {que: []};\n                window.googletag = window.googletag || {cmd: []};\n      </script>\n  <script async src="https://flux-cdn.com/client/1000265/sportsv_01465.min.js"></script>\n  <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>\n  <script>\n    window.fluxtag = {\n      readyBids: {prebid: false, amazon: false, google: false},\n      failSafeTimeout: 3000,\n      isFn: function (object) {\n        var _t = \'Function\';\n        var toString = Object.prototype.toString;\n        return toString.call(object) === \'[object \' + _t + \']\';\n      },\n      launchAdServer: function () {\n        if (!fluxtag.readyBids.prebid || !fluxtag.readyBids.amazon) {\n          return;\n        }\n        fluxtag.requestAdServer();\n      },\n      requestAdServer: function () {\n        if (!fluxtag.readyBids.google) {\n          fluxtag.readyBids.google = true;\n          googletag.cmd.push(function () {\n            if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {\n              pbjs.que.push(function () { pbjs.setTargetingForGPTAsync(); });\n            }\n            googletag.pubads().refresh();\n          });\n        }\n      },\n      renderAds: function (lines, failSafeTimeout) {\n        googletag.cmd.push(function () {\n          var failSafeTimeout = failSafeTimeout || window.fluxtag.failSafeTimeout;\n          var bidRequestTimeout = (failSafeTimeout - 500) > 0 ? failSafeTimeout - 500 : failSafeTimeout;\n          var refreshLines = [];\n          var param ...

# %%
# 抓新聞列表
items = newpage.findAll('div',{'class':"row item"})
items
# Out:
# [<div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/118662">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/10</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/118662">【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰</a>
#  </h3>
#  <p class="description">就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮相，被安排鎮守游擊大關並出任打線第九棒，防守功夫到位不說，首安與首盜也差一點就能出現，整體展現可圈可點值得驕傲。一路相持不下的兩隊，是激戰到突破僵局的第十三局才分出勝負，紅雀牛棚自找麻煩堆成滿壘，Joey Bart一棒就讓比賽畫下句點，究竟賽況與鄭宗哲表現為何，以下一同回顧。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118662">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/聖路易紅雀">聖路易紅雀</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/匹茲堡海盜">匹茲堡海盜</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/突破僵局制">突破僵局制</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/大聯盟初登場">大聯盟初登場</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/鄭宗哲">鄭宗哲</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Erick Fedde">Erick Fedde</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Mitch Keller">Mitch Keller</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Tsung-Che Cheng">Tsung-Che Cheng</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Joey Bart">Joey Bart</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/118640">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/09</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/118640">【MLB2025】捕手不同卻是一樣的賽揚實力，Tarik Skubal完美出擊助老虎咬傷洋基</a>
#  </h3>
#  <p class="description">近期橫掃白襪取得連勝的老虎，本週是在主場迎接強火軍團洋基來犯，首戰就已出色壓制延續連勝，這日續由賽揚強投達成封鎖並要到5連勝。即便主戰捕手臨時因傷缺陣，但總教練的未雨綢繆是起到效用，接手任務的Dillon Dingler不僅出色執行，打擊更有亮眼發揮，其與Tarik Skubal如何率隊前行，以下一同回顧。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118640">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/底特律老虎">底特律老虎</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/紐約洋基">紐約洋基</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Paul Goldschmidt">Paul Goldschmidt</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Aaron Judge">Aaron Judge</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Tarik Skubal">Tarik Skubal</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/Dillon Dingler">Dillon Dingler</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/A.J.Hinch">A.J.Hinch</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/83288">
#  <div class="panel-default">
#  <div class="sponsor right top">BRAND STUDIO</div>
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg 1200w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2021/04/29</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/83288">棒球迷的最佳選擇：最新《MLB九局職棒21》，帶給玩家更愛不釋手的遊戲體驗</a>
#  </h3>
#  <p class="description">MLB九局職棒推出2021年版本，將整個介面大幅改版，讓玩家可以在最舒適的環境中盡情享受遊戲體驗。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/svspy"><img alt="合作夥伴" loading="lazy" src="https://www.sportsv.net/assets/images/level-role-icon2.png" title="合作夥伴"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/svspy">運動特務</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/83288">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/Mlb">Mlb</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/陳金鋒">陳金鋒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/棒球">棒球</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/王建民">王建民</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/職棒">職棒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/九局職棒">九局職棒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/MLB九局職棒21">MLB九局職棒21</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/118618">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/09</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/118618">日職農場化、「有原式」FA 的質疑：探析入札制度所掀起的陣陣漣漪</a>
#  </h3>
#  <p class="description">為了能邁向更高層級去挑戰，「入札制度」是不少日本球員會選擇的管道，行之有年且造就不少好手，站上世界舞台的前端，是職業棒球合作交流的良好展現。不過近年風氣與思維方面的轉變，使得美意產生些許質疑聲音，包含日職是否會進入農場化，海歸後轉投他隊的另類FA等，本文將就此制度所帶出的漣漪，藉由自身角度分享看法。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/paipaijesus12130906"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/paipaijesus12130906">圓周率</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118618">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/Mlb">Mlb</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/日本職棒">日本職棒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/大谷翔平">大谷翔平</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/有原航平">有原航平</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/入札制度">入札制度</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/上澤直之">上澤直之</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/佐佐木朗希">佐佐木朗希</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/農場化">農場化</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/有原式FA">有原式FA</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/假旅外">假旅外</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/118642">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/a4640b2c-e044-47b9-9330-8eec9498ac1d.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/a4640b2c-e044-47b9-9330-8eec9498ac1d.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/a4640b2c-e044-47b9-9330-8eec9498ac1d.jpg 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/09</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/118642">MLB》變了味的強投對決，Sean Murphy 復出首戰四打點率勇士收下系列賽開門�
.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/db875f94-f5cd-4729-bd26-29ba80f8da5e.jpg 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/04/07</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/mlb">MLB</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/118386">《站上顛峰的武士》─ 村神的經典一擊！日本武士起死回生挺進冠軍戰</a>
#  </h3>
#  <p class="description">日本休息室所有人都衝上了場，簇擁著打出經典一擊的村上。「兩隊都打出了精彩表現，兩隊的投球也都出色。沒有哪隊想過要放棄，雖然是日本晉級，但這一晚，是屬於棒球界的勝利！」</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/sportsveditor"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118386">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/棒球">棒球</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/大谷翔平">大谷翔平</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/日職">日職</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/書摘">書摘</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/站上顛峰的武士">站上顛峰的武士</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/畢方出版">畢方出版</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>]

# %%
category = 'MLB'


# 存放資料之變數
article_link_list =[]
title_list=[]
date_list=[]
category_list=[]
photo_link_list=[]

item_id_list=[]
content_list=[]


serial_no = 1

for item in items:

    #新聞標題
    title = item.find('h3').text.strip()
    cont = re.sub(r'.*(東京賽》|MLB》)', '', title)
    print( cont )

    #新聞日期
    news_time = item.find('div', {'class':"date"}).text
    print(news_time)
    dtime = datetime.strptime(news_time, '%Y/%m/%d')
    news_date = dtime.strftime("%Y-%m-%d")
    
    #新聞連結
    article_url = item.find('a').get('href')
    print(article_url)

    # 最新的新聞列表之新聞連結:開頭缺少"https://www.cna.com.tw"
    # if article_url.startswith("/news"):
    #     article_url = "https://www.cna.com.tw"+article_url
    #     article_link_list.append(article_url)
    # else:
    #     article_link_list.append(article_url)
    
    


    try:
    # Use if else to deal with it
        if item.find('img').get('src'):
            photo_link = item.find('img').get('src')
    except:
        print('No photo link!')
        photo_link=''
    
    print(photo_link)

    
    category_list.append(category)
    date_list.append(news_date)
    title_list.append(cont)
    photo_link_list.append(photo_link)
    article_link_list.append(article_url)
    
    # item id
    date_str = dtime.strftime("%Y%m%d")

    item_id_list.append("sportsv_" + date_str + "_" + str(serial_no))
    serial_no += 1

    ##### Crawl article content爬新聞內容
    # There are some words we don't like to analyze, They should be removed.
    req = requests.get(article_url, headers={ 'user-agent': user_agent.random }, timeout=5)
    
    # page = BeautifulSoup(req.text,'lxml')
    page = BeautifulSoup(req.text, 'html.parser')

    # Find content
    content_div = page.find('div', class_='article-content')
    paragraphs = content_div.find_all('p')
    content = ''.join([p.get_text(strip=True) for p in paragraphs])
    content = re.sub(r'1.大谷翔平.*', '', content)
    content


    # Remove unnecessary content
    # Remove "透過 Google News追蹤中央社"
    # try:
    #     content.find('div', {'class':"gmailNews"}).decompose()
    # except:
    #     pass

    # # Remove "訂閱早安電子報"
    # try:
    #     content.find('div', {'class':"subscriInnTitle"}).decompose()
    # except:
    #     pass

    # # 額外插入的訂閱連結-->移除之
    # try:
    #     content.find('div', {'class':"SubscriptionInner mySubscriptionInner"}).decompose()
    # except:
    #     pass

    # # 額外插入的延伸閱讀區塊-->移除之
    # try:
    #     content.find('div', {'class':"paragraph moreArticle"}).decompose()
    # except:
    #     pass
    # # 額外插入的圖片與文字說明區塊-->移除之
    # try:
    #     for media in content.findAll('div', {'class':"media"}):
    #         media.decompose()
    # except:
    #     pass

    # Remove unnecessary content
    # cont = content.text
    # cont = re.sub('（中央社.+?）','', cont)
    # cont = re.sub('（編輯：.*','', cont) 
    # cont = re.sub('（譯者：.*','', cont) 
    
    content_list.append(content)
    
    # scrap only 10 articles
    if serial_no >= 10:
        break
    
    time.sleep(10)  # 遵守爬蟲禮節，請小睡一下
# Out:
# 【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰
# 2025/04/10
# https://www.sportsv.net/articles/118662
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6c6ce76b-2b27-4ec1-9ec5-b41109a191cd.jpg
# 【MLB2025】捕手不同卻是一樣的賽揚實力，Tarik Skubal完美出擊助老虎咬傷洋基
# 2025/04/09
# https://www.sportsv.net/articles/118640
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/6a5fa131-601e-469d-b7d2-ef9c308e9b1e.jpg
# 棒球迷的最佳選擇：最新《MLB九局職棒21》，帶給玩家更愛不釋手的遊戲體驗
# 2021/04/29
# https://www.sportsv.net/articles/83288
# https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/23f92161-f769-4424-9cb6-c4f892164f25.jpg
# 日職農場化、「有原式」FA 的質疑：探析入札制度所掀起的陣陣漣漪
# 2025/04/09
# https://www.sportsv.net/articles/118618
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/38d510f9-94ae-40ed-905d-123a762fbec0.png
# 變了味的強投對決，Sean Murphy 復出首戰四打點率勇士收下系列賽開門紅
# 2025/04/09
# https://www.sportsv.net/articles/118642
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/a4640b2c-e044-47b9-9330-8eec9498ac1d.jpg
# 自始至終的第二順位，Vladimir Guerrero Jr. 是如何簽下五億的延長合約？
# 2025/04/08
# https://www.sportsv.net/articles/118605
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/4d69a740-cdbd-4560-9fd4-c0a108ac8e60.jpg
# 【MLB2025】Francisco Lindor達陣生涯1500安，力挺千賀滉大擊敗馬林魚勝投開胡
# 2025/04/08
# https://www.sportsv.net/articles/118615
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/602c8f19-14a5-475e-a7c8-72321285f9d1.png
# 農場淬鍊脫穎而出，旅美小將鄭宗哲晉升匹茲堡海盜隊一員
# 2025/04/08
# https://www.sportsv.net/articles/118617
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/27b47ea5-cfdf-4c8b-9694-886c54d35eb1.jpg
# 大破大立刪減薪資開創王朝盛事，洛杉磯道奇如何一步步成為「邪惡帝國」？
# 2025/04/08
# https://www.sportsv.net/articles/118544
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/0ca05b56-87be-4888-816c-9453ad4058fc.jpg

# %%
len(article_link_list)
# Out:
# 9

# %%
item_id_list
# Out:
# ['sportsv_20250410_1',
#  'sportsv_20250409_2',
#  'sportsv_20210429_3',
#  'sportsv_20250409_4',
#  'sportsv_20250409_5',
#  'sportsv_20250408_6',
#  'sportsv_20250408_7',
#  'sportsv_20250408_8',
#  'sportsv_20250408_9']

# %%
title_list
# Out:
# ['【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰',
#  '【MLB2025】捕手不同卻是一樣的賽揚實力，Tarik Skubal完美出擊助老虎咬傷洋基',
#  '棒球迷的最佳選擇：最新《MLB九局職棒21》，帶給玩家更愛不釋手的遊戲體驗',
#  '日職農場化、「有原式」FA 的質疑：探析入札制度所掀起的陣陣漣漪',
#  '變了味的強投對決，Sean Murphy 復出首戰四打點率勇士收下系列賽開門紅',
#  '自始至終的第二順位，Vladimir Guerrero Jr. 是如何簽下五億的延長合約？',
#  '【MLB2025】Francisco Lindor達陣生涯1500安，力挺千賀滉大擊敗馬林魚勝投開胡',
#  '農場淬鍊脫穎而出，旅美小將鄭宗哲晉升匹茲堡海盜隊一員',
#  '大破大立刪減薪資開創王朝盛事，洛杉磯道奇如何一步步成為「邪惡帝國」？']

# %% [markdown]
# ## Put them into pandas dataframe and save

# %% [markdown]
# #### 先將資料組合在一起，zip縫起來

# %%
import pandas as pd

# %%
data = zip(item_id_list,date_list, title_list,category_list,content_list,article_link_list,photo_link_list)
df = pd.DataFrame(list(data), columns=['item_id','date','title','category','content','link','photo_link'])

# %%
df.head(3)
# Out:
#               item_id        date  \
# 0  sportsv_20250410_1  2025-04-10
# 1  sportsv_20250409_2  2025-04-09
# 2  sportsv_20210429_3  2021-04-29
#
#                                             title category  \
# 0     【MLB25:臺將出擊】鄭宗哲大聯盟初體驗，海盜Joey Bart擊落紅雀終結延長激戰      MLB
# 1  【MLB2025】捕手不同卻是一樣的賽揚實力，Tarik Skubal完美出擊助老虎咬傷洋基      MLB
# 2           棒球迷的最佳選擇：最新《MLB九局職棒21》，帶給玩家更愛不釋手的遊戲體驗      MLB
#
#                                              content  \
# 0  《看看MLB25-27》就在今晨的海盜紅雀系列最終戰，臺灣好手鄭宗哲迎來自己大聯盟生涯的初亮...
# 1  《看看MLB25-25》近期橫掃白襪取得連勝的老虎，本週是在主場迎接強火軍團洋基來犯，首戰就...
# 2  約莫在2005年，王建民在大聯盟的表現開始加溫，從2005年的8勝到2006年、2007年的...
#
#                                       link  \
# 0  https://www.sportsv.net/articles/118662
# 1  https://www.sportsv.net/articles/118640
# 2   https://www.sportsv.net/articles/83288
#
#                                           photo_link
# 0  https://bucket-image.inkmaginecms.com/version/...
# 1  https://bucket-image.inkmaginecms.com/version/...
# 2  https://bucket-image.inkmaginecms.com/version/...

# %%
df.shape
# Out:
# (9, 7)

# %% [markdown]
# ## Save

# %%
df.to_csv("sportsv_baseball_categroy.csv", sep="|", index=False, mode='a', header=False)

# %% [markdown]
# 中華職棒

# %%
category_url = 'https://www.sportsv.net/baseball/cpbl'

# req = requests.get(category_url)
req = requests.get(category_url, headers={ 'user-agent': user_agent.random })

# page = BeautifulSoup(req.text, 'lxml')
page = BeautifulSoup(req.text, 'html.parser')

# %%
req.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-Hant-TW">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <meta name="_token" content="QuTgZo6S4THqHLCcln0DOjwbkfAu1KO0FyqsNwzw"/>\n        <link rel="shortcut icon" href="https://www.sportsv.net/assets/images/favicon.ico" type="image/x-icon">\n        <title>中職 | 運動視界 Sports Vision</title>\n<meta name="description" content="中職比賽前半段，雙方有來有往互有領先，但到比賽後半段，兩隊陷入僵局，一直到突破僵局制，靠著林佳緯、林子豪的長打攻下大局，最終也幫助統一獅中止近期... 相關標籤: 中華職棒,統一獅,例行賽,林子豪,台鋼雄鷹,林佳緯,中信兄弟,味全龍,黃恩賜,陳冠偉,中華職棒逐場戰報,鋼龍,羅戈,關鍵暴投,棒球">\n<link rel="canonical" href="https://www.sportsv.net/baseball/cpbl">\n        <meta property="og:title" content="中職 | 運動視界 Sports Vision">\n<meta property="og:description" content="中職比賽前半段，雙方有來有往互有領先，但到比賽後半段，兩隊陷入僵局，一直到突破僵局制，靠著林佳緯、林子豪的長打攻下大局，最終也幫助統一獅中止近期... 相關標籤: 中華職棒,統一獅,例行賽,林子豪,台鋼雄鷹,林佳緯,中信兄弟,味全龍,黃恩賜,陳冠偉,中華職棒逐場戰報,鋼龍,羅戈,關鍵暴投,棒球">\n<meta property="og:url" content="https://www.sportsv.net/baseball/cpbl">\n<meta property="og:site_name" content="運動視界 Sports Vision">\n<meta property="og:locale" content="zh_TW">\n<meta property="og:image" content="https://www.sportsv.net/assets/images/social-share.jpg">\n\n        <meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="運動視界 Sports Vision">\n<meta name="twitter:creator" content="運動視界 Sports Vision">\n<meta name="twitter:title" content="中職 | 運動視界 Sports Vision">\n<meta name="twitter:description" content="中職比賽前半段，雙方有來有往互有領先，但到比賽後半段，兩隊陷入僵局，一直到突破僵局制，靠著林佳緯、林子豪的長打攻下大局，最終也幫助統一獅中止近期... 相關標籤: 中華職棒,統一獅,例行賽,林子豪,台鋼雄鷹,林佳緯,中信兄弟,味全龍,黃恩賜,陳冠偉,中華職棒逐場戰報,鋼龍,羅戈,關鍵暴投,棒球">\n\n        <meta name="robots" content="all">\n\n        <link rel="preload" as="style" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" /><link rel="preload" as="style" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" /><link rel="stylesheet" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" /><link rel="stylesheet" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" />        <script>\n          window.pbjs = window.pbjs || {que: []};\n                window.googletag = window.googletag || {cmd: []};\n      </script>\n  <script async src="https://flux-cdn.com/client/1000265/sportsv_01465.min.js"></script>\n  <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>\n  <script>\n    window.fluxtag = {\n      readyBids: {prebid: false, amazon: false, google: false},\n      failSafeTimeout: 3000,\n      isFn: function (object) {\n        var _t = \'Function\';\n        var toString = Object.prototype.toString;\n        return toString.call(object) === \'[object \' + _t + \']\';\n      },\n      launchAdServer: function () {\n        if (!fluxtag.readyBids.prebid || !fluxtag.readyBids.amazon) {\n          return;\n        }\n        fluxtag.requestAdServer();\n      },\n      requestAdServer: function () {\n        if (!fluxtag.readyBids.google) {\n          fluxtag.readyBids.google = true;\n          googletag.cmd.push(function () {\n            if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {\n              pbjs.que.push(function () { pbjs.setTargetingForGPTAsync(); });\n            }\n            googletag.pubads().refresh();\n          });\n        }\n      },\n      renderAds: function (lines, failSafeTimeout) {\n        googletag.cmd.push(function () {\n          var failSafeTimeout = failSafeTimeout || window.fluxtag.failSafeTimeout;\n          var bidRequestTimeout = (failSafeTimeout - 500) > 0 ? failSafeTimeout - 500 : failSafeTimeout;\n          var refreshLines = [];\n          var params = (function () {\n            var readyBids = {amazon: false, google: false, prebid: false};\n            var definedSlots = [];\n            var adsInfo = {\n              gpt: {slots: [], displayDivIds: []},\n              aps: {slots: [], divIds ...

# %%
cpbl_items = page.findAll('div',{'class':"row item"})
cpbl_items
# Out:
# [<div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/118506">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2025/04/02</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/118506">台灣職棒球場「新莊棒球場」導入纖維強度提升約1.7倍的全新人工草皮 採用美津濃棒球專用人工草皮「MS CRAFT BASEBALL TURF-V」</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/sales"><img alt="合作夥伴" loading="lazy" src="https://www.sportsv.net/assets/images/level-role-icon2.png" title="合作夥伴"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/sales">廣編企劃</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118506">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/118601">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/93f94baf-d40e-46a2-b612-bcff78d48228.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/93f94baf-d40e-46a2-b612-bcff78d48228.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/93f94baf-d40e-46a2-b612-bcff78d48228.jpg 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2025/04/07</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/118601">《鏡象閒話》戰報第一篇：詹子賢的棒次安排</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/ahutopian"><img alt="特約名家" loading="lazy" src="https://www.sportsv.net/assets/images/level-role-icon4.png" title="特約名家"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/ahutopian">AhUtopian/烏托邦/余大</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118601">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/118581">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/2e825f05-019f-47b5-92ad-05699201391d.png" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/2e825f05-019f-47b5-92ad-05699201391d.png 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/04/2e825f05-019f-47b5-92ad-05699201391d.png 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2025/04/07</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/118581">O3站前話中職(2025 Week 1+2)-鳴槍起跑猿跌倒，乘勢而起龍飛高。</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/daikankyohou"><img alt="榮譽名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-role-icon3.png" title="榮譽名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/daikankyohou">大艦巨砲主義萬歲！</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/118581">
#  <i class="fa fa-comments"></i>74</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/
/>
# </a>
# </div>
# </div>
# <div class="col-xs-12 col-md-7 infon">
# <div class="date">2025/04/07</div>
# <ul class="crumb">
# <li>
# <a href="https://www.sportsv.net/baseball">棒球</a>
# <i class="fa fa-chevron-right"></i>
# </li>
# <li>
# <a href="https://www.sportsv.net/baseball/cpbl">中職</a>
# </li>
# </ul>
# <h4>
# <a href="https://www.sportsv.net/articles/118601">《鏡象閒話》戰報第一篇：詹子賢的棒次安排</a>
# </h4>
# <div class="author">
# <a class="author_status" href="https://www.sportsv.net/authors/ahutopian"><img alt="特約名家" loading="lazy" src="https://www.sportsv.net/assets/images/level-role-icon4.png" title="特約名家"/></a>
# <a class="author_name" href="https://www.sportsv.net/authors/ahutopian">AhUtopian/烏托邦/余大</a>
# <a class="author_comments" href="https://www.sportsv.net/articles/118601">
# <i class="fa fa-comments"></i>0</a>
# </div>
# </div>
# </div>

# %%
item.find('h4').text.strip()
# Out:
# '《鏡象閒話》戰報第一篇：詹子賢的棒次安排'

# %%
category = '中職'

serial_no = 1

# 存放資料之變數
article_link_list = []
title_list = []
date_list = []
category_list = []
photo_link_list = []

item_id_list = []
content_list = []

for item in cpbl_items:
    # 新聞標題
    title = (item.find('h3') or item.find('h4')).text.strip() if (item.find('h3') or item.find('h4')) else None
    print(title)

    # 如果標題為 None，則跳過這篇新聞
    if title is None or title == "":
        print("標題為空，跳過這篇新聞。")
        continue

    # 新聞日期
    news_time = item.find('div', {'class': "date"}).text.strip() if item.find('div', {'class': "date"}) else ""
    print(news_time)

    # 新聞連結
    article_url = item.find('a').get('href')
    print(article_url)

    try:
        # Use if else to deal with it
        if item.find('img').get('src'):
            photo_link = item.find('img').get('src')
    except:
        print('No photo link!')
        photo_link = ''

    print(photo_link)

    category_list.append(category)
    date_list.append(news_time)
    title_list.append(title)  # 修正了這裡的變數名稱
    photo_link_list.append(photo_link)
    article_link_list.append(article_url)

    # item id
    date_str = dtime.strftime("%Y%m%d")

    item_id_list.append("sportsv_" + date_str + "_" + str(serial_no))
    serial_no += 1

    ##### Crawl article content 爬新聞內容
    # There are some words we don't like to analyze, They should be removed.
    req = requests.get(article_url, headers={'user-agent': user_agent.random}, timeout=5)
    # page = BeautifulSoup(req.text, 'lxml')
    page = BeautifulSoup(req.text, 'html.parser')
    


    # Find content
    content_div = page.find('div', class_='article-content')
    paragraphs = content_div.find_all('p')
    content = ''.join([p.get_text(strip=True) for p in paragraphs])
    content

    content_list.append(content)

    # scrap only 10 articles
    if serial_no >= 10:
        break

    time.sleep(10)  # 遵守爬蟲禮節，請小睡一下
# Out:
# 台灣職棒球場「新莊棒球場」導入纖維強度提升約1.7倍的全新人工草皮 採用美津濃棒球專用人工草皮「MS CRAFT BASEBALL TURF-V」
# 2025/04/02
# https://www.sportsv.net/articles/118506
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg
# 《鏡象閒話》戰報第一篇：詹子賢的棒次安排
# 2025/04/07
# https://www.sportsv.net/articles/118601
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/93f94baf-d40e-46a2-b612-bcff78d48228.jpg
# O3站前話中職(2025 Week 1+2)-鳴槍起跑猿跌倒，乘勢而起龍飛高。
# 2025/04/07
# https://www.sportsv.net/articles/118581
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/2e825f05-019f-47b5-92ad-05699201391d.png
# 到底要怎麼打才有長打...失去優勢的蘇智傑如何再起？
# 2025/04/07
# https://www.sportsv.net/articles/118438
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/7c56efd9-5733-4f3d-bea2-97cb5829cc2a.jpg
# 盧孟揚、陳冠穎、伍立辰無懼大場面，中信兄弟土投的未來希望？
# 2025/04/07
# https://www.sportsv.net/articles/118586
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/cf7ebe11-de37-48c6-bbb7-32f875815089.png
# 大象週報．象前衝(Week1+2)-新人投手開箱
# 2025/04/07
# https://www.sportsv.net/articles/118530
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/1eedc9e6-62f2-40b3-a942-d3429835bba1.jpg
# None
# 標題為空，跳過這篇新聞。
# 長打連發攻破雄鷹防線 統一獅中止四連敗
# 2025/04/09
# https://www.sportsv.net/articles/118651
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/a64989a7-2b1f-43f6-81ec-3b148dd19973.jpg
# 陳冠偉關鍵暴投種下敗因 味全龍終止開季五連勝
# 2025/04/09
# https://www.sportsv.net/articles/118622
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/606707aa-b883-456f-9736-f4771ba086f4.jpg
# 台灣職棒球場「新莊棒球場」導入纖維強度提升約1.7倍的全新人工草皮 採用美津濃棒球專用人工草皮「MS CRAFT BASEBALL TURF-V」
# 2025/04/02
# https://www.sportsv.net/articles/118506
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/bbbe37b8-9b6a-4931-a753-7f0e50894fd4.jpg

# %%
data = zip(item_id_list,date_list, title_list,category_list,content_list,article_link_list,photo_link_list)
df = pd.DataFrame(list(data), columns=['item_id','date','title','category','content','link','photo_link'])

# %%
df.to_csv("sportsv_baseball_categroy.csv", sep="|", index=False, mode='a', header=False)

# %% [markdown]
# 日職

# %%
category_url = 'https://www.sportsv.net/baseball/npb'

# req = requests.get(category_url)
req = requests.get(category_url, headers={ 'user-agent': user_agent.random })

# page = BeautifulSoup(req.text, 'lxml')
page = BeautifulSoup(req.text, 'html.parser')

# %%
req.text
# Out:
# '<!DOCTYPE html>\n<html lang="zh-Hant-TW">\n    <head>\n        <meta charset="utf-8">\n        <meta http-equiv="X-UA-Compatible" content="IE=edge">\n        <meta name="viewport" content="width=device-width, initial-scale=1">\n        <meta name="_token" content="rjvqwHZVa9jPsh01Tve0HmxoPGzhw1JhHMwZcTJ1"/>\n        <link rel="shortcut icon" href="https://www.sportsv.net/assets/images/favicon.ico" type="image/x-icon">\n        <title>日職 | 運動視界 Sports Vision</title>\n<meta name="description" content="日職日職史上僅三人達到的250次救援成功，近日則迎來一位新成員加入，效力歐力士15年的平野佳壽，於對戰羅德的關鍵時刻登板並成功關門，不僅讓他達到難得... 相關標籤: 日本職棒,Npb,歐力士猛牛,亞利桑那響尾蛇,終結者,守護神,名球會,平野佳壽,岸田護,250次救援成功,中日龍,廣島東洋鯉魚,小園海斗,末包昇大,堂林翔太">\n<link rel="canonical" href="https://www.sportsv.net/baseball/npb">\n        <meta property="og:title" content="日職 | 運動視界 Sports Vision">\n<meta property="og:description" content="日職日職史上僅三人達到的250次救援成功，近日則迎來一位新成員加入，效力歐力士15年的平野佳壽，於對戰羅德的關鍵時刻登板並成功關門，不僅讓他達到難得... 相關標籤: 日本職棒,Npb,歐力士猛牛,亞利桑那響尾蛇,終結者,守護神,名球會,平野佳壽,岸田護,250次救援成功,中日龍,廣島東洋鯉魚,小園海斗,末包昇大,堂林翔太">\n<meta property="og:url" content="https://www.sportsv.net/baseball/npb">\n<meta property="og:site_name" content="運動視界 Sports Vision">\n<meta property="og:locale" content="zh_TW">\n<meta property="og:image" content="https://www.sportsv.net/assets/images/social-share.jpg">\n\n        <meta name="twitter:card" content="summary_large_image">\n<meta name="twitter:site" content="運動視界 Sports Vision">\n<meta name="twitter:creator" content="運動視界 Sports Vision">\n<meta name="twitter:title" content="日職 | 運動視界 Sports Vision">\n<meta name="twitter:description" content="日職日職史上僅三人達到的250次救援成功，近日則迎來一位新成員加入，效力歐力士15年的平野佳壽，於對戰羅德的關鍵時刻登板並成功關門，不僅讓他達到難得... 相關標籤: 日本職棒,Npb,歐力士猛牛,亞利桑那響尾蛇,終結者,守護神,名球會,平野佳壽,岸田護,250次救援成功,中日龍,廣島東洋鯉魚,小園海斗,末包昇大,堂林翔太">\n\n        <meta name="robots" content="all">\n\n        <link rel="preload" as="style" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" /><link rel="preload" as="style" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" /><link rel="stylesheet" href="https://www.sportsv.net/assets/assets/vendor-YagqDQax.css" /><link rel="stylesheet" href="https://www.sportsv.net/assets/assets/style-C8GybCr0.css" />        <script>\n          window.pbjs = window.pbjs || {que: []};\n                window.googletag = window.googletag || {cmd: []};\n      </script>\n  <script async src="https://flux-cdn.com/client/1000265/sportsv_01465.min.js"></script>\n  <script async src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script>\n  <script>\n    window.fluxtag = {\n      readyBids: {prebid: false, amazon: false, google: false},\n      failSafeTimeout: 3000,\n      isFn: function (object) {\n        var _t = \'Function\';\n        var toString = Object.prototype.toString;\n        return toString.call(object) === \'[object \' + _t + \']\';\n      },\n      launchAdServer: function () {\n        if (!fluxtag.readyBids.prebid || !fluxtag.readyBids.amazon) {\n          return;\n        }\n        fluxtag.requestAdServer();\n      },\n      requestAdServer: function () {\n        if (!fluxtag.readyBids.google) {\n          fluxtag.readyBids.google = true;\n          googletag.cmd.push(function () {\n            if (!!(pbjs.setTargetingForGPTAsync) && fluxtag.isFn(pbjs.setTargetingForGPTAsync)) {\n              pbjs.que.push(function () { pbjs.setTargetingForGPTAsync(); });\n            }\n            googletag.pubads().refresh();\n          });\n        }\n      },\n      renderAds: function (lines, failSafeTimeout) {\n        googletag.cmd.push(function () {\n          var failSafeTimeout = failSafeTimeout || window.fluxtag.failSafeTimeout;\n          var bidRequestTimeout = (failSafeTimeout - 500) > 0 ? failSafeTimeout - 500 : failSafeTimeout;\n          var refreshLines = [];\n          var params = (function () {\n            var readyBids = {amazon: false, google: false, prebid: false};\n            var definedSlots = [];\n            var adsInfo = {\n              gpt: {slots: [], displayDivIds:  ...

# %%
items = page.findAll('div',{'class':"row item"})
items
# Out:
# [<div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/4c397a0a-a124-44c8-af5f-b0650e9d9412.png
# 中止開季4連敗！西武獅取得2025年賽季第一個勝場系列戰
# 2025/04/08
# https://www.sportsv.net/articles/118619
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/04/de6525b1-96c8-411c-82e5-a6b7700d21d3.jpg

# %%
data = zip(item_id_list,date_list, title_list,category_list,content_list,article_link_list,photo_link_list)
df = pd.DataFrame(list(data), columns=['item_id','date','title','category','content','link','photo_link'])

# %%
df.to_csv("sportsv_baseball_categroy.csv", sep="|", index=False, mode='a', header=False)

# %% [markdown]
# 三級棒球

# %%
category_url = 'https://www.sportsv.net/baseball/student'

# req = requests.get(category_url)
req = requests.get(category_url, headers={ 'user-agent': user_agent.random })

# page = BeautifulSoup(req.text, 'lxml')
page = BeautifulSoup(req.text, 'html.parser')

# %%
items = page.findAll('div',{'class':"row item"})
items
# Out:
# [<div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/91722">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/3719bfc8-a620-4d45-b3cc-afebebb2efca.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/3719bfc8-a620-4d45-b3cc-afebebb2efca.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/05/3719bfc8-a620-4d45-b3cc-afebebb2efca.jpg 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2022/02/01</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/91722">被稱為最強U18中華隊！他們目前的近況？(上)</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/sci_girl"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/sci_girl">喜歡碎念的Riley</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/91722">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/80232">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/d4294725-8220-40c5-9664-c2e5a0fcdb43.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/d4294725-8220-40c5-9664-c2e5a0fcdb43.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/05/d4294725-8220-40c5-9664-c2e5a0fcdb43.jpg 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2021/01/04</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/80232">【球爸筆記】讓孩子玩棒球會不會荒廢學業嗎？來談談一般大眾對於打棒球這件事的一些誤解之1</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/arjinyuan"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/arjinyuan">Arjin Yuan</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/80232">
#  <i class="fa fa-comments"></i>2</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/91756">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/8e3dd684-77f1-4f49-b8de-51d7e82f4b68.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/8e3dd684-77f1-4f49-b8de-51d7e82f4b68.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/05/8e3dd684-77f1-4f49-b8de-51d7e82f4b68.jpg 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2022/02/04</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/91756">被稱為最強U18中華隊！他們目前的近況？(下)</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/sci_girl"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/sci_girl">喜歡碎念的Riley</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/91756">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/80140">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/7a1ac179-b979-4205-a407-c965036453f1.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/7a1ac179-b979-4205-a407-c965036453f1.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/05/7a1ac179-b979-4205-a407-c965036453f1.jpg 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2020/12/31</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/80140">【球爸筆記】讓孩子玩棒球會很花錢嗎？來算算棒球個人裝備的初期成本</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/arjinyuan"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/arjinyuan">Arjin Yuan</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/80140">
#  <i class="fa fa-comments"></i>4</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/93928">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/9450f4a2-0eef-4e85-8960-cd62c7a86f45.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/9450f4a2-0eef-4e85-8960-cd62c7a86f45.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/05/9450f4a2-0eef-4e85-8960-cd62c7a86f45.jpg 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2022/04/30</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/93928">【球爸筆記】棒球國是會議後多年過去了，臺灣三級棒球有哪些改變呢？由數據來觀察學生棒球的趨勢</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/arjinyuan"><img alt="名人堂" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon4.png" title="名人堂"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/arjinyuan">Arjin Yuan</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/93928">
#  <i class="fa fa-comments"></i>8</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <div class="panel-default">
#  <a href="https://www.sportsv.net/articles/116065">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/11/b931dc24-eca3-45d4-b5be-15b4fb66ffea.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/11/b931dc24-eca3-45d4-b5be-15b4fb66ffea.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/11/b931dc24-eca3-45d4-b5be-15b4fb66ffea.jpg 800w"/>
#  </a>
#  </div>
#  </div>
#  <div class="col-xs-12 col-md-7 infon">
#  <div class="date">2024/12/12</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h4>
#  <a href="https://www.sportsv.net/articles/116065">【青棒 | 成長點滴】以天賦站穩腳步，用笑容走向頂峰—關於朱盟快樂打棒球的「美」夢</a>
#  </h4>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/pennywei2023"><img alt="新人聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon1.png" title="新人聯盟"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/pennywei2023">Wei Sin Yi</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/116065">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/115021">
#  <div class="panel-default">
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/01/702e72d2-cefe-4485-91eb-a068ffba3d3c.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2025/01/702e72d2-cefe-4485-91eb-a068ffba3d3c.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2025/01/702e72d2-cefe-4485-91eb-a068ffba3d3c.jpg 800w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2025/01/22</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/115021">【場邊筆記｜U18】鉑濬 in our eyes：這些年，我們視角裡的林鉑濬</a>
#  </h3>
#  <p class="description">對於畢業自鶯歌工商、2024年亞洲青棒錦標賽MVP－林鉑濬的印象，多來自於轉播、報導、教練或中華隊隊友口中的王者風範。其實，隱身在其背後的訓練員、高中搭擋捕手，以及現場見證奪下MVP殊榮的前室友學長，正如一台台不為眾人所知的無名相機，也點滴記錄著他的成長。本篇將透過他們各自不同的「視角」，回顧這位即將踏上美職夢土，好勝、愛哭卻又重感情的野球少年的熱血青春。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/
div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/116689">臺韓少棒賽／大仁2投聯手四局無安打 提前扣倒韓國白虎</a>
#  </h3>
#  <p class="description">大仁國小林垣翔首度先發三局無安打奪勝，與羅品皓聯手封鎖韓國白虎，終場10:0提前結束比賽。首局猛攻5分奠定勝基，王梓睿、賴冠祥、羅品皓皆有場內全壘打演出。</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/jerryyu050115"><img alt="新人聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon1.png" title="新人聯盟"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/jerryyu050115">小游</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/116689">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/少棒">少棒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/韓國">韓國</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/臺韓少棒賽">臺韓少棒賽</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/大仁國小">大仁國小</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>,
#  <div class="row item">
#  <div class="col-md-5">
#  <a href="https://www.sportsv.net/articles/55200">
#  <div class="panel-default">
#  <div class="sponsor right top">SPONSORED</div>
#  <img class="cover" loading="lazy" src="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/6e2fd69d-ddbf-42f2-9eba-0acb55d8465d.jpg" srcset="https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/6e2fd69d-ddbf-42f2-9eba-0acb55d8465d.jpg 480w, https://bucket-image.inkmaginecms.com/version/mobile/1/image/2024/05/6e2fd69d-ddbf-42f2-9eba-0acb55d8465d.jpg 800w, https://bucket-image.inkmaginecms.com/version/desktop/1/image/2024/05/6e2fd69d-ddbf-42f2-9eba-0acb55d8465d.jpg 1200w"/>
#  </div>
#  </a>
#  </div>
#  <div class="col-md-7">
#  <div class="date">2018/08/31</div>
#  <ul class="crumb">
#  <li>
#  <a href="https://www.sportsv.net/baseball">棒球</a>
#  <i class="fa fa-chevron-right"></i>
#  </li>
#  <li>
#  <a href="https://www.sportsv.net/baseball/student">三級棒球</a>
#  </li>
#  </ul>
#  <h3>
#  <a href="https://www.sportsv.net/articles/55200">徐裴翊談少棒：關鍵不只在球場，養成與教育更是重點</a>
#  </h3>
#  <p class="description">Photo Credit：關鍵評論網
#
#
#  過往熱愛中華職棒，或是經常親臨天母棒球場、洲際棒球場，為中華棒球隊吶喊加油、聲嘶力竭的棒球運動愛好者們，相信都曾經在場邊見過前電視臺體育主播：徐...</p>
#  <div class="author">
#  <a class="author_status" href="https://www.sportsv.net/authors/sportsveditor"><img alt="大聯盟" loading="lazy" src="https://www.sportsv.net/assets/images/level-icon3.png" title="大聯盟"/></a>
#  <a class="author_name" href="https://www.sportsv.net/authors/sportsveditor">運動視界編輯</a>
#  <a class="author_comments" href="https://www.sportsv.net/articles/55200">
#  <i class="fa fa-comments"></i>0</a>
#  </div>
#  <div id="tags">
#  <ul class="tagcloud-list">
#  <li>
#  <a class="tag-link" href="/tags/三級棒球">三級棒球</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/徐裴翊">徐裴翊</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/倆好球">倆好球</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/臺灣少棒">臺灣少棒</a>
#  </li>
#  <li>
#  <a class="tag-link" href="/tags/SPONSORED">SPONSORED</a>
#  </li>
#  </ul>
#  </div>
#  </div>
#  </div>]

# %%
category = '三級棒球'

serial_no = 1

# 存放資料之變數
article_link_list = []
title_list = []
date_list = []
category_list = []
photo_link_list = []

item_id_list = []
content_list = []

for item in items:
    # 新聞標題
    title = (item.find('h3') or item.find('h4')).text.strip() if (item.find('h3') or item.find('h4')) else None
    print(title)

    # 如果標題為 None，則跳過這篇新聞
    if title is None or title == "":
        print("標題為空，跳過這篇新聞。")
        continue

    # 新聞日期
    news_time = item.find('div', {'class': "date"}).text.strip() if item.find('div', {'class': "date"}) else ""
    print(news_time)

    # 新聞連結
    article_url = item.find('a').get('href')
    print(article_url)

    try:
        # Use if else to deal with it
        if item.find('img').get('src'):
            photo_link = item.find('img').get('src')
    except:
        print('No photo link!')
        photo_link = ''

    print(photo_link)

    category_list.append(category)
    date_list.append(news_time)
    title_list.append(title)  # 修正了這裡的變數名稱
    photo_link_list.append(photo_link)
    article_link_list.append(article_url)

    # item id
    date_str = dtime.strftime("%Y%m%d")

    item_id_list.append("sportsv_" + date_str + "_" + str(serial_no))
    serial_no += 1

    ##### Crawl article content 爬新聞內容
    # There are some words we don't like to analyze, They should be removed.
    req = requests.get(article_url, headers={'user-agent': user_agent.random}, timeout=5)
    # page = BeautifulSoup(req.text, 'lxml')
    page = BeautifulSoup(req.text, 'html.parser')


    # Find content
    content_div = page.find('div', class_='article-content')
    paragraphs = content_div.find_all('p')
    content = ''.join([p.get_text(strip=True) for p in paragraphs])
    content

    content_list.append(content)

    # scrap only 10 articles
    if serial_no >= 10:
        break

    time.sleep(10)  # 遵守爬蟲禮節，請小睡一下
# Out:
# 被稱為最強U18中華隊！他們目前的近況？(上)
# 2022/02/01
# https://www.sportsv.net/articles/91722
# https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/3719bfc8-a620-4d45-b3cc-afebebb2efca.jpg
# 【球爸筆記】讓孩子玩棒球會不會荒廢學業嗎？來談談一般大眾對於打棒球這件事的一些誤解之1
# 2021/01/04
# https://www.sportsv.net/articles/80232
# https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/d4294725-8220-40c5-9664-c2e5a0fcdb43.jpg
# 被稱為最強U18中華隊！他們目前的近況？(下)
# 2022/02/04
# https://www.sportsv.net/articles/91756
# https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/8e3dd684-77f1-4f49-b8de-51d7e82f4b68.jpg
# 【球爸筆記】讓孩子玩棒球會很花錢嗎？來算算棒球個人裝備的初期成本
# 2020/12/31
# https://www.sportsv.net/articles/80140
# https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/7a1ac179-b979-4205-a407-c965036453f1.jpg
# 【球爸筆記】棒球國是會議後多年過去了，臺灣三級棒球有哪些改變呢？由數據來觀察學生棒球的趨勢
# 2022/04/30
# https://www.sportsv.net/articles/93928
# https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/9450f4a2-0eef-4e85-8960-cd62c7a86f45.jpg
# 【青棒 | 成長點滴】以天賦站穩腳步，用笑容走向頂峰—關於朱盟快樂打棒球的「美」夢
# 2024/12/12
# https://www.sportsv.net/articles/116065
# https://bucket-image.inkmaginecms.com/version/list/1/image/2024/11/b931dc24-eca3-45d4-b5be-15b4fb66ffea.jpg
# 【場邊筆記｜U18】鉑濬 in our eyes：這些年，我們視角裡的林鉑濬
# 2025/01/22
# https://www.sportsv.net/articles/115021
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/01/702e72d2-cefe-4485-91eb-a068ffba3d3c.jpg
# 【場邊筆記｜大專】「有我在」的大專舞台－記24年UBL四強賽那些人物的小事
# 2025/01/16
# https://www.sportsv.net/articles/116865
# https://bucket-image.inkmaginecms.com/version/list/1/image/2025/01/3df0bd6d-fd0c-4d8a-8c5f-d3ed94144da0.png
# 停止跟孩子說為國爭光，讓我們幫助他們為自己發光
# 2018/11/28
# https://www.sportsv.net/articles/57884
# https://bucket-image.inkmaginecms.com/version/list/1/image/2024/05/3f5cd234-2573-4459-8549-07575a3f0c1d.jpg

# %%
data = zip(item_id_list,date_list, title_list,category_list,content_list,article_link_list,photo_link_list)
df = pd.DataFrame(list(data), columns=['item_id','date','title','category','content','link','photo_link'])

# %%
df.to_csv("sportsv_baseball_categroy.csv", sep="|", index=False, mode='a', header=False)
